# %%
import requests
import pandas as pd
import json
import numpy as np


# Setup pitch and plot
from mplsoccer.pitch import Pitch ,VerticalPitch

username = "XXX"
password = "XXX"


from skillcorner.client import SkillcornerClient
client=SkillcornerClient(username=username,password=password)

def time_to_seconds(time_str):
    if time_str is None:
        return 90 * 60  # 120 minutes = 7200 seconds
    h, m, s = map(int, time_str.split(':'))
    return h * 3600 + m * 60 + s


# black .

# %% [markdown]
# ### Extract Tracking Data

# %%
####-----------------------------------------------------------------------------------
# If you're a skillcorner client and you know your match_id you can use the pyton client
###------------------------------------------------------------------------------------
# match_id=1886347
# client.save_match_tracking_data(match_id,
#                                 params={'data_version':3},
#                                 filepath=f'{match_id}_tracking_raw.jsonl')

####-----------------------------------------------------------------------------------
# If you've cloned the repo and are in your local copy
###------------------------------------------------------------------------------------
match_id = 1886347
# raw_data = pd.read_json(
#     f"../sample_data/{match_id}_tracking_extrapolated.jsonl", lines=True
# )

####-----------------------------------------------------------------------------------
# If you're on a separate project/environemnt
###------------------------------------------------------------------------------------

# # Construct the raw GitHub URL
tracking_data_github_url=f'https://media.githubusercontent.com/media/SkillCorner/opendata/741bdb798b0c1835057e3fa77244c1571a00e4aa/data/matches/{match_id}/{match_id}_tracking_extrapolated.jsonl' # Data is stored using GitLFS
raw_data=pd.read_json(tracking_data_github_url,lines=True)


raw_df = pd.json_normalize(
    raw_data.to_dict("records"),
    "player_data",
    ["frame", "timestamp", "period", "possession", "ball_data"],
)

# Extract 'player_id' and 'group from the 'possession' dictionary
raw_df["possession_player_id"] = raw_df["possession"].apply(
    lambda x: x.get("player_id")
)
raw_df["possession_group"] = raw_df["possession"].apply(lambda x: x.get("group"))


# (Optional) Expand the ball_data with json_normalize
raw_df[["ball_x", "ball_y", "ball_z", "is_detected_ball"]] = pd.json_normalize(
    raw_df.ball_data
)


# (Optional) Drop the original 'possession' column if you no longer need it
raw_df = raw_df.drop(columns=["possession", "ball_data"])

# Add the match_id identifier to your dataframe
raw_df["match_id"] = match_id
tracking_df = raw_df.copy()
tracking_df.head()
# Out:
#        x      y  player_id  is_detected frame  timestamp period  \
# 0 -39.63  -0.08      51009        False    10 2025-10-28    1.0
# 1 -19.21  -9.18     176224         True    10 2025-10-28    1.0
# 2 -21.83   0.47      51649         True    10 2025-10-28    1.0
# 3  -1.16 -32.47      50983         True    10 2025-10-28    1.0
# 4 -18.88  15.73     735578         True    10 2025-10-28    1.0
#
#    possession_player_id possession_group  ball_x  ball_y  ball_z  \
# 0                   NaN             None    0.32    0.38    0.13
# 1                   NaN             None    0.32    0.38    0.13
# 2                   NaN             None    0.32    0.38    0.13
# 3                   NaN             None    0.32    0.38    0.13
# 4                   NaN             None    0.32    0.38    0.13
#
#    is_detected_ball  match_id
# 0              True   1886347
# 1              True   1886347
# 2              True   1886347
# 3              True   1886347
# 4              True   1886347

# %% [markdown]
# ### Extract MetaData

# %%
####-----------------------------------------------------------------------------------
# If you're a skillcorner client and you know your match_id you can use the python client
###------------------------------------------------------------------------------------
# match_id=1886347
# raw_match_data=client.get_match(match_id)


####-----------------------------------------------------------------------------------
# If you've cloned the repo and are in your local copy
###------------------------------------------------------------------------------------
# match_id = 1886347
# file_path = f"../../data/matches/{match_id}/{match_id}_match.json"

# with open(file_path, "r") as f:
#     raw_match_data = json.load(f)

####-----------------------------------------------------------------------------------
# If you're on a separate project/environemnt
###------------------------------------------------------------------------------------
match_id=1886347
meta_data_github_url=f'https://raw.githubusercontent.com/SkillCorner/opendata/741bdb798b0c1835057e3fa77244c1571a00e4aa/data/matches/{match_id}/{match_id}_match.json'
# Read the JSON data as a JSON object
response = requests.get(meta_data_github_url)
raw_match_data = response.json()


# The output has nested json elements. We process them
raw_match_df = pd.json_normalize(raw_match_data, max_level=2)
raw_match_df["home_team_side"] = raw_match_df["home_team_side"].astype(str)

players_df = pd.json_normalize(
    raw_match_df.to_dict("records"),
    record_path="players",
    meta=[
        "home_team_score",
        "away_team_score",
        "date_time",
        "home_team_side",
        "home_team.name",
        "home_team.id",
        "away_team.name",
        "away_team.id",
    ],  # data we keep
)


# Take only players who played and create their total time
players_df = players_df[
    ~((players_df.start_time.isna()) & (players_df.end_time.isna()))
]
players_df["total_time"] = players_df["end_time"].apply(time_to_seconds) - players_df[
    "start_time"
].apply(time_to_seconds)

# Create a flag for GK
players_df["is_gk"] = players_df["player_role.acronym"] == "GK"

# Add a flag if the given player is home or away
players_df["match_name"] = (
    players_df["home_team.name"] + " vs " + players_df["away_team.name"]
)


# Add a flag if the given player is home or away
players_df["home_away_player"] = np.where(
    players_df.team_id == players_df["home_team.id"], "Home", "Away"
)

# Create flag from player
players_df["team_name"] = np.where(
    players_df.team_id == players_df["home_team.id"],
    players_df["home_team.name"],
    players_df["away_team.name"],
)

# Figure out sides
players_df[["home_team_side_1st_half", "home_team_side_2nd_half"]] = (
    players_df["home_team_side"]
    .astype(str)
    .str.strip("[]")
    .str.replace("'", "")
    .str.split(", ", expand=True)
)
# Clean up sides
players_df["direction_player_1st_half"] = np.where(
    players_df.home_away_player == "Home",
    players_df.home_team_side_1st_half,
    players_df.home_team_side_2nd_half,
)
players_df["direction_player_2nd_half"] = np.where(
    players_df.home_away_player == "Home",
    players_df.home_team_side_2nd_half,
    players_df.home_team_side_1st_half,
)


# Clean up and keep the columns that we want to keep about

columns_to_keep = [
    "start_time",
    "end_time",
    "match_name",
    "date_time",
    "home_team.name",
    "away_team.name",
    "id",
    "short_name",
    "number",
    "team_id",
    "team_name",
    "player_role.position_group",
    "total_time",
    "player_role.name",
    "player_role.acronym",
    "is_gk",
    "direction_player_1st_half",
    "direction_player_2nd_half",
]
players_df = players_df[columns_to_keep]
players_df.head()
# Out:
#   start_time  end_time                               match_name  \
# 0   00:00:00  01:25:21  Auckland FC vs Newcastle United Jets FC
# 1   00:00:00      None  Auckland FC vs Newcastle United Jets FC
# 2   00:00:00  01:16:37  Auckland FC vs Newcastle United Jets FC
# 3   00:00:00  01:24:58  Auckland FC vs Newcastle United Jets FC
# 4   00:00:00      None  Auckland FC vs Newcastle United Jets FC
#
#               date_time home_team.name            away_team.name      id  \
# 0  2024-11-30T04:00:00Z    Auckland FC  Newcastle United Jets FC   38673
# 1  2024-11-30T04:00:00Z    Auckland FC  Newcastle United Jets FC   51713
# 2  2024-11-30T04:00:00Z    Auckland FC  Newcastle United Jets FC   50951
# 3  2024-11-30T04:00:00Z    Auckland FC  Newcastle United Jets FC   50978
# 4  2024-11-30T04:00:00Z    Auckland FC  Newcastle United Jets FC  133498
#
#     short_name  number  team_id                 team_name  \
# 0       G. May      10     4177               Auckland FC
# 1   C. Elliott      17     4177               Auckland FC
# 2   J. Brimmer      22     4177               Auckland FC
# 3   C. Timmins      19     1805  Newcastle United Jets FC
# 4  F. De Vries      15     4177               Auckland FC
#
#   player_role.position_group  total_time         player_role.name  \
# 0             Center Forward        5121           Center Forward
# 1                  Full Back        5400               Right Back
# 2             Center Forward        4597           Center Forward
# 3                   Midfield        5098  Left Defensive Midfield
# 4                  Full Back        5400                Left Back
#
#   player_role.acronym  is_gk direction_player_1st_half  \
# 0                  CF  False             right_to_left
# 1                  RB  False             right_to_left
# 2                  CF  False             right_to_left
# 3                 LDM  False             left_to_right
# 4                  LB  False             right_to_left
#
#   direction_player_2nd_half
# 0             left_to_right
# 1             left_to_right
# 2             left_to_right
# 3             right_to_left
# 4             left_to_right

# %% [markdown]
# ### Merge Dataframes

# %%
# Merging datasets
enriched_tracking_data = tracking_df.merge(
    players_df, left_on=["player_id"], right_on=["id"]
)
enriched_tracking_data.head()
# Out:
#        x      y  player_id  is_detected frame  timestamp period  \
# 0 -39.63  -0.08      51009        False    10 2025-10-28    1.0
# 1 -19.21  -9.18     176224         True    10 2025-10-28    1.0
# 2 -21.83   0.47      51649         True    10 2025-10-28    1.0
# 3  -1.16 -32.47      50983         True    10 2025-10-28    1.0
# 4 -18.88  15.73     735578         True    10 2025-10-28    1.0
#
#    possession_player_id possession_group  ball_x  ball_y  ball_z  \
# 0                   NaN             None    0.32    0.38    0.13
# 1                   NaN             None    0.32    0.38    0.13
# 2                   NaN             None    0.32    0.38    0.13
# 3                   NaN             None    0.32    0.38    0.13
# 4                   NaN             None    0.32    0.38    0.13
#
#    is_detected_ball  match_id start_time end_time  \
# 0              True   1886347   00:00:00     None
# 1              True   1886347   00:00:00     None
# 2              True   1886347   00:00:00     None
# 3              True   1886347   00:00:00     None
# 4              True   1886347   00:00:00     None
#
#                                 match_name             date_time  \
# 0  Auckland FC vs Newcastle United Jets FC  2024-11-30T04:00:00Z
# 1  Auckland FC vs Newcastle United Jets FC  2024-11-30T04:00:00Z
# 2  Auckland FC vs Newcastle United Jets FC  2024-11-30T04:00:00Z
# 3  Auckland FC vs Newcastle United Jets FC  2024-11-30T04:00:00Z
# 4  Auckland FC vs Newcastle United Jets FC  2024-11-30T04:00:00Z
#
#   home_team.name            away_team.name      id  short_name  number  \
# 0    Auckland FC  Newcastle United Jets FC   51009    R. Scott       1
# 1    Auckland FC  Newcastle United Jets FC  176224   P. Cancar       4
# 2    Auckland FC  Newcastle United Jets FC   51649  A. Šušnjar      15
# 3    Auckland FC  Newcastle United Jets FC   50983   D. Ingham      14
# 4    Auckland FC  Newcastle United Jets FC  735578    M. Natta      33
#
#    team_id                 team_name player_role.position_group  total_time  \
# 0     1805  Newcastle United Jets FC                      Other        5400
# 1     1805  Newcastle United Jets FC           Central Defender        5400
# 2     1805  Newcastle United Jets FC           Central Defender        5400
# 3     1805  Newcastle United Jets FC                  Full Back        5400
# 4     1805  Newcastle United Jets FC                  Full Back        5400
#
#     player_role.name player_role.acronym  is_gk direction_player_1st_half  \
# 0         Goalkeeper                  GK   True             left_to_right
# 1  Right Center Back                 RCB  False             left_to_right
# 2   Left Center Back                 LCB  False             left_to_right
# 3         Right Back                  RB  False             left_to_right
# 4          Left Back                  LB  False             left_to_right
#
#   direction_player_2nd_half
# 0             right_to_left
# 1             right_to_left
# 2             right_to_left
# 3             right_to_left
# 4             right_to_left

# %% [markdown]
# ### Get dynamic events data

# %%
match_id = 1886347
de_match = pd.read_csv(f"./sample_data/{match_id}_dynamic_events.csv")

# %%
pd.set_option('display.max_columns', None)
pd.set_option('display.width', None)
pd.set_option('display.max_colwidth', None)

print(f"Total columns: {len(de_match.columns)}")
list(de_match.columns)
# Out:
# Total columns: 294
# ['event_id',
#  'index',
#  'match_id',
#  'frame_start',
#  'frame_end',
#  'frame_physical_start',
#  'time_start',
#  'time_end',
#  'minute_start',
#  'second_start',
#  'duration',
#  'period',
#  'attacking_side_id',
#  'attacking_side',
#  'event_type_id',
#  'event_type',
#  'event_subtype_id',
#  'event_subtype',
#  'player_id',
#  'player_name',
#  'player_position_id',
#  'player_position',
#  'player_in_possession_id',
#  'player_in_possession_name',
#  'player_in_possession_position_id',
#  'player_in_possession_position',
#  'team_id',
#  'team_shortname',
#  'x_start',
#  'y_start',
#  'channel_id_start',
#  'channel_start',
#  'third_id_start',
#  'third_start',
#  'penalty_area_start',
#  'x_end',
#  'y_end',
#  'channel_id_end',
#  'channel_end',
#  'third_id_end',
#  'third_end',
#  'penalty_area_end',
#  'associated_player_possession_event_id',
#  'associated_player_possession_frame_start',
#  'associated_player_possession_frame_end',
#  'associated_player_possession_end_type_id',
#  'associated_player_possession_end_type',
#  'associated_off_ball_run_event_id',
#  'associated_off_ball_run_subtype_id',
#  'associated_off_ball_run_subtype',
#  'game_state_id',
#  'game_state',
#  'team_score',
#  'opponent_team_score',
#  'phase_index',
#  'player_possession_phase_index',
#  'first_player_possession_in_team_possession',
#  'last_player_possession_in_team_possession',
#  'lead_to_different_phase',
#  'issued_from_different_phase',
#  'n_player_possessions_in_phase',
#  'team_possession_loss_in_phase',
#  'team_in_possession_phase_type_id',
#  'team_in_possession_phase_type',
#  'team_out_of_possession_phase_type_id',
#  'team_out_of_possession_phase_type',
#  'current_team_in_possession_next_phase_type_id',
#  'current_team_in_possession_next_phase_type',
#  'current_team_out_of_possession_next_phase_type_id',
#  'current_team_out_of_possession_next_phase_type',
#  'current_team_in_possession_previous_phase_type_id',
#  'current_team_in_possession_previous_phase_type',
#  'current_team_out_of_possession_previous_phase_type_id',
#  'current_team_out_of_possession_previous_phase_type',
#  'game_interruption_before_id',
#  'game_interruption_before',
#  'game_interruption_after_id',
#  'game_interruption_after',
#  'lead_to_shot',
#  'lead_to_goal',
#  'distance_covered',
#  'trajectory_angle',
#  'trajectory_direction_id',
#  'trajectory_direction',
#  'in_to_out',
#  'out_to_in',
#  'speed_avg',
#  'speed_avg_band_id',
#  'speed_avg_band',
#  'separation_start',
#  'separation_end',
#  'separation_gain',
#  'last_defensive_line_x_start',
#  'last_defensive_line_x_end',
#  'delta_to_last_defensive_line_start',
#  'delta_to_last_defensive_line_end',
#  'delta_to_last_defensive_line_gain',
#  'last_defensive_line_height_start',
#  'last_defensive_line_height_end',
#  'last_defensive_line_height_gain',
#  'inside_defensive_shape_start',
#  'inside_defensive_shape_end',
#  'start_type_id',
#  'start_type',
#  'end_type_id',
#  'end_type',
#  'consecutive_on_ball_engagements',
#  'one_touch',
#  'quick_pass',
#  'carry',
#  'forward_momentum',
#  'is_header',
#  'hand_pass',
#  'initiate_give_and_go',
#  'pass_angle_received',
#  'pass_direction_received_id',
#  'pass_direction_received',
#  'pass_distance_received',
#  'pass_range_received_id',
#  'pass_range_received',
#  'pass_outcome_id',
#  'pass_outcome',
#  'targeted_passing_option_event_id',
#  'high_pass',
#  'player_targeted_id',
#  'player_targeted_name',
#  'player_targeted_position_id',
#  'player_targeted_position',
#  'player_targeted_x_pass',
#  'player_targeted_y_pass',
#  'player_targeted_channel_pass_id',
#  'player_targeted_channel_pass',
#  'player_targeted_third_pass_id',
#  'player_targeted_third_pass',
#  'player_targeted_penalty_area_pass',
#  'player_targeted_x_reception',
#  'player_targeted_y_reception',
#  'player_targeted_channel_reception_id',
#  'player_targeted_channel_reception',
#  'player_targeted_third_reception_id',
#  'player_targeted_third_reception',
#  'player_targeted_penalty_area_reception',
#  'player_targeted_distance_to_goal_start',
#  'player_targeted_distance_to_goal_end',
#  'player_targeted_angle_to_goal_start',
#  'player_targeted_angle_to_goal_end',
#  'player_targeted_average_speed',
#  'player_targeted_speed_avg_band_id',
#  'player_targeted_speed_avg_band',
#  'speed_difference',
#  'player_targeted_xpass_completion',
#  'player_targeted_difficult_pass_target',
#  'player_targeted_xthreat',
#  'player_targeted_dangerous',
#  'n_passing_options',
#  'n_off_ball_runs',
#  'n_passing_options_line_break',
#  'n_passing_options_first_line_break',
#  'n_passing_options_second_last_line_break',
#  'n_passing_options_last_line_break',
#  'n_passing_options_ahead',
#  'n_passing_options_dangerous_difficult',
#  'n_passing_options_dangerous_not_difficult',
#  'n_passing_options_not_dangerous_not_difficult',
#  'n_passing_options_not_dangerous_difficult',
#  'n_passing_options_at_start',
#  'n_passing_options_at_end',
#  'n_passing_options_ahead_at_start',
#  'n_passing_options_ahead_at_end',
#  'n_teammates_ahead_end',
#  'n_teammates_ahead_start',
#  'n_player_targeted_opponents_ahead_start',
#  'n_player_targeted_opponents_ahead_end',
#  'n_player_targeted_teammates_ahead_start',
#  'n_player_targeted_teammates_ahead_end',
#  'n_player_targeted_teammates_within_5m_start',
#  'n_player_targeted_teammates_within_5m_end',
#  'n_player_targeted_opponents_within_5m_start',
#  'n_player_targeted_opponents_within_5m_end',
#  'organised_defense',
#  'defensive_structure',
#  'n_defensive_lines',
#  'first_line_break',
#  'first_line_break_type_id',
#  'first_line_break_type',
#  'second_last_line_break',
#  'second_last_line_break_type_id',
#  'second_last_line_break_type',
#  'last_line_break',
#  'last_line_break_type_id',
#  'last_line_break_type',
#  'furthest_line_break_id',
#  'furthest_line_break',
#  'furthest_line_break_type_id',
#  'furthest_line_break_type',
#  'interplayer_distance',
#  'interplayer_distance_range_id',
#  'interplayer_distance_range',
#  'interplayer_distance_start',
#  'interplayer_distance_end',
#  'interplayer_distance_min',
#  'interplayer_distance_start_physical',
#  'close_at_player_possession_start',
#  'interplayer_angle',
#  'interplayer_direction_id',
#  'interplayer_direction',
#  'angle_of_engagement',
#  'goal_side_start',
#  'goal_side_end',
#  'pass_distance',
#  'pass_range_id',
#  'pass_range',
#  'pass_angle',
#  'pass_direction_id',
#  'pass_direction',
#  'pass_ahead',
#  'n_opponents_ahead_player_in_possession_pass_moment',
#  'n_opponents_ahead_pass_reception',
#  'n_opponents_bypassed',
#  'location_to_player_in_possession_id_start',
#  'location_to_player_in_possession_start',
#  'location_to_player_in_possession_id_end',
#  'location_to_player_in_possession_end',
#  'distance_to_player_in_possession_start',
#  'distance_to_player_in_possession_end',
#  'player_in_possession_x_start',
#  'player_in_possession_y_start',
#  'player_in_possession_channel_id_start',
#  'player_in_possession_channel_start',
#  'player_in_possession_third_id_start',
#  'player_in_possession_third_start',
#  'player_in_possession_penalty_area_start',
#  'player_in_possession_x_end',
#  'player_in_possession_y_end',
#  'player_in_possession_channel_id_end',
#  'player_in_possession_channel_end',
#  'player_in_possession_third_id_end',
#  'player_in_possession_third_end',
#  'player_in_possession_penalty_area_end',
#  'targeted',
#  'received',
#  'received_in_space',
#  'dangerous',
#  'difficult_pass_target',
#  'xthreat',
#  'xpass_completion',
#  'passing_option_score',
#  'predicted_passing_option',
#  'peak_passing_option_frame',
#  'passing_option_at_player_possession_start',
#  'n_simultaneous_runs',
#  'give_and_go',
#  'intended_run_behind',
#  'push_defensive_line',
#  'break_defensive_line',
#  'passing_option_at_start',
#  'n_simultaneous_passing_options',
#  'passing_option_at_pass_moment',
#  'n_opponents_ahead_end',
#  'n_opponents_ahead_start',
#  'n_opponents_overtaken',
#  'pressing_chain',
#  'pressing_chain_length',
#  'pressing_chain_end_type_id',
#  'pressing_chain_end_type',
#  'pressing_chain_index',
#  'index_in_pressing_chain',
#  'simultaneous_defensive_engagement_same_target',
#  'simultaneous_defensive_engagement_same_target_rank',
#  'affected_line_breaking_passing_option_id',
#  'affected_line_break_id',
#  'affected_line_break',
#  'affected_line_breaking_passing_option_attempted',
#  'affected_line_breaking_passing_option_xthreat',
#  'affected_line_breaking_passing_option_dangerous',
#  'affected_line_breaking_passing_option_run_subtype_id',
#  'affected_line_breaking_passing_option_run_subtype',
#  'possession_danger',
#  'beaten_by_possession',
#  'beaten_by_movement',
#  'stop_possession_danger',
#  'reduce_possession_danger',
#  'force_backward',
#  'xloss_player_possession_start',
#  'xloss_player_possession_end',
#  'xloss_player_possession_max',
#  'xshot_player_possession_start',
#  'xshot_player_possession_end',
#  'xshot_player_possession_max',
#  'is_player_possession_start_matched',
#  'is_player_possession_end_matched',
#  'is_previous_pass_matched',
#  'is_pass_reception_matched',
#  'fully_extrapolated']

# %% [markdown]
# ### Player Possession

# %%
de_match[de_match['event_type'] == 'player_possession']['lead_to_goal'].value_counts()
# Out:
# lead_to_goal
# False    993
# True       6
# Name: count, dtype: int64

# %%
de_match[de_match['event_id'] == '8_1']['event_type'].value_counts()
# Out:
# event_type
# player_possession    1
# Name: count, dtype: int64

# %%
de_match[de_match['event_type'] == 'on_ball_engagement']
# Out:
#      event_id  index  match_id  frame_start  frame_end  frame_physical_start  \
# 4         9_0      4   1886347           56         58                  34.0
# 11        9_1     11   1886347           74         89                  60.0
# 18        9_2     18   1886347          235        251                 232.0
# 23        9_3     23   1886347          253        299                 253.0
# 35        9_4     35   1886347          314        319                 314.0
# ...       ...    ...       ...          ...        ...                   ...
# 5060    9_932   5060   1886347        58584      58588               58584.0
# 5062    9_933   5062   1886347        58590      58609               58590.0
# 5066    9_934   5066   1886347        58605      58609               58599.0
# 5073    9_935   5073   1886347        58753      58761               58742.0
# 5075    9_936   5075   1886347        58760      58761               58760.0
#
#      time_start time_end  minute_start  second_start  duration  period  \
# 4       00:02.4  00:04.8             0             2       2.4       1
# 11      00:05.0  00:07.9             0             5       2.9       1
# 18      00:22.2  00:24.1             0            22       1.9       1
# 23      00:24.3  00:28.9             0            24       4.6       1
# 35      00:30.4  00:30.9             0            30       0.5       1
# ...         ...      ...           ...           ...       ...     ...
# 5060    96:18.4  96:18.8            96            18       0.4       2
# 5062    96:19.0  96:20.9            96            19       1.9       2
# 5066    96:19.9  96:20.9            96            19       1.0       2
# 5073    96:34.2  96:36.1            96            34       1.9       2
# 5075    96:36.0  96:36.1            96            36       0.1       2
#
#       attacking_side_id attacking_side  event_type_id          event_type  \
# 4                     2  right_to_left              9  on_ball_engagement
# 11                    2  right_to_left              9  on_ball_engagement
# 18                    1  left_to_right              9  on_ball_engagement
# 23                    2  right_to_left              9  on_ball_engagement
# 35                    1  left_to_right              9  on_ball_engagement
# ...                 ...            ...            ...                 ...
# 5060                  1  left_to_right              9  on_ball_engagement
# 5062                  1  left_to_right              9  on_ball_engagement
# 5066                  1  left_to_right              9  on_ball_engagement
# 5073                  1  left_to_right              9  on_ball_engagement
# 5075                  1  left_to_right              9  on_ball_engagement
#
#       event_subtype_id   event_subtype  player_id  player_name  \
# 4                 11.0        pressing      50951   J. Brimmer
# 11                14.0  recovery_press      38673       G. May
# 18                12.0        pressure     795505     E. Adams
# 23                12.0        pressure     965685   L. Gillion
# 35                12.0        pressure      50983    D. Ingham
# ...                ...             ...        ...          ...
# 5060              12.0        pressure     965685   L. Gillion
# 5062              12.0        pressure     133498  F. De Vries
# 5066              14.0  recovery_press     965685   L. Gillion
# 5073              12.0        pressure     163972      M. Mata
# 5075              15.0           other      43829    N. Moreno
#
#       player_position_id player_position  player_in_possession_id  \
# 4                     19              CF                  51649.0
# 11                    19              CF                 735578.0
# 18                    17              RW                 133498.0
# 23                    16              LW                  50983.0
# 35                     8              RB                 965685.0
# ...                  ...             ...                      ...
# 5060                  16              LW                 735574.0
# 5062                   2              LB                  50983.0
# 5066                  16              LW                  50983.0
# 5073                  19              CF                  51649.0
# 5075                  17              RW                  51649.0
#
#      player_in_possession_name  player_in_possession_position_id  \
# 4                   A. Šušnjar                               4.0
# 11                    M. Natta                               2.0
# 18                 F. De Vries                               2.0
# 23                   D. Ingham                               8.0
# 35                  L. Gillion                              16.0
# ...                        ...                               ...
# 5060                 K. Grozos                              11.0
# 5062                 D. Ingham                               8.0
# 5066                 D. Ingham                               8.0
# 5073                A. Šušnjar                               4.0
# 5075                A. Šušnjar                               4.0
#
#      player_in_possession_position  team_id team_shortname  x_start  y_start  \
# 4                              LCB     4177    Auckland FC    13.03     0.06
# 11                              LB     4177    Auckland FC    16.03   -13.76
# 18                              LB     1805      Newcastle     7.53   -22.72
# 23                              RB     4177    Auckland FC     4.24    23.94
# 35                              LW     1805      Newcastle   -39.16   -28.55
# ...                            ...      ...            ...      ...      ...
# 5060                           RDM     4177    Auckland FC   -18.13    21.80
# 5062                            RB     4177    Auckland FC   -28.00    23.43
# 5066                            RB     4177    Auckland FC   -22.03    27.29
# 5073                           LCB     4177    Auckland FC   -18.24     5.27
# 5075                           LCB     4177    Auckland FC   -21.73    -3.68
#
#       channel_id_start     channel_start  third_id_start      third_start  \
# 4                    3            center               2     middle_third
# 11                   4  half_space_right               2     middle_third
# 18                   5        wide_right               2     middle_third
# 23                   1         wide_left               2     middle_third
# 35                   5        wide_right               1  defensive_third
# ...                ...               ...             ...              ...
# 5060                 1         wide_left               1  defensive_third
# 5062                 1         wide_left               1  defensive_third
# 5066                 1         wide_left               1  defensive_third
# 5073                 3            center               1  defensive_third
# 5075                 3            center               1  defensive_third
#
#       penalty_area_start  x_end  y_end  channel_id_end channel_end  \
# 4                  False  13.98  -0.68               3      center
# 11                 False  10.97 -22.06               5  wide_right
# 18                 False   7.87 -29.66               5  wide_right
# 23                 False  36.27  29.39               1   wide_left
# 35                 False -37.63 -27.21               5  wide_right
# ...                  ...    ...    ...             ...         ...
# 5060               False -17.89  22.87               1   wide_left
# 5062               False -27.72  31.64               1   wide_left
# 5066               False -23.23  28.40               1   wide_left
# 5073               False -18.83   1.26               3      center
# 5075               False -21.77  -3.74               3      center
#
#       third_id_end        third_end  penalty_area_end  \
# 4                2     middle_third             False
# 11               2     middle_third             False
# 18               2     middle_third             False
# 23               3  attacking_third             False
# 35               1  defensive_third             False
# ...            ...              ...               ...
# 5060             1  defensive_third             False
# 5062             1  defensive_third             False
# 5066             1  defensive_third             False
# 5073             1  defensive_third             False
# 5075             1  defensive_third             False
#
#      associated_player_possession_event_id  \
# 4                                      8_1
# 11                                     8_2
# 18                                     8_4
# 23                                     8_5
# 35                                     8_6
# ...                                    ...
# 5060                                 8_994
# 5062                                 8_995
# 5066                                 8_995
# 5073                                 8_997
# 5075                                 8_997
#
#       associated_player_possession_frame_start  \
# 4                                         48.0
# 11                                        72.0
# 18                                       243.0
# 23                                       283.0
# 35                                       301.0
# ...                                        ...
# 5060                                   58581.0
# 5062                                   58602.0
# 5066                                   58602.0
# 5073                                   58733.0
# 5075                                   58733.0
#
#       associated_player_possession_frame_end  \
# 4                                       58.0
# 11                                      89.0
# 18                                     251.0
# 23                                     299.0
# 35                                     337.0
# ...                                      ...
# 5060                                 58588.0
# 5062                                 58609.0
# 5066                                 58609.0
# 5073                                 58761.0
# 5075                                 58761.0
#
#       associated_player_possession_end_type_id  \
# 4                                          1.0
# 11                                         1.0
# 18                                         1.0
# 23                                         1.0
# 35                                         1.0
# ...                                        ...
# 5060                                       1.0
# 5062                                       1.0
# 5066                                       1.0
# 5073                                       2.0
# 5075                                       2.0
#
#      associated_player_possession_end_type associated_off_ball_run_event_id  \
# 4                                     pass                              NaN
# 11                                    pass                              NaN
# 18                                    pass                              NaN
# 23                                    pass                              NaN
# 35                                    pass                              NaN
# ...                                    ...                              ...
# 5060                                  pass                              NaN
# 5062                                  pass                              NaN
# 5066                                  pass                              NaN
# 5073                                  shot                              NaN
# 5075                                  shot                              NaN
#
#       associated_off_ball_run_subtype_id associated_off_ball_run_subtype  \
# 4                                    NaN                             NaN
# 11                                   NaN                             NaN
# 18                                   NaN                             NaN
# 23                                   NaN                             NaN
# 35                                   NaN                             NaN
# ...                                  ...                             ...
# 5060                                 NaN                             NaN
# 5062                                 NaN                             NaN
# 5066                                 NaN                             NaN
# 5073                                 NaN                             NaN
# 5075                                 NaN                             NaN
#
#       game_state_id game_state  team_score  opponent_team_score  phase_index  \
# 4                 3    drawing           0                    0            0
# 11                3    drawing           0                    0            1
# 18                3    drawing           0                    0            3
# 23                3    drawing           0                    0            4
# 35                3    drawing           0                    0            5
# ...             ...        ...         ...                  ...          ...
# 5060              1    winning           2                    0          451
# 5062              1    winning           2                    0          451
# 5066              1    winning           2                    0          451
# 5073              1    winning           2                    0          452
# 5075              1    winning           2                    0          452
#
#       player_possession_phase_index  \
# 4                               NaN
# 11                              NaN
# 18                              NaN
# 23                              NaN
# 35                              NaN
# ...                             ...
# 5060                            NaN
# 5062                            NaN
# 5066                            NaN
# 5073                            NaN
# 5075                            NaN
#
#      first_player_possession_in_team_possession  \
# 4                                           NaN
# 11                                          NaN
# 18                                          NaN
# 23                                          NaN
# 35                                          NaN
# ...                                         ...
# 5060                                        NaN
# 5062                                        NaN
# 5066                                        NaN
# 5073                                        NaN
# 5075                                        NaN
#
#      last_player_possession_in_team_possession lead_to_different_phase  \
# 4                                          NaN                     NaN
# 11                                         NaN                     NaN
# 18                                         NaN                     NaN
# 23                                         NaN                     NaN
# 35                                         NaN                     NaN
# ...                                        ...                     ...
# 5060                                       NaN                     NaN
# 5062                                       NaN                     NaN
# 5066                                       NaN                     NaN
# 5073                                       NaN                     NaN
# 5075                                       NaN                     NaN
#
#      issued_from_different_phase  n_player_possessions_in_phase  \
# 4                            NaN                            NaN
# 11                           NaN                            NaN
# 18                           NaN                            NaN
# 23                           NaN                            NaN
# 35                           NaN                            NaN
# ...                          ...                            ...
# 5060                         NaN                            NaN
# 5062                         NaN                            NaN
# 5066                         NaN                            NaN
# 5073                         NaN                            NaN
# 5075                         NaN                            NaN
#
#      team_possession_loss_in_phase  team_in_possession_phase_type_id  \
# 4                            False                                 1
# 11                            True                                 6
# 18                            True                                 1
# 23                            True                                 5
# 35                            True                                 2
# ...                            ...                               ...
# 5060                         False                                 2
# 5062                         False                                 2
# 5066                         False                                 2
# 5073                          True                                 2
# 5075                          True                                 2
#
#      team_in_possession_phase_type  team_out_of_possession_phase_type_id  \
# 4                           create                                     9
# 11                          direct                                    15
# 18                          create                                     9
# 23                         chaotic                                     5
# 35                          finish                                     8
# ...                            ...                                   ...
# 5060                        finish                                     8
# 5062                        finish                                     8
# 5066                        finish                                     8
# 5073                        finish                                     8
# 5075                        finish                                     8
#
#      team_out_of_possession_phase_type  \
# 4                         medium_block
# 11                    defending_direct
# 18                        medium_block
# 23                             chaotic
# 35                           low_block
# ...                                ...
# 5060                         low_block
# 5062                         low_block
# 5066                         low_block
# 5073                         low_block
# 5075                         low_block
#
#       current_team_in_possession_next_phase_type_id  \
# 4                                               NaN
# 11                                              NaN
# 18                                              NaN
# 23                                              NaN
# 35                                              NaN
# ...                                             ...
# 5060                                            NaN
# 5062                                            NaN
# 5066                                            NaN
# 5073                                            NaN
# 5075                                            NaN
#
#      current_team_in_possession_next_phase_type  \
# 4                                           NaN
# 11                                          NaN
# 18                                          NaN
# 23                                          NaN
# 35                                          NaN
# ...                                         ...
# 5060                                        NaN
# 5062                                        NaN
# 5066                                        NaN
# 5073                                        NaN
# 5075                                        NaN
#
#       current_team_out_of_possession_next_phase_type_id  \
# 4                                                   NaN
# 11                                                  NaN
# 18                                                  NaN
# 23                                                  NaN
# 35                                                  NaN
# ...                                                 ...
# 5060                                                NaN
# 5062                                                NaN
# 5066                                                NaN
# 5073                                                NaN
# 5075                                                NaN
#
#      current_team_out_of_possession_next_phase_type  \
# 4                                               NaN
# 11                                              NaN
# 18                                              NaN
# 23                                              NaN
# 35                                              NaN
# ...                                             ...
# 5060                                            NaN
# 5062                                            NaN
# 5066                                            NaN
# 5073                                            NaN
# 5075                                            NaN
#
#       current_team_in_possession_previous_phase_type_id  \
# 4                                                   NaN
# 11                                                  NaN
# 18                                                  NaN
# 23                                                  NaN
# 35                                                  NaN
# ...                                                 ...
# 5060                                                NaN
# 5062                                                NaN
# 5066                                                NaN
# 5073                                                NaN
# 5075                                                NaN
#
#      current_team_in_possession_previous_phase_type  \
# 4                                               NaN
# 11                                              NaN
# 18                                              NaN
# 23                                              NaN
# 35                                              NaN
# ...                                             ...
# 5060                                            NaN
# 5062                                            NaN
# 5066                                            NaN
# 5073                                            NaN
# 5075                                            NaN
#
#       current_team_out_of_possession_previous_phase_type_id  \
# 4                                                       NaN
# 11                                                      NaN
# 18                                                      NaN
# 23                                                      NaN
# 35                                                      NaN
# ...                                                     ...
# 5060                                                    NaN
# 5062                                                    NaN
# 5066                                                    NaN
# 5073                                                    NaN
# 5075                                                    NaN
#
#      current_team_out_of_possession_previous_phase_type  \
# 4                                                   NaN
# 11                                                  NaN
# 18                                                  NaN
# 23                                                  NaN
# 35                                                  NaN
# ...                                                 ...
# 5060                                                NaN
# 5062                                                NaN
# 5066                                                NaN
# 5073                                                NaN
# 5075                                                NaN
#
#       game_interruption_before_id game_interruption_before  \
# 4                             NaN                      NaN
# 11                            NaN                      NaN
# 18                            NaN                      NaN
# 23                            NaN                      NaN
# 35                            NaN                      NaN
# ...                           ...                      ...
# 5060                          NaN                      NaN
# 5062                          NaN                      NaN
# 5066                          NaN                      NaN
# 5073                          NaN                      NaN
# 5075                          NaN                      NaN
#
#       game_interruption_after_id game_interruption_after  lead_to_shot  \
# 4                            NaN                     NaN         False
# 11                           3.0           free_kick_for         False
# 18                           NaN                     NaN         False
# 23                           NaN                     NaN         False
# 35                           NaN                     NaN         False
# ...                          ...                     ...           ...
# 5060                         NaN                     NaN         False
# 5062                        12.0        throw_in_against         False
# 5066                        12.0        throw_in_against         False
# 5073                         NaN                     NaN          True
# 5075                         NaN                     NaN          True
#
#       lead_to_goal  distance_covered  trajectory_angle  \
# 4            False             14.45            -36.69
# 11           False             16.64           -121.37
# 18           False              8.04            -87.20
# 23           False             33.10              9.66
# 35           False              1.59             41.21
# ...            ...               ...               ...
# 5060         False              1.13             74.96
# 5062         False              8.04             88.05
# 5066         False              4.23            138.14
# 5073         False              8.79            -98.37
# 5075         False              0.18           -120.58
#
#       trajectory_direction_id trajectory_direction in_to_out out_to_in  \
# 4                         1.0              forward       NaN       NaN
# 11                        4.0        sideway_right       NaN       NaN
# 18                        4.0        sideway_right       NaN       NaN
# 23                        1.0              forward       NaN       NaN
# 35                        1.0              forward       NaN       NaN
# ...                       ...                  ...       ...       ...
# 5060                      3.0         sideway_left       NaN       NaN
# 5062                      3.0         sideway_left       NaN       NaN
# 5066                      2.0             backward       NaN       NaN
# 5073                      4.0        sideway_right       NaN       NaN
# 5075                      4.0        sideway_right       NaN       NaN
#
#       speed_avg  speed_avg_band_id speed_avg_band  separation_start  \
# 4         21.52                3.0            hsr               NaN
# 11        21.52                3.0            hsr               NaN
# 18        15.71                2.0        running               NaN
# 23        25.97                4.0      sprinting               NaN
# 35        14.45                1.0        jogging               NaN
# ...         ...                ...            ...               ...
# 5060      10.08                1.0        jogging               NaN
# 5062      15.49                2.0        running               NaN
# 5066      15.12                2.0        running               NaN
# 5073      17.37                2.0        running               NaN
# 5075       1.92                1.0        jogging               NaN
#
#       separation_end  separation_gain  last_defensive_line_x_start  \
# 4                NaN              NaN                       -18.94
# 11               NaN              NaN                       -19.07
# 18               NaN              NaN                        -9.84
# 23               NaN              NaN                       -25.41
# 35               NaN              NaN                       -39.73
# ...              ...              ...                          ...
# 5060             NaN              NaN                       -29.92
# 5062             NaN              NaN                       -30.61
# 5066             NaN              NaN                       -33.17
# 5073             NaN              NaN                       -31.75
# 5075             NaN              NaN                       -32.34
#
#       last_defensive_line_x_end  delta_to_last_defensive_line_start  \
# 4                        -19.11                               31.97
# 11                       -19.11                               35.10
# 18                       -12.15                               17.37
# 23                       -11.17                               29.65
# 35                       -39.24                                0.57
# ...                         ...                                 ...
# 5060                     -30.36                               11.79
# 5062                     -33.93                                2.61
# 5066                     -33.93                               11.14
# 5073                     -32.47                               13.51
# 5075                     -32.47                               10.61
#
#       delta_to_last_defensive_line_end  delta_to_last_defensive_line_gain  \
# 4                                33.09                               1.12
# 11                               30.08                              -5.02
# 18                               20.02                               2.65
# 23                               47.44                              17.79
# 35                                1.61                               1.04
# ...                                ...                                ...
# 5060                             12.47                               0.68
# 5062                              6.21                               3.60
# 5066                             10.70                              -0.44
# 5073                             13.64                               0.13
# 5075                             10.70                               0.09
#
#       last_defensive_line_height_start  last_defensive_line_height_end  \
# 4                                33.06                           32.89
# 11                               32.93                           32.89
# 18                               42.16                           39.85
# 23                               26.59                           40.83
# 35                               12.27                           12.76
# ...                                ...                             ...
# 5060                             22.08                           21.64
# 5062                             21.39                           18.07
# 5066                             18.83                           18.07
# 5073                             20.25                           19.53
# 5075                             19.66                           19.53
#
#       last_defensive_line_height_gain inside_defensive_shape_start  \
# 4                               -0.17                          NaN
# 11                              -0.04                          NaN
# 18                              -2.31                          NaN
# 23                              14.24                          NaN
# 35                               0.49                          NaN
# ...                               ...                          ...
# 5060                            -0.44                          NaN
# 5062                            -3.32                          NaN
# 5066                            -0.76                          NaN
# 5073                            -0.72                          NaN
# 5075                            -0.13                          NaN
#
#      inside_defensive_shape_end  start_type_id start_type  end_type_id  \
# 4                           NaN            NaN        NaN          NaN
# 11                          NaN            NaN        NaN         10.0
# 18                          NaN            NaN        NaN          8.0
# 23                          NaN            NaN        NaN          7.0
# 35                          NaN            NaN        NaN          NaN
# ...                         ...            ...        ...          ...
# 5060                        NaN            NaN        NaN          NaN
# 5062                        NaN            NaN        NaN          9.0
# 5066                        NaN            NaN        NaN         10.0
# 5073                        NaN            NaN        NaN          8.0
# 5075                        NaN            NaN        NaN          8.0
#
#                  end_type consecutive_on_ball_engagements one_touch  \
# 4                     NaN                           False       NaN
# 11    indirect_disruption                           False       NaN
# 18        indirect_regain                           False       NaN
# 23          direct_regain                           False       NaN
# 35                    NaN                           False       NaN
# ...                   ...                             ...       ...
# 5060                  NaN                           False       NaN
# 5062    direct_disruption                           False       NaN
# 5066  indirect_disruption                            True       NaN
# 5073      indirect_regain                           False       NaN
# 5075      indirect_regain                           False       NaN
#
#      quick_pass carry forward_momentum is_header hand_pass  \
# 4           NaN   NaN              NaN       NaN       NaN
# 11          NaN   NaN              NaN       NaN       NaN
# 18          NaN   NaN              NaN       NaN       NaN
# 23          NaN   NaN              NaN       NaN       NaN
# 35          NaN   NaN              NaN       NaN       NaN
# ...         ...   ...              ...       ...       ...
# 5060        NaN   NaN              NaN       NaN       NaN
# 5062        NaN   NaN              NaN       NaN       NaN
# 5066        NaN   NaN              NaN       NaN       NaN
# 5073        NaN   NaN              NaN       NaN       NaN
# 5075        NaN   NaN              NaN       NaN       NaN
#
#      initiate_give_and_go  pass_angle_received  pass_direction_received_id  \
# 4                     NaN                  NaN                         NaN
# 11                    NaN                  NaN                         NaN
# 18                    NaN                  NaN                         NaN
# 23                    NaN                  NaN                         NaN
# 35                    NaN                  NaN                         NaN
# ...                   ...                  ...                         ...
# 5060                  NaN                  NaN                         NaN
# 5062                  NaN                  NaN                         NaN
# 5066                  NaN                  NaN                         NaN
# 5073                  NaN                  NaN                         NaN
# 5075                  NaN                  NaN                         NaN
#
#      pass_direction_received  pass_distance_received  pass_range_received_id  \
# 4                        NaN                     NaN                     NaN
# 11                       NaN                     NaN                     NaN
# 18                       NaN                     NaN                     NaN
# 23                       NaN                     NaN                     NaN
# 35                       NaN                     NaN                     NaN
# ...                      ...                     ...                     ...
# 5060                     NaN                     NaN                     NaN
# 5062                     NaN                     NaN                     NaN
# 5066                     NaN                     NaN                     NaN
# 5073                     NaN                     NaN                     NaN
# 5075                     NaN                     NaN                     NaN
#
#      pass_range_received  pass_outcome_id pass_outcome  \
# 4                    NaN              NaN          NaN
# 11                   NaN              NaN          NaN
# 18                   NaN              NaN          NaN
# 23                   NaN              NaN          NaN
# 35                   NaN              NaN          NaN
# ...                  ...              ...          ...
# 5060                 NaN              NaN          NaN
# 5062                 NaN              NaN          NaN
# 5066                 NaN              NaN          NaN
# 5073                 NaN              NaN          NaN
# 5075                 NaN              NaN          NaN
#
#      targeted_passing_option_event_id high_pass  player_targeted_id  \
# 4                                 NaN       NaN             51649.0
# 11                                NaN       NaN            735578.0
# 18                                NaN       NaN            133498.0
# 23                                NaN       NaN             50983.0
# 35                                NaN       NaN            965685.0
# ...                               ...       ...                 ...
# 5060                              NaN       NaN            735574.0
# 5062                              NaN       NaN             50983.0
# 5066                              NaN       NaN             50983.0
# 5073                              NaN       NaN             51649.0
# 5075                              NaN       NaN             51649.0
#
#      player_targeted_name  player_targeted_position_id  \
# 4              A. Šušnjar                          4.0
# 11               M. Natta                          2.0
# 18            F. De Vries                          2.0
# 23              D. Ingham                          8.0
# 35             L. Gillion                         16.0
# ...                   ...                          ...
# 5060            K. Grozos                         11.0
# 5062            D. Ingham                          8.0
# 5066            D. Ingham                          8.0
# 5073           A. Šušnjar                          4.0
# 5075           A. Šušnjar                          4.0
#
#      player_targeted_position  player_targeted_x_pass  player_targeted_y_pass  \
# 4                         LCB                     NaN                     NaN
# 11                         LB                     NaN                     NaN
# 18                         LB                     NaN                     NaN
# 23                         RB                     NaN                     NaN
# 35                         LW                     NaN                     NaN
# ...                       ...                     ...                     ...
# 5060                      RDM                     NaN                     NaN
# 5062                       RB                     NaN                     NaN
# 5066                       RB                     NaN                     NaN
# 5073                      LCB                     NaN                     NaN
# 5075                      LCB                     NaN                     NaN
#
#       player_targeted_channel_pass_id player_targeted_channel_pass  \
# 4                                 NaN                          NaN
# 11                                NaN                          NaN
# 18                                NaN                          NaN
# 23                                NaN                          NaN
# 35                                NaN                          NaN
# ...                               ...                          ...
# 5060                              NaN                          NaN
# 5062                              NaN                          NaN
# 5066                              NaN                          NaN
# 5073                              NaN                          NaN
# 5075                              NaN                          NaN
#
#       player_targeted_third_pass_id player_targeted_third_pass  \
# 4                               NaN                        NaN
# 11                              NaN                        NaN
# 18                              NaN                        NaN
# 23                              NaN                        NaN
# 35                              NaN                        NaN
# ...                             ...                        ...
# 5060                            NaN                        NaN
# 5062                            NaN                        NaN
# 5066                            NaN                        NaN
# 5073                            NaN                        NaN
# 5075                            NaN                        NaN
#
#      player_targeted_penalty_area_pass  player_targeted_x_reception  \
# 4                                  NaN                          NaN
# 11                                 NaN                          NaN
# 18                                 NaN                          NaN
# 23                                 NaN                          NaN
# 35                                 NaN                          NaN
# ...                                ...                          ...
# 5060                               NaN                          NaN
# 5062                               NaN                          NaN
# 5066                               NaN                          NaN
# 5073                               NaN                          NaN
# 5075                               NaN                          NaN
#
#       player_targeted_y_reception  player_targeted_channel_reception_id  \
# 4                             NaN                                   NaN
# 11                            NaN                                   NaN
# 18                            NaN                                   NaN
# 23                            NaN                                   NaN
# 35                            NaN                                   NaN
# ...                           ...                                   ...
# 5060                          NaN                                   NaN
# 5062                          NaN                                   NaN
# 5066                          NaN                                   NaN
# 5073                          NaN                                   NaN
# 5075                          NaN                                   NaN
#
#      player_targeted_channel_reception  player_targeted_third_reception_id  \
# 4                                  NaN                                 NaN
# 11                                 NaN                                 NaN
# 18                                 NaN                                 NaN
# 23                                 NaN                                 NaN
# 35                                 NaN                                 NaN
# ...                                ...                                 ...
# 5060                               NaN                                 NaN
# 5062                               NaN                                 NaN
# 5066                               NaN                                 NaN
# 5073                               NaN                                 NaN
# 5075                               NaN                                 NaN
#
#      player_targeted_third_reception player_targeted_penalty_area_reception  \
# 4                                NaN                                    NaN
# 11                               NaN                                    NaN
# 18                               NaN                                    NaN
# 23                               NaN                                    NaN
# 35                               NaN                                    NaN
# ...                              ...                                    ...
# 5060                             NaN                                    NaN
# 5062                             NaN                                    NaN
# 5066                             NaN                                    NaN
# 5073                             NaN                                    NaN
# 5075                             NaN                                    NaN
#
#       player_targeted_distance_to_goal_start  \
# 4                                      74.24
# 11                                     71.93
# 18                                     69.93
# 23                                     65.29
# 35                                     33.02
# ...                                      ...
# 5060                                   47.23
# 5062                                   41.63
# 5066                                   41.91
# 5073                                   38.66
# 5075                                   35.51
#
#       player_targeted_distance_to_goal_end  \
# 4                                    74.26
# 11                                   67.25
# 18                                   69.06
# 23                                   94.35
# 35                                   32.47
# ...                                    ...
# 5060                                 46.99
# 5062                                 41.61
# 5066                                 41.61
# 5073                                 35.05
# 5075                                 35.05
#
#       player_targeted_angle_to_goal_start  player_targeted_angle_to_goal_end  \
# 4                                  178.20                             177.92
# 11                                 163.32                             158.93
# 18                                 153.34                             152.10
# 23                                -159.45                            -162.17
# 35                                 116.11                             118.55
# ...                                   ...                                ...
# 5060                              -147.60                            -147.21
# 5062                              -128.15                            -128.58
# 5066                              -128.43                            -128.58
# 5073                              -178.30                             177.58
# 5075                               178.08                             177.58
#
#       player_targeted_average_speed  player_targeted_speed_avg_band_id  \
# 4                              3.77                                1.0
# 11                            13.94                                1.0
# ...
# 23                    NaN                     NaN
# 35                    NaN                     NaN
# ...                   ...                     ...
# 5060                  NaN                     NaN
# 5062                  NaN                     NaN
# 5066                  NaN                     NaN
# 5073                  NaN                     NaN
# 5075                  NaN                     NaN
#
#       n_simultaneous_passing_options passing_option_at_pass_moment  \
# 4                                NaN                           NaN
# 11                               NaN                           NaN
# 18                               NaN                           NaN
# 23                               NaN                           NaN
# 35                               NaN                           NaN
# ...                              ...                           ...
# 5060                             NaN                           NaN
# 5062                             NaN                           NaN
# 5066                             NaN                           NaN
# 5073                             NaN                           NaN
# 5075                             NaN                           NaN
#
#       n_opponents_ahead_end  n_opponents_ahead_start  n_opponents_overtaken  \
# 4                       NaN                      NaN                    NaN
# 11                      NaN                      NaN                    NaN
# 18                      NaN                      NaN                    NaN
# 23                      NaN                      NaN                    NaN
# 35                      NaN                      NaN                    NaN
# ...                     ...                      ...                    ...
# 5060                    NaN                      NaN                    NaN
# 5062                    NaN                      NaN                    NaN
# 5066                    NaN                      NaN                    NaN
# 5073                    NaN                      NaN                    NaN
# 5075                    NaN                      NaN                    NaN
#
#      pressing_chain  pressing_chain_length  pressing_chain_end_type_id  \
# 4              True                    2.0                         2.0
# 11             True                    2.0                         2.0
# 18            False                    NaN                         NaN
# 23            False                    NaN                         NaN
# 35            False                    NaN                         NaN
# ...             ...                    ...                         ...
# 5060          False                    NaN                         NaN
# 5062          False                    NaN                         NaN
# 5066          False                    NaN                         NaN
# 5073          False                    NaN                         NaN
# 5075          False                    NaN                         NaN
#
#      pressing_chain_end_type  pressing_chain_index  index_in_pressing_chain  \
# 4                 disruption                   0.0                      1.0
# 11                disruption                   0.0                      2.0
# 18                       NaN                   NaN                      NaN
# 23                       NaN                   NaN                      NaN
# 35                       NaN                   NaN                      NaN
# ...                      ...                   ...                      ...
# 5060                     NaN                   NaN                      NaN
# 5062                     NaN                   NaN                      NaN
# 5066                     NaN                   NaN                      NaN
# 5073                     NaN                   NaN                      NaN
# 5075                     NaN                   NaN                      NaN
#
#      simultaneous_defensive_engagement_same_target  \
# 4                                            False
# 11                                           False
# 18                                           False
# 23                                           False
# 35                                           False
# ...                                            ...
# 5060                                         False
# 5062                                          True
# 5066                                          True
# 5073                                          True
# 5075                                          True
#
#       simultaneous_defensive_engagement_same_target_rank  \
# 4                                                    NaN
# 11                                                   NaN
# 18                                                   NaN
# 23                                                   NaN
# 35                                                   NaN
# ...                                                  ...
# 5060                                                 NaN
# 5062                                                 1.0
# 5066                                                 2.0
# 5073                                                 1.0
# 5075                                                 2.0
#
#      affected_line_breaking_passing_option_id  affected_line_break_id  \
# 4                                         NaN                     NaN
# 11                                        NaN                     NaN
# 18                                       7_10                     2.0
# 23                                        NaN                     NaN
# 35                                        NaN                     NaN
# ...                                       ...                     ...
# 5060                                      NaN                     NaN
# 5062                                   7_2535                     3.0
# 5066                                      NaN                     NaN
# 5073                                      NaN                     NaN
# 5075                                      NaN                     NaN
#
#      affected_line_break affected_line_breaking_passing_option_attempted  \
# 4                    NaN                                             NaN
# 11                   NaN                                             NaN
# 18           second_last                                            True
# 23                   NaN                                             NaN
# 35                   NaN                                             NaN
# ...                  ...                                             ...
# 5060                 NaN                                             NaN
# 5062                last                                            True
# 5066                 NaN                                             NaN
# 5073                 NaN                                             NaN
# 5075                 NaN                                             NaN
#
#       affected_line_breaking_passing_option_xthreat  \
# 4                                               NaN
# 11                                              NaN
# 18                                           0.0065
# 23                                              NaN
# 35                                              NaN
# ...                                             ...
# 5060                                            NaN
# 5062                                         0.0103
# 5066                                            NaN
# 5073                                            NaN
# 5075                                            NaN
#
#      affected_line_breaking_passing_option_dangerous  \
# 4                                                NaN
# 11                                               NaN
# 18                                             False
# 23                                               NaN
# 35                                               NaN
# ...                                              ...
# 5060                                             NaN
# 5062                                           False
# 5066                                             NaN
# 5073                                             NaN
# 5075                                             NaN
#
#       affected_line_breaking_passing_option_run_subtype_id  \
# 4                                                      NaN
# 11                                                     NaN
# 18                                                     NaN
# 23                                                     NaN
# 35                                                     NaN
# ...                                                    ...
# 5060                                                   NaN
# 5062                                                  10.0
# 5066                                                   NaN
# 5073                                                   NaN
# 5075                                                   NaN
#
#      affected_line_breaking_passing_option_run_subtype possession_danger  \
# 4                                                  NaN             False
# 11                                                 NaN             False
# 18                                                 NaN             False
# 23                                                 NaN             False
# 35                                                 NaN             False
# ...                                                ...               ...
# 5060                                               NaN             False
# 5062                                          underlap             False
# 5066                                               NaN             False
# 5073                                               NaN              True
# 5075                                               NaN              True
#
#      beaten_by_possession beaten_by_movement stop_possession_danger  \
# 4                   False              False                  False
# 11                  False              False                  False
# 18                  False              False                  False
# 23                  False              False                  False
# 35                  False              False                  False
# ...                   ...                ...                    ...
# 5060                False              False                  False
# 5062                False              False                  False
# 5066                False              False                  False
# 5073                 True              False                  False
# 5075                False              False                  False
#
#      reduce_possession_danger force_backward  xloss_player_possession_start  \
# 4                       False          False                            NaN
# 11                      False          False                          0.288
# 18                      False          False                          0.321
# 23                      False          False                          0.333
# 35                      False          False                          0.455
# ...                       ...            ...                            ...
# 5060                    False          False                          0.129
# 5062                    False          False                          0.251
# 5066                    False          False                          0.251
# 5073                    False          False                          0.071
# 5075                    False          False                          0.071
#
#       xloss_player_possession_end  xloss_player_possession_max  \
# 4                             NaN                          NaN
# 11                          0.392                        0.392
# 18                          0.393                        0.403
# 23                          0.479                        0.485
# 35                          0.402                        0.455
# ...                           ...                          ...
# 5060                        0.102                        0.133
# 5062                        0.189                        0.295
# 5066                        0.189                        0.295
# 5073                        0.402                        0.402
# 5075                        0.402                        0.402
#
#       xshot_player_possession_start  xshot_player_possession_end  \
# 4                               NaN                          NaN
# 11                            0.003                        0.000
# 18                            0.000                        0.001
# 23                            0.000                        0.000
# 35                            0.010                        0.004
# ...                             ...                          ...
# 5060                          0.001                        0.000
# 5062                          0.003                        0.000
# 5066                          0.003                        0.000
# 5073                          0.004                        0.231
# 5075                          0.004                        0.231
#
#       xshot_player_possession_max  is_player_possession_start_matched  \
# 4                             NaN                                True
# 11                          0.004                                True
# 18                          0.007                                True
# 23                          0.000                                True
# 35                          0.015                                True
# ...                           ...                                 ...
# 5060                        0.001                                True
# 5062                        0.005                                True
# 5066                        0.005                                True
# 5073                        0.402                                True
# 5075                        0.402                                True
#
#       is_player_possession_end_matched is_previous_pass_matched  \
# 4                                 True                     True
# 11                                True                     True
# 18                                True                     True
# 23                                True                     True
# 35                                True                     True
# ...                                ...                      ...
# 5060                              True                     True
# 5062                              True                     True
# 5066                              True                     True
# 5073                              True                     True
# 5075                              True                     True
#
#      is_pass_reception_matched fully_extrapolated
# 4                         True                NaN
# 11                        True                NaN
# 18                        True                NaN
# 23                        True                NaN
# 35                        True                NaN
# ...                        ...                ...
# 5060                      True                NaN
# 5062                      True                NaN
# 5066                      True                NaN
# 5073                       NaN                NaN
# 5075                       NaN                NaN
#
# [937 rows x 294 columns]

# %%
de_match[de_match['player_in_possession_id']==735578]
# Out:
#      event_id  index  match_id  frame_start  frame_end  frame_physical_start  \
# 6         7_2      6   1886347           72         82                   NaN
# 7         7_3      7   1886347           72         89                   NaN
# 8         7_4      8   1886347           72         89                   NaN
# 9         7_5      9   1886347           73         89                   NaN
# 10        1_0     10   1886347           74         90                   NaN
# ...       ...    ...       ...          ...        ...                   ...
# 4883   7_2444   4883   1886347        57055      57059                   NaN
# 4967    9_917   4967   1886347        58002      58011               58002.0
# 5004   7_2505   5004   1886347        58262      58277                   NaN
# 5005    1_594   5005   1886347        58269      58284                   NaN
# 5006   7_2506   5006   1886347        58270      58277                   NaN
#
#      time_start time_end  minute_start  second_start  duration  period  \
# 6       00:06.2  00:07.2             0             6       1.0       1
# 7       00:06.2  00:07.9             0             6       1.7       1
# 8       00:06.2  00:07.9             0             6       1.7       1
# 9       00:06.3  00:07.9             0             6       1.6       1
# 10      00:06.4  00:08.0             0             6       1.6       1
# ...         ...      ...           ...           ...       ...     ...
# 4883    93:45.5  93:45.9            93            45       0.4       2
# 4967    95:20.2  95:21.1            95            20       0.9       2
# 5004    95:46.2  95:47.7            95            46       1.5       2
# 5005    95:46.9  95:48.4            95            46       1.5       2
# 5006    95:47.0  95:47.7            95            47       0.7       2
#
#       attacking_side_id attacking_side  event_type_id          event_type  \
# 6                     1  left_to_right              7      passing_option
# 7                     1  left_to_right              7      passing_option
# 8                     1  left_to_right              7      passing_option
# 9                     1  left_to_right              7      passing_option
# 10                    1  left_to_right              1        off_ball_run
# ...                 ...            ...            ...                 ...
# 4883                  2  right_to_left              7      passing_option
# 4967                  1  left_to_right              9  on_ball_engagement
# 5004                  2  right_to_left              7      passing_option
# 5005                  2  right_to_left              1        off_ball_run
# 5006                  2  right_to_left              7      passing_option
#
#       event_subtype_id          event_subtype  player_id   player_name  \
# 6                  NaN                    NaN      50978    C. Timmins
# 7                  NaN                    NaN     795507    L. Bayliss
# 8                  NaN                    NaN     966120     B. Gibson
# 9                  NaN                    NaN     735573   T. Aquilina
# 10                 7.0           pulling_wide     735573   T. Aquilina
# ...                ...                    ...        ...           ...
# 4883               NaN                    NaN     735573   T. Aquilina
# 4967              15.0                  other      43829     N. Moreno
# 5004               NaN                    NaN     795506     C. Taylor
# 5005               8.0  run_ahead_of_the_ball     560992  D. Wilmering
# 5006               NaN                    NaN     560992  D. Wilmering
#
#       player_position_id player_position  player_in_possession_id  \
# 6                      9             LDM                 735578.0
# 7                     15              AM                 735578.0
# 8                     19              CF                 735578.0
# 9                     16              LW                 735578.0
# 10                    16              LW                 735578.0
# ...                  ...             ...                      ...
# 4883                  16              LW                 735578.0
# 4967                  17              RW                 735578.0
# 5004                  19              CF                 735578.0
# 5005                  15              AM                 735578.0
# 5006                  15              AM                 735578.0
#
#      player_in_possession_name  player_in_possession_position_id  \
# 6                     M. Natta                               2.0
# 7                     M. Natta                               2.0
# 8                     M. Natta                               2.0
# 9                     M. Natta                               2.0
# 10                    M. Natta                               2.0
# ...                        ...                               ...
# 4883                  M. Natta                               2.0
# 4967                  M. Natta                               2.0
# 5004                  M. Natta                               2.0
# 5005                  M. Natta                               2.0
# 5006                  M. Natta                               2.0
#
#      player_in_possession_position  team_id team_shortname  x_start  y_start  \
# 6                               LB     1805      Newcastle    -4.66    11.04
# 7                               LB     1805      Newcastle    14.93    10.13
# 8                               LB     1805      Newcastle    12.73     3.61
# 9                               LB     1805      Newcastle     7.31    19.98
# 10                              LB     1805      Newcastle     7.31    20.40
# ...                            ...      ...            ...      ...      ...
# 4883                            LB     1805      Newcastle   -22.76     7.22
# 4967                            LB     4177    Auckland FC    15.81   -27.45
# 5004                            LB     1805      Newcastle    14.01    32.20
# 5005                            LB     1805      Newcastle    16.35    17.33
# 5006                            LB     1805      Newcastle    16.73    17.54
#
#       channel_id_start    channel_start  third_id_start      third_start  \
# 6                    2  half_space_left               2     middle_third
# 7                    2  half_space_left               2     middle_third
# 8                    3           center               2     middle_third
# 9                    2  half_space_left               2     middle_third
# 10                   1        wide_left               2     middle_third
# ...                ...              ...             ...              ...
# 4883                 3           center               1  defensive_third
# 4967                 5       wide_right               2     middle_third
# 5004                 1        wide_left               2     middle_third
# 5005                 2  half_space_left               2     middle_third
# 5006                 2  half_space_left               2     middle_third
#
#       penalty_area_start  x_end  y_end  channel_id_end      channel_end  \
# 6                  False  -6.39  14.27               2  half_space_left
# 7                  False  11.67  16.14               2  half_space_left
# 8                  False  16.91   9.27               2  half_space_left
# 9                  False   6.87  27.64               1        wide_left
# 10                 False   6.94  28.05               1        wide_left
# ...                  ...    ...    ...             ...              ...
# 4883               False -21.65   7.96               3           center
# 4967               False  16.59 -28.15               5       wide_right
# 5004               False  15.79  33.38               1        wide_left
# 5005               False  22.92  19.72               2  half_space_left
# 5006               False  19.93  18.66               2  half_space_left
#
#       third_id_end        third_end  penalty_area_end  \
# 6                2     middle_third             False
# 7                2     middle_third             False
# 8                2     middle_third             False
# 9                2     middle_third             False
# 10               2     middle_third             False
# ...            ...              ...               ...
# 4883             1  defensive_third             False
# 4967             2     middle_third             False
# 5004             2     middle_third             False
# 5005             3  attacking_third             False
# 5006             3  attacking_third             False
#
#      associated_player_possession_event_id  \
# 6                                      8_2
# 7                                      8_2
# 8                                      8_2
# 9                                      8_2
# 10                                     8_2
# ...                                    ...
# 4883                                 8_957
# 4967                                 8_974
# 5004                                 8_984
# 5005                                 8_984
# 5006                                 8_984
#
#       associated_player_possession_frame_start  \
# 6                                         72.0
# 7                                         72.0
# 8                                         72.0
# 9                                         72.0
# 10                                        72.0
# ...                                        ...
# 4883                                   57045.0
# 4967                                   58004.0
# 5004                                   58262.0
# 5005                                   58262.0
# 5006                                   58262.0
#
#       associated_player_possession_frame_end  \
# 6                                        NaN
# 7                                        NaN
# 8                                        NaN
# 9                                        NaN
# 10                                       NaN
# ...                                      ...
# 4883                                     NaN
# 4967                                 58011.0
# 5004                                     NaN
# 5005                                     NaN
# 5006                                     NaN
#
#       associated_player_possession_end_type_id  \
# 6                                          NaN
# 7                                          NaN
# 8                                          NaN
# 9                                          NaN
# 10                                         NaN
# ...                                        ...
# 4883                                       NaN
# 4967                                       5.0
# 5004                                       NaN
# 5005                                       NaN
# 5006                                       NaN
#
#      associated_player_possession_end_type associated_off_ball_run_event_id  \
# 6                                      NaN                              NaN
# 7                                      NaN                              1_1
# 8                                      NaN                              1_2
# 9                                      NaN                              1_0
# 10                                     NaN                              NaN
# ...                                    ...                              ...
# 4883                                   NaN                              NaN
# 4967                       possession_loss                              NaN
# 5004                                   NaN                              NaN
# 5005                                   NaN                              NaN
# 5006                                   NaN                            1_594
#
#       associated_off_ball_run_subtype_id associated_off_ball_run_subtype  \
# 6                                    NaN                             NaN
# 7                                    2.0                    coming_short
# 8                                    1.0                          behind
# 9                                    7.0                    pulling_wide
# 10                                   NaN                             NaN
# ...                                  ...                             ...
# 4883                                 NaN                             NaN
# 4967                                 NaN                             NaN
# 5004                                 NaN                             NaN
# 5005                                 NaN                             NaN
# 5006                                 8.0           run_ahead_of_the_ball
#
#       game_state_id game_state  team_score  opponent_team_score  phase_index  \
# 6                 3    drawing           0                    0            1
# 7                 3    drawing           0                    0            1
# 8                 3    drawing           0                    0            1
# 9                 3    drawing           0                    0            1
# 10                3    drawing           0                    0            1
# ...             ...        ...         ...                  ...          ...
# 4883              2     losing           0                    2          435
# 4967              1    winning           2                    0          448
# 5004              2     losing           0                    2          448
# 5005              2     losing           0                    2          448
# 5006              2     losing           0                    2          448
#
#       player_possession_phase_index  \
# 6                               NaN
# 7                               NaN
# 8                               NaN
# 9                               NaN
# 10                              NaN
# ...                             ...
# 4883                            NaN
# 4967                            NaN
# 5004                            NaN
# 5005                            NaN
# 5006                            NaN
#
#      first_player_possession_in_team_possession  \
# 6                                           NaN
# 7                                           NaN
# 8                                           NaN
# 9                                           NaN
# 10                                          NaN
# ...                                         ...
# 4883                                        NaN
# 4967                                        NaN
# 5004                                        NaN
# 5005                                        NaN
# 5006                                        NaN
#
#      last_player_possession_in_team_possession lead_to_different_phase  \
# 6                                          NaN                     NaN
# 7                                          NaN                     NaN
# 8                                          NaN                     NaN
# 9                                          NaN                     NaN
# 10                                         NaN                     NaN
# ...                                        ...                     ...
# 4883                                       NaN                     NaN
# 4967                                       NaN                     NaN
# 5004                                       NaN                     NaN
# 5005                                       NaN                     NaN
# 5006                                       NaN                     NaN
#
#      issued_from_different_phase  n_player_possessions_in_phase  \
# 6                            NaN                            NaN
# 7                            NaN                            NaN
# 8                            NaN                            NaN
# 9                            NaN                            NaN
# 10                           NaN                            NaN
# ...                          ...                            ...
# 4883                         NaN                            NaN
# 4967                         NaN                            NaN
# 5004                         NaN                            NaN
# 5005                         NaN                            NaN
# 5006                         NaN                            NaN
#
#      team_possession_loss_in_phase  team_in_possession_phase_type_id  \
# 6                              NaN                                 6
# 7                              NaN                                 6
# 8                              NaN                                 6
# 9                              NaN                                 6
# 10                             NaN                                 6
# ...                            ...                               ...
# 4883                           NaN                                 0
# 4967                         False                                 1
# 5004                           NaN                                 1
# 5005                           NaN                                 1
# 5006                           NaN                                 1
#
#      team_in_possession_phase_type  team_out_of_possession_phase_type_id  \
# 6                           direct                                    15
# 7                           direct                                    15
# 8                           direct                                    15
# 9                           direct                                    15
# 10                          direct                                    15
# ...                            ...                                   ...
# 4883                      build_up                                    10
# 4967                        create                                     9
# 5004                        create                                     9
# 5005                        create                                     9
# 5006                        create                                     9
#
#      team_out_of_possession_phase_type  \
# 6                     defending_direct
# 7                     defending_direct
# 8                     defending_direct
# 9                     defending_direct
# 10                    defending_direct
# ...                                ...
# 4883                        high_block
# 4967                      medium_block
# 5004                      medium_block
# 5005                      medium_block
# 5006                      medium_block
#
#       current_team_in_possession_next_phase_type_id  \
# 6                                               NaN
# 7                                               NaN
# 8                                               NaN
# 9                                               NaN
# 10                                              NaN
# ...                                             ...
# 4883                                            NaN
# 4967                                            NaN
# 5004                                            NaN
# 5005                                            NaN
# 5006                                            NaN
#
#      current_team_in_possession_next_phase_type  \
# 6                                           NaN
# 7                                           NaN
# 8                                           NaN
# 9                                           NaN
# 10                                          NaN
# ...                                         ...
# 4883                                        NaN
# 4967                                        NaN
# 5004                                        NaN
# 5005                                        NaN
# 5006                                        NaN
#
#       current_team_out_of_possession_next_phase_type_id  \
# 6                                                   NaN
# 7                                                   NaN
# 8                                                   NaN
# 9                                                   NaN
# 10                                                  NaN
# ...                                                 ...
# 4883                                                NaN
# 4967                                                NaN
# 5004                                                NaN
# 5005                                                NaN
# 5006                                                NaN
#
#      current_team_out_of_possession_next_phase_type  \
# 6                                               NaN
# 7                                               NaN
# 8                                               NaN
# 9                                               NaN
# 10                                              NaN
# ...                                             ...
# 4883                                            NaN
# 4967                                            NaN
# 5004                                            NaN
# 5005                                            NaN
# 5006                                            NaN
#
#       current_team_in_possession_previous_phase_type_id  \
# 6                                                   NaN
# 7                                                   NaN
# 8                                                   NaN
# 9                                                   NaN
# 10                                                  NaN
# ...                                                 ...
# 4883                                                NaN
# 4967                                                NaN
# 5004                                                NaN
# 5005                                                NaN
# 5006                                                NaN
#
#      current_team_in_possession_previous_phase_type  \
# 6                                               NaN
# 7                                               NaN
# 8                                               NaN
# 9                                               NaN
# 10                                              NaN
# ...                                             ...
# 4883                                            NaN
# 4967                                            NaN
# 5004                                            NaN
# 5005                                            NaN
# 5006                                            NaN
#
#       current_team_out_of_possession_previous_phase_type_id  \
# 6                                                       NaN
# 7                                                       NaN
# 8                                                       NaN
# 9                                                       NaN
# 10                                                      NaN
# ...                                                     ...
# 4883                                                    NaN
# 4967                                                    NaN
# 5004                                                    NaN
# 5005                                                    NaN
# 5006                                                    NaN
#
#      current_team_out_of_possession_previous_phase_type  \
# 6                                                   NaN
# 7                                                   NaN
# 8                                                   NaN
# 9                                                   NaN
# 10                                                  NaN
# ...                                                 ...
# 4883                                                NaN
# 4967                                                NaN
# 5004                                                NaN
# 5005                                                NaN
# 5006                                                NaN
#
#       game_interruption_before_id game_interruption_before  \
# 6                             NaN                      NaN
# 7                             NaN                      NaN
# 8                             NaN                      NaN
# 9                             NaN                      NaN
# 10                            NaN                      NaN
# ...                           ...                      ...
# 4883                          NaN                      NaN
# 4967                          NaN                      NaN
# 5004                          NaN                      NaN
# 5005                          NaN                      NaN
# 5006                          NaN                      NaN
#
#       game_interruption_after_id game_interruption_after  lead_to_shot  \
# 6                            NaN                     NaN         False
# 7                            NaN                     NaN         False
# 8                            NaN                     NaN         False
# 9                            NaN                     NaN         False
# 10                           NaN                     NaN         False
# ...                          ...                     ...           ...
# 4883                         NaN                     NaN         False
# 4967                         NaN                     NaN         False
# 5004                         NaN                     NaN         False
# 5005                         NaN                     NaN         False
# 5006                         NaN                     NaN         False
#
#       lead_to_goal  distance_covered  trajectory_angle  \
# 6            False              3.68            118.17
# 7            False              6.57            118.48
# 8            False              6.67             53.55
# 9            False              7.69             93.29
# 10           False              7.69             92.77
# ...            ...               ...               ...
# 4883         False              1.28             32.23
# 4967         False              1.27            -41.91
# 5004         False              2.25             33.54
# 5005         False              6.60             19.99
# 5006         False              2.90             19.29
#
#       trajectory_direction_id trajectory_direction in_to_out out_to_in  \
# 6                         3.0         sideway_left     False     False
# 7                         3.0         sideway_left     False     False
# 8                         3.0         sideway_left      True     False
# 9                         3.0         sideway_left      True     False
# 10                        3.0         sideway_left     False     False
# ...                       ...                  ...       ...       ...
# 4883                      1.0              forward     False     False
# 4967                      1.0              forward       NaN       NaN
# 5004                      1.0              forward     False     False
# 5005                      1.0              forward     False     False
# 5006                      1.0              forward     False     False
#
#       speed_avg  speed_avg_band_id speed_avg_band  separation_start  \
# 6         13.16                1.0        jogging              8.18
# 7         15.15                2.0        running              5.74
# 8         15.21                2.0        running              4.40
# 9         17.16                2.0        running              5.52
# 10        17.13                2.0        running              5.75
# ...         ...                ...            ...               ...
# 4883      11.76                1.0        jogging              3.43
# 4967       5.84                1.0        jogging               NaN
# 5004       5.81                1.0        jogging             12.25
# 5005      16.68                2.0        running              4.73
# 5006      17.36                2.0        running              4.64
#
#       separation_end  separation_gain  last_defensive_line_x_start  \
# 6               7.15            -1.03                        19.02
# 7               6.90             1.16                        19.02
# 8               3.30            -1.10                        19.02
# 9               5.86             0.34                        19.05
# 10              5.74            -0.01                        19.07
# ...              ...              ...                          ...
# 4883            3.14            -0.29                        -3.03
# 4967             NaN              NaN                        -2.86
# 5004            3.99            -8.26                        19.04
# 5005            3.28            -1.45                        21.01
# 5006            3.85            -0.79                        21.29
#
#       last_defensive_line_x_end  delta_to_last_defensive_line_start  \
# 6                         18.91                               23.68
# 7                         19.11                                4.09
# 8                         19.11                                6.29
# 9                         19.11                               11.74
# 10                        19.22                               11.76
# ...                         ...                                 ...
# 4883                      -2.27                               19.73
# 4967                      -3.00                               18.67
# 5004                      23.09                                5.03
# 5005                      24.49                                4.66
# 5006                      23.09                                4.56
#
#       delta_to_last_defensive_line_end  delta_to_last_defensive_line_gain  \
# 6                                25.30                               1.62
# 7                                 7.44                               3.35
# 8                                 2.20                              -4.09
# 9                                12.24                               0.50
# 10                               12.28                               0.52
# ...                                ...                                ...
# 4883                             19.38                              -0.35
# 4967                             19.59                               0.92
# 5004                              7.30                               2.27
# 5005                              1.57                              -3.09
# 5006                              3.16                              -1.40
#
#       last_defensive_line_height_start  last_defensive_line_height_end  \
# 6                                32.98                           33.09
# 7                                32.98                           32.89
# 8                                32.98                           32.89
# 9                                32.95                           32.89
# 10                               32.93                           32.78
# ...                                ...                             ...
# 4883                             55.03                           54.27
# 4967                             49.14                           49.00
# 5004                             32.96                           28.91
# 5005                             30.99                           27.51
# 5006                             30.71                           28.91
#
#       last_defensive_line_height_gain inside_defensive_shape_start  \
# 6                                0.11                         True
# 7                               -0.09                         True
# 8                               -0.09                         True
# 9                               -0.06                        False
# 10                              -0.15                        False
# ...                               ...                          ...
# 4883                            -0.76                         True
# 4967                            -0.14                          NaN
# 5004                            -4.05                        False
# 5005                            -3.48                         True
# 5006                            -1.80                         True
#
#      inside_defensive_shape_end  start_type_id start_type  end_type_id  \
# 6                          True            NaN        NaN          NaN
# 7                          True            NaN        NaN          NaN
# 8                          True            NaN        NaN          NaN
# 9                         False            NaN        NaN          NaN
# 10                        False            NaN        NaN          NaN
# ...                         ...            ...        ...          ...
# 4883                       True            NaN        NaN          NaN
# 4967                        NaN            NaN        NaN          NaN
# 5004                      False            NaN        NaN          NaN
# 5005                      False            NaN        NaN          NaN
# 5006                       True            NaN        NaN          NaN
#
#      end_type consecutive_on_ball_engagements one_touch quick_pass carry  \
# 6         NaN                             NaN       NaN        NaN   NaN
# 7         NaN                             NaN       NaN        NaN   NaN
# 8         NaN                             NaN       NaN        NaN   NaN
# 9         NaN                             NaN       NaN        NaN   NaN
# 10        NaN                             NaN       NaN        NaN   NaN
# ...       ...                             ...       ...        ...   ...
# 4883      NaN                             NaN       NaN        NaN   NaN
# 4967      NaN                           False       NaN        NaN   NaN
# 5004      NaN                             NaN       NaN        NaN   NaN
# 5005      NaN                             NaN       NaN        NaN   NaN
# 5006      NaN                             NaN       NaN        NaN   NaN
#
#      forward_momentum is_header hand_pass initiate_give_and_go  \
# 6                 NaN       NaN       NaN                  NaN
# 7                 NaN       NaN       NaN                  NaN
# 8                 NaN       NaN       NaN                  NaN
# 9                 NaN       NaN       NaN                  NaN
# 10                NaN       NaN       NaN                  NaN
# ...               ...       ...       ...                  ...
# 4883              NaN       NaN       NaN                  NaN
# 4967              NaN       NaN       NaN                  NaN
# 5004              NaN       NaN       NaN                  NaN
# 5005              NaN       NaN       NaN                  NaN
# 5006              NaN       NaN       NaN                  NaN
#
#       pass_angle_received  pass_direction_received_id pass_direction_received  \
# 6                     NaN                         NaN                     NaN
# 7                     NaN                         NaN                     NaN
# 8                     NaN                         NaN                     NaN
# 9                     NaN                         NaN                     NaN
# 10                    NaN                         NaN                     NaN
# ...                   ...                         ...                     ...
# 4883                  NaN                         NaN                     NaN
# 4967                  NaN                         NaN                     NaN
# 5004                  NaN                         NaN                     NaN
# 5005                  NaN                         NaN                     NaN
# 5006                  NaN                         NaN                     NaN
#
#       pass_distance_received  pass_range_received_id pass_range_received  \
# 6                        NaN                     NaN                 NaN
# 7                        NaN                     NaN                 NaN
# 8                        NaN                     NaN                 NaN
# 9                        NaN                     NaN                 NaN
# 10                       NaN                     NaN                 NaN
# ...                      ...                     ...                 ...
# 4883                     NaN                     NaN                 NaN
# 4967                     NaN                     NaN                 NaN
# 5004                     NaN                     NaN                 NaN
# 5005                     NaN                     NaN                 NaN
# 5006                     NaN                     NaN                 NaN
#
#       pass_outcome_id pass_outcome targeted_passing_option_event_id high_pass  \
# 6                 NaN          NaN                              NaN       NaN
# 7                 NaN          NaN                              NaN       NaN
# 8                 NaN          NaN                              NaN       NaN
# 9                 NaN          NaN                              NaN       NaN
# 10                NaN          NaN                              NaN       NaN
# ...               ...          ...                              ...       ...
# 4883              NaN          NaN                              NaN       NaN
# 4967              NaN          NaN                              NaN       NaN
# 5004              NaN          NaN                              NaN     False
# 5005              NaN          NaN                              NaN       NaN
# 5006              NaN          NaN                              NaN       NaN
#
#       player_targeted_id player_targeted_name  player_targeted_position_id  \
# 6                    NaN                  NaN                          NaN
# 7                    NaN                  NaN                          NaN
# 8                    NaN                  NaN                          NaN
# 9                    NaN                  NaN                          NaN
# 10                   NaN                  NaN                          NaN
# ...                  ...                  ...                          ...
# 4883                 NaN                  NaN                          NaN
# 4967            735578.0             M. Natta                          2.0
# 5004                 NaN                  NaN                          NaN
# 5005                 NaN                  NaN                          NaN
# 5006                 NaN                  NaN                          NaN
#
#      player_targeted_position  player_targeted_x_pass  player_targeted_y_pass  \
# 6                         NaN                     NaN                     NaN
# 7                         NaN                     NaN                     NaN
# 8                         NaN                     NaN                     NaN
# 9                         NaN                     NaN                     NaN
# 10                        NaN                     NaN                     NaN
# ...                       ...                     ...                     ...
# 4883                      NaN                     NaN                     NaN
# 4967                       LB                     NaN                     NaN
# 5004                      NaN                     NaN                     NaN
# 5005                      NaN                     NaN                     NaN
# 5006                      NaN                     NaN                     NaN
#
#       player_targeted_channel_pass_id player_targeted_channel_pass  \
# 6                                 NaN                          NaN
# 7                                 NaN                          NaN
# 8                                 NaN                          NaN
# 9                                 NaN                          NaN
# 10                                NaN                          NaN
# ...                               ...                          ...
# 4883                              NaN                          NaN
# 4967                              NaN                          NaN
# 5004                              NaN                          NaN
# 5005                              NaN                          NaN
# 5006                              NaN                          NaN
#
#       player_targeted_third_pass_id player_targeted_third_pass  \
# 6                               NaN                        NaN
# 7                               NaN                        NaN
# 8                               NaN                        NaN
# 9                               NaN                        NaN
# 10                              NaN                        NaN
# ...                             ...                        ...
# 4883                            NaN                        NaN
# 4967                            NaN                        NaN
# 5004                            NaN                        NaN
# 5005                            NaN                        NaN
# 5006                            NaN                        NaN
#
#      player_targeted_penalty_area_pass  player_targeted_x_reception  \
# 6                                  NaN                          NaN
# 7                                  NaN                          NaN
# 8                                  NaN                          NaN
# 9                                  NaN                          NaN
# 10                                 NaN                          NaN
# ...                                ...                          ...
# 4883                               NaN                          NaN
# 4967                               NaN                          NaN
# 5004                               NaN                          NaN
# 5005                               NaN                          NaN
# 5006                               NaN                          NaN
#
#       player_targeted_y_reception  player_targeted_channel_reception_id  \
# 6                             NaN                                   NaN
# 7                             NaN                                   NaN
# 8                             NaN                                   NaN
# 9                             NaN                                   NaN
# 10                            NaN                                   NaN
# ...                           ...                                   ...
# 4883                          NaN                                   NaN
# 4967                          NaN                                   NaN
# 5004                          NaN                                   NaN
# 5005                          NaN                                   NaN
# 5006                          NaN                                   NaN
#
#      player_targeted_channel_reception  player_targeted_third_reception_id  \
# 6                                  NaN                                 NaN
# 7                                  NaN                                 NaN
# 8                                  NaN                                 NaN
# 9                                  NaN                                 NaN
# 10                                 NaN                                 NaN
# ...                                ...                                 ...
# 4883                               NaN                                 NaN
# 4967                               NaN                                 NaN
# 5004                               NaN                                 NaN
# 5005                               NaN                                 NaN
# 5006                               NaN                                 NaN
#
#      player_targeted_third_reception player_targeted_penalty_area_reception  \
# 6                                NaN                                    NaN
# 7                                NaN                                    NaN
# 8                                NaN                                    NaN
# 9                                NaN                                    NaN
# 10                               NaN                                    NaN
# ...                              ...                                    ...
# 4883                             NaN                                    NaN
# 4967                             NaN                                    NaN
# 5004                             NaN                                    NaN
# 5005                             NaN                                    NaN
# 5006                             NaN                                    NaN
#
#       player_targeted_distance_to_goal_start  \
# 6                                        NaN
# 7                                        NaN
# 8                                        NaN
# 9                                        NaN
# 10                                       NaN
# ...                                      ...
# 4883                                     NaN
# 4967                                   73.98
# 5004                                     NaN
# 5005                                     NaN
# 5006                                     NaN
#
#       player_targeted_distance_to_goal_end  \
# 6                                      NaN
# 7                                      NaN
# 8                                      NaN
# 9                                      NaN
# 10                                     NaN
# ...                                    ...
# 4883                                   NaN
# 4967                                 74.62
# 5004                                   NaN
# 5005                                   NaN
# 5006                                   NaN
#
#       player_targeted_angle_to_goal_start  player_targeted_angle_to_goal_end  \
# 6                                     NaN                                NaN
# 7                                     NaN                                NaN
# 8                                     NaN                                NaN
# 9                                     NaN                                NaN
# 10                                    NaN                                NaN
# ...                                   ...                                ...
# 4883                                  NaN                                NaN
# 4967                               158.54                             157.64
# 5004                                  NaN                                NaN
# 5005                                  NaN                                NaN
# 5006                                  NaN                                NaN
#
#       player_targeted_average_speed  player_targeted_speed_avg_band_id  \
# 6                               NaN                                NaN
# 7                               NaN                                NaN
# 8                               NaN                                NaN
# 9                               NaN                                NaN
# ...
# 9                     NaN                     NaN
# 10                    NaN                    True
# ...                   ...                     ...
# 4883                  NaN                     NaN
# 4967                  NaN                     NaN
# 5004                  NaN                     NaN
# 5005                  NaN                    True
# 5006                  NaN                     NaN
#
#       n_simultaneous_passing_options passing_option_at_pass_moment  \
# 6                                3.0                         False
# 7                                3.0                          True
# 8                                3.0                          True
# 9                                3.0                          True
# 10                               NaN                           NaN
# ...                              ...                           ...
# 4883                             2.0                          True
# 4967                             NaN                           NaN
# 5004                             1.0                          True
# 5005                             NaN                           NaN
# 5006                             1.0                          True
#
#       n_opponents_ahead_end  n_opponents_ahead_start  n_opponents_overtaken  \
# 6                       NaN                      NaN                    NaN
# 7                       NaN                      NaN                    NaN
# 8                       NaN                      NaN                    NaN
# 9                       NaN                      NaN                    NaN
# 10                      5.0                      5.0                    0.0
# ...                     ...                      ...                    ...
# 4883                    NaN                      NaN                    NaN
# 4967                    NaN                      NaN                    NaN
# 5004                    NaN                      NaN                    NaN
# 5005                    4.0                      5.0                    1.0
# 5006                    NaN                      NaN                    NaN
#
#      pressing_chain  pressing_chain_length  pressing_chain_end_type_id  \
# 6               NaN                    NaN                         NaN
# 7               NaN                    NaN                         NaN
# 8               NaN                    NaN                         NaN
# 9               NaN                    NaN                         NaN
# 10              NaN                    NaN                         NaN
# ...             ...                    ...                         ...
# 4883            NaN                    NaN                         NaN
# 4967          False                    NaN                         NaN
# 5004            NaN                    NaN                         NaN
# 5005            NaN                    NaN                         NaN
# 5006            NaN                    NaN                         NaN
#
#      pressing_chain_end_type  pressing_chain_index  index_in_pressing_chain  \
# 6                        NaN                   NaN                      NaN
# 7                        NaN                   NaN                      NaN
# 8                        NaN                   NaN                      NaN
# 9                        NaN                   NaN                      NaN
# 10                       NaN                   NaN                      NaN
# ...                      ...                   ...                      ...
# 4883                     NaN                   NaN                      NaN
# 4967                     NaN                   NaN                      NaN
# 5004                     NaN                   NaN                      NaN
# 5005                     NaN                   NaN                      NaN
# 5006                     NaN                   NaN                      NaN
#
#      simultaneous_defensive_engagement_same_target  \
# 6                                              NaN
# 7                                              NaN
# 8                                              NaN
# 9                                              NaN
# 10                                             NaN
# ...                                            ...
# 4883                                           NaN
# 4967                                         False
# 5004                                           NaN
# 5005                                           NaN
# 5006                                           NaN
#
#       simultaneous_defensive_engagement_same_target_rank  \
# 6                                                    NaN
# 7                                                    NaN
# 8                                                    NaN
# 9                                                    NaN
# 10                                                   NaN
# ...                                                  ...
# 4883                                                 NaN
# 4967                                                 NaN
# 5004                                                 NaN
# 5005                                                 NaN
# 5006                                                 NaN
#
#      affected_line_breaking_passing_option_id  affected_line_break_id  \
# 6                                         NaN                     NaN
# 7                                         NaN                     NaN
# 8                                         NaN                     NaN
# 9                                         NaN                     NaN
# 10                                        NaN                     NaN
# ...                                       ...                     ...
# 4883                                      NaN                     NaN
# 4967                                      NaN                     NaN
# 5004                                      NaN                     NaN
# 5005                                      NaN                     NaN
# 5006                                      NaN                     NaN
#
#      affected_line_break affected_line_breaking_passing_option_attempted  \
# 6                    NaN                                             NaN
# 7                    NaN                                             NaN
# 8                    NaN                                             NaN
# 9                    NaN                                             NaN
# 10                   NaN                                             NaN
# ...                  ...                                             ...
# 4883                 NaN                                             NaN
# 4967                 NaN                                             NaN
# 5004                 NaN                                             NaN
# 5005                 NaN                                             NaN
# 5006                 NaN                                             NaN
#
#       affected_line_breaking_passing_option_xthreat  \
# 6                                               NaN
# 7                                               NaN
# 8                                               NaN
# 9                                               NaN
# 10                                              NaN
# ...                                             ...
# 4883                                            NaN
# 4967                                            NaN
# 5004                                            NaN
# 5005                                            NaN
# 5006                                            NaN
#
#      affected_line_breaking_passing_option_dangerous  \
# 6                                                NaN
# 7                                                NaN
# 8                                                NaN
# 9                                                NaN
# 10                                               NaN
# ...                                              ...
# 4883                                             NaN
# 4967                                             NaN
# 5004                                             NaN
# 5005                                             NaN
# 5006                                             NaN
#
#       affected_line_breaking_passing_option_run_subtype_id  \
# 6                                                      NaN
# 7                                                      NaN
# 8                                                      NaN
# 9                                                      NaN
# 10                                                     NaN
# ...                                                    ...
# 4883                                                   NaN
# 4967                                                   NaN
# 5004                                                   NaN
# 5005                                                   NaN
# 5006                                                   NaN
#
#      affected_line_breaking_passing_option_run_subtype possession_danger  \
# 6                                                  NaN               NaN
# 7                                                  NaN               NaN
# 8                                                  NaN               NaN
# 9                                                  NaN               NaN
# 10                                                 NaN               NaN
# ...                                                ...               ...
# 4883                                               NaN               NaN
# 4967                                               NaN             False
# 5004                                               NaN               NaN
# 5005                                               NaN               NaN
# 5006                                               NaN               NaN
#
#      beaten_by_possession beaten_by_movement stop_possession_danger  \
# 6                     NaN                NaN                    NaN
# 7                     NaN                NaN                    NaN
# 8                     NaN                NaN                    NaN
# 9                     NaN                NaN                    NaN
# 10                    NaN                NaN                    NaN
# ...                   ...                ...                    ...
# 4883                  NaN                NaN                    NaN
# 4967                False              False                  False
# 5004                  NaN                NaN                    NaN
# 5005                  NaN                NaN                    NaN
# 5006                  NaN                NaN                    NaN
#
#      reduce_possession_danger force_backward  xloss_player_possession_start  \
# 6                         NaN            NaN                            NaN
# 7                         NaN            NaN                            NaN
# 8                         NaN            NaN                            NaN
# 9                         NaN            NaN                            NaN
# 10                        NaN            NaN                            NaN
# ...                       ...            ...                            ...
# 4883                      NaN            NaN                            NaN
# 4967                    False          False                          0.336
# 5004                      NaN            NaN                            NaN
# 5005                      NaN            NaN                            NaN
# 5006                      NaN            NaN                            NaN
#
#       xloss_player_possession_end  xloss_player_possession_max  \
# 6                             NaN                          NaN
# 7                             NaN                          NaN
# 8                             NaN                          NaN
# 9                             NaN                          NaN
# 10                            NaN                          NaN
# ...                           ...                          ...
# 4883                          NaN                          NaN
# 4967                        0.316                        0.336
# 5004                          NaN                          NaN
# 5005                          NaN                          NaN
# 5006                          NaN                          NaN
#
#       xshot_player_possession_start  xshot_player_possession_end  \
# 6                               NaN                          NaN
# 7                               NaN                          NaN
# 8                               NaN                          NaN
# 9                               NaN                          NaN
# 10                              NaN                          NaN
# ...                             ...                          ...
# 4883                            NaN                          NaN
# 4967                            0.0                          0.0
# 5004                            NaN                          NaN
# 5005                            NaN                          NaN
# 5006                            NaN                          NaN
#
#       xshot_player_possession_max  is_player_possession_start_matched  \
# 6                             NaN                                True
# 7                             NaN                                True
# 8                             NaN                                True
# 9                             NaN                                True
# 10                            NaN                                True
# ...                           ...                                 ...
# 4883                          NaN                                True
# 4967                          0.0                                True
# 5004                          NaN                                True
# 5005                          NaN                                True
# 5006                          NaN                                True
#
#       is_player_possession_end_matched is_previous_pass_matched  \
# 6                                 True                      NaN
# 7                                 True                      NaN
# 8                                 True                      NaN
# 9                                 True                      NaN
# 10                                True                      NaN
# ...                                ...                      ...
# 4883                              True                      NaN
# 4967                              True                     True
# 5004                              True                      NaN
# 5005                              True                      NaN
# 5006                              True                      NaN
#
#      is_pass_reception_matched fully_extrapolated
# 6                          NaN              False
# 7                          NaN              False
# 8                          NaN              False
# 9                          NaN              False
# 10                         NaN                NaN
# ...                        ...                ...
# 4883                       NaN              False
# 4967                       NaN                NaN
# 5004                      True              False
# 5005                       NaN                NaN
# 5006                       NaN              False
#
# [238 rows x 294 columns]

# %%
de_match[de_match['associated_off_ball_run_event_id'].notnull()]
# Out:
#      event_id  index  match_id  frame_start  frame_end  frame_physical_start  \
# 7         7_3      7   1886347           72         89                   NaN
# 8         7_4      8   1886347           72         89                   NaN
# 9         7_5      9   1886347           73         89                   NaN
# 15        7_6     15   1886347          202        229                   NaN
# 32       7_15     32   1886347          301        337                   NaN
# ...       ...    ...       ...          ...        ...                   ...
# 5006   7_2506   5006   1886347        58270      58277                   NaN
# 5019   7_2513   5019   1886347        58381      58389                   NaN
# 5031   7_2518   5031   1886347        58413      58436                   NaN
# 5041   7_2522   5041   1886347        58512      58524                   NaN
# 5064   7_2535   5064   1886347        58602      58609                   NaN
#
#      time_start time_end  minute_start  second_start  duration  period  \
# 7       00:06.2  00:07.9             0             6       1.7       1
# 8       00:06.2  00:07.9             0             6       1.7       1
# 9       00:06.3  00:07.9             0             6       1.6       1
# 15      00:19.2  00:21.9             0            19       2.7       1
# 32      00:29.1  00:32.7             0            29       3.6       1
# ...         ...      ...           ...           ...       ...     ...
# 5006    95:47.0  95:47.7            95            47       0.7       2
# 5019    95:58.1  95:58.9            95            58       0.8       2
# 5031    96:01.3  96:03.6            96             1       2.3       2
# 5041    96:11.2  96:12.4            96            11       1.2       2
# 5064    96:20.2  96:20.9            96            20       0.7       2
#
#       attacking_side_id attacking_side  event_type_id      event_type  \
# 7                     1  left_to_right              7  passing_option
# 8                     1  left_to_right              7  passing_option
# 9                     1  left_to_right              7  passing_option
# 15                    2  right_to_left              7  passing_option
# 32                    2  right_to_left              7  passing_option
# ...                 ...            ...            ...             ...
# 5006                  2  right_to_left              7  passing_option
# 5019                  2  right_to_left              7  passing_option
# 5031                  2  right_to_left              7  passing_option
# 5041                  2  right_to_left              7  passing_option
# 5064                  2  right_to_left              7  passing_option
#
#       event_subtype_id event_subtype  player_id   player_name  \
# 7                  NaN           NaN     795507    L. Bayliss
# 8                  NaN           NaN     966120     B. Gibson
# 9                  NaN           NaN     735573   T. Aquilina
# 15                 NaN           NaN     133498   F. De Vries
# 32                 NaN           NaN      23418   F. Gallegos
# ...                ...           ...        ...           ...
# 5006               NaN           NaN     560992  D. Wilmering
# 5019               NaN           NaN     560992  D. Wilmering
# 5031               NaN           NaN     795506     C. Taylor
# 5041               NaN           NaN      50983     D. Ingham
# 5064               NaN           NaN     735573   T. Aquilina
#
#       player_position_id player_position  player_in_possession_id  \
# 7                     15              AM                 735578.0
# 8                     19              CF                 735578.0
# 9                     16              LW                 735578.0
# 15                     2              LB                  33697.0
# 32                    15              AM                 965685.0
# ...                  ...             ...                      ...
# 5006                  15              AM                 735578.0
# 5019                  15              AM                 795506.0
# 5031                  19              CF                 560992.0
# 5041                   8              RB                 735574.0
# 5064                  16              LW                  50983.0
#
#      player_in_possession_name  player_in_possession_position_id  \
# 7                     M. Natta                               2.0
# 8                     M. Natta                               2.0
# 9                     M. Natta                               2.0
# 15                 N. Pijnaker                               4.0
# 32                  L. Gillion                              16.0
# ...                        ...                               ...
# 5006                  M. Natta                               2.0
# 5019                 C. Taylor                              19.0
# 5031              D. Wilmering                              15.0
# 5041                 K. Grozos                              11.0
# 5064                 D. Ingham                               8.0
#
#      player_in_possession_position  team_id team_shortname  x_start  y_start  \
# 7                               LB     1805      Newcastle    14.93    10.13
# 8                               LB     1805      Newcastle    12.73     3.61
# 9                               LB     1805      Newcastle     7.31    19.98
# 15                             LCB     4177    Auckland FC   -15.93    21.92
# 32                              LW     4177    Auckland FC    15.23    28.01
# ...                            ...      ...            ...      ...      ...
# 5006                            LB     1805      Newcastle    16.73    17.54
# 5019                            CF     1805      Newcastle    13.34    33.77
# 5031                            AM     1805      Newcastle    18.09    32.29
# 5041                           RDM     1805      Newcastle    33.17   -24.35
# 5064                            RB     1805      Newcastle    28.22   -23.19
#
#       channel_id_start    channel_start  third_id_start      third_start  \
# 7                    2  half_space_left               2     middle_third
# 8                    3           center               2     middle_third
# 9                    2  half_space_left               2     middle_third
# 15                   1        wide_left               2     middle_third
# 32                   1        wide_left               2     middle_third
# ...                ...              ...             ...              ...
# 5006                 2  half_space_left               2     middle_third
# 5019                 1        wide_left               2     middle_third
# 5031                 1        wide_left               3  attacking_third
# 5041                 5       wide_right               3  attacking_third
# 5064                 5       wide_right               3  attacking_third
#
#       penalty_area_start  x_end  y_end  channel_id_end      channel_end  \
# 7                  False  11.67  16.14               2  half_space_left
# 8                  False  16.91   9.27               2  half_space_left
# 9                  False   6.87  27.64               1        wide_left
# 15                 False -10.82  30.43               1        wide_left
# 32                 False  37.89  29.34               1        wide_left
# ...                  ...    ...    ...             ...              ...
# 5006               False  19.93  18.66               2  half_space_left
# 5019               False  14.86  33.51               1        wide_left
# 5031               False  27.02  32.18               1        wide_left
# 5041               False  30.81 -28.42               5       wide_right
# 5064               False  31.74 -25.12               5       wide_right
#
#       third_id_end        third_end  penalty_area_end  \
# 7                2     middle_third             False
# 8                2     middle_third             False
# 9                2     middle_third             False
# 15               2     middle_third             False
# 32               3  attacking_third             False
# ...            ...              ...               ...
# 5006             3  attacking_third             False
# 5019             2     middle_third             False
# 5031             3  attacking_third             False
# 5041             3  attacking_third             False
# 5064             3  attacking_third             False
#
#      associated_player_possession_event_id  \
# 7                                      8_2
# 8                                      8_2
# 9                                      8_2
# 15                                     8_3
# 32                                     8_6
# ...                                    ...
# 5006                                 8_984
# 5019                                 8_986
# 5031                                 8_988
# 5041                                 8_990
# 5064                                 8_995
#
#       associated_player_possession_frame_start  \
# 7                                         72.0
# 8                                         72.0
# 9                                         72.0
# 15                                       202.0
# 32                                       301.0
# ...                                        ...
# 5006                                   58262.0
# 5019                                   58341.0
# 5031                                   58406.0
# 5041                                   58512.0
# 5064                                   58602.0
#
#       associated_player_possession_frame_end  \
# 7                                        NaN
# 8                                        NaN
# 9                                        NaN
# 15                                       NaN
# 32                                       NaN
# ...                                      ...
# 5006                                     NaN
# 5019                                     NaN
# 5031                                     NaN
# 5041                                     NaN
# 5064                                     NaN
#
#       associated_player_possession_end_type_id  \
# 7                                          NaN
# 8                                          NaN
# 9                                          NaN
# 15                                         NaN
# 32                                         NaN
# ...                                        ...
# 5006                                       NaN
# 5019                                       NaN
# 5031                                       NaN
# 5041                                       NaN
# 5064                                       NaN
#
#      associated_player_possession_end_type associated_off_ball_run_event_id  \
# 7                                      NaN                              1_1
# 8                                      NaN                              1_2
# 9                                      NaN                              1_0
# 15                                     NaN                              1_3
# 32                                     NaN                              1_5
# ...                                    ...                              ...
# 5006                                   NaN                            1_594
# 5019                                   NaN                            1_595
# 5031                                   NaN                            1_596
# 5041                                   NaN                            1_597
# 5064                                   NaN                            1_598
#
#       associated_off_ball_run_subtype_id associated_off_ball_run_subtype  \
# 7                                    2.0                    coming_short
# 8                                    1.0                          behind
# 9                                    7.0                    pulling_wide
# 15                                   7.0                    pulling_wide
# 32                                   5.0                         overlap
# ...                                  ...                             ...
# 5006                                 8.0           run_ahead_of_the_ball
# 5019                                 8.0           run_ahead_of_the_ball
# 5031                                 9.0                         support
# 5041                                 7.0                    pulling_wide
# 5064                                10.0                        underlap
#
#       game_state_id game_state  team_score  opponent_team_score  phase_index  \
# 7                 3    drawing           0                    0            1
# 8                 3    drawing           0                    0            1
# 9                 3    drawing           0                    0            1
# 15                3    drawing           0                    0            2
# 32                3    drawing           0                    0            5
# ...             ...        ...         ...                  ...          ...
# 5006              2     losing           0                    2          448
# 5019              2     losing           0                    2          450
# 5031              2     losing           0                    2          451
# 5041              2     losing           0                    2          451
# 5064              2     losing           0                    2          451
#
#       player_possession_phase_index  \
# 7                               NaN
# 8                               NaN
# 9                               NaN
# 15                              NaN
# 32                              NaN
# ...                             ...
# 5006                            NaN
# 5019                            NaN
# 5031                            NaN
# 5041                            NaN
# 5064                            NaN
#
#      first_player_possession_in_team_possession  \
# 7                                           NaN
# 8                                           NaN
# 9                                           NaN
# 15                                          NaN
# 32                                          NaN
# ...                                         ...
# 5006                                        NaN
# 5019                                        NaN
# 5031                                        NaN
# 5041                                        NaN
# 5064                                        NaN
#
#      last_player_possession_in_team_possession lead_to_different_phase  \
# 7                                          NaN                     NaN
# 8                                          NaN                     NaN
# 9                                          NaN                     NaN
# 15                                         NaN                     NaN
# 32                                         NaN                     NaN
# ...                                        ...                     ...
# 5006                                       NaN                     NaN
# 5019                                       NaN                     NaN
# 5031                                       NaN                     NaN
# 5041                                       NaN                     NaN
# 5064                                       NaN                     NaN
#
#      issued_from_different_phase  n_player_possessions_in_phase  \
# 7                            NaN                            NaN
# 8                            NaN                            NaN
# 9                            NaN                            NaN
# 15                           NaN                            NaN
# 32                           NaN                            NaN
# ...                          ...                            ...
# 5006                         NaN                            NaN
# 5019                         NaN                            NaN
# 5031                         NaN                            NaN
# 5041                         NaN                            NaN
# 5064                         NaN                            NaN
#
#      team_possession_loss_in_phase  team_in_possession_phase_type_id  \
# 7                              NaN                                 6
# 8                              NaN                                 6
# 9                              NaN                                 6
# 15                             NaN                                 0
# 32                             NaN                                 2
# ...                            ...                               ...
# 5006                           NaN                                 1
# 5019                           NaN                                 1
# 5031                           NaN                                 2
# 5041                           NaN                                 2
# 5064                           NaN                                 2
#
#      team_in_possession_phase_type  team_out_of_possession_phase_type_id  \
# 7                           direct                                    15
# 8                           direct                                    15
# 9                           direct                                    15
# 15                        build_up                                    10
# 32                          finish                                     8
# ...                            ...                                   ...
# 5006                        create                                     9
# 5019                        create                                     9
# 5031                        finish                                     8
# 5041                        finish                                     8
# 5064                        finish                                     8
#
#      team_out_of_possession_phase_type  \
# 7                     defending_direct
# 8                     defending_direct
# 9                     defending_direct
# 15                          high_block
# 32                           low_block
# ...                                ...
# 5006                      medium_block
# 5019                      medium_block
# 5031                         low_block
# 5041                         low_block
# 5064                         low_block
#
#       current_team_in_possession_next_phase_type_id  \
# 7                                               NaN
# 8                                               NaN
# 9                                               NaN
# 15                                              NaN
# 32                                              NaN
# ...                                             ...
# 5006                                            NaN
# 5019                                            NaN
# 5031                                            NaN
# 5041                                            NaN
# 5064                                            NaN
#
#      current_team_in_possession_next_phase_type  \
# 7                                           NaN
# 8                                           NaN
# 9                                           NaN
# 15                                          NaN
# 32                                          NaN
# ...                                         ...
# 5006                                        NaN
# 5019                                        NaN
# 5031                                        NaN
# 5041                                        NaN
# 5064                                        NaN
#
#       current_team_out_of_possession_next_phase_type_id  \
# 7                                                   NaN
# 8                                                   NaN
# 9                                                   NaN
# 15                                                  NaN
# 32                                                  NaN
# ...                                                 ...
# 5006                                                NaN
# 5019                                                NaN
# 5031                                                NaN
# 5041                                                NaN
# 5064                                                NaN
#
#      current_team_out_of_possession_next_phase_type  \
# 7                                               NaN
# 8                                               NaN
# 9                                               NaN
# 15                                              NaN
# 32                                              NaN
# ...                                             ...
# 5006                                            NaN
# 5019                                            NaN
# 5031                                            NaN
# 5041                                            NaN
# 5064                                            NaN
#
#       current_team_in_possession_previous_phase_type_id  \
# 7                                                   NaN
# 8                                                   NaN
# 9                                                   NaN
# 15                                                  NaN
# 32                                                  NaN
# ...                                                 ...
# 5006                                                NaN
# 5019                                                NaN
# 5031                                                NaN
# 5041                                                NaN
# 5064                                                NaN
#
#      current_team_in_possession_previous_phase_type  \
# 7                                               NaN
# 8                                               NaN
# 9                                               NaN
# 15                                              NaN
# 32                                              NaN
# ...                                             ...
# 5006                                            NaN
# 5019                                            NaN
# 5031                                            NaN
# 5041                                            NaN
# 5064                                            NaN
#
#       current_team_out_of_possession_previous_phase_type_id  \
# 7                                                       NaN
# 8                                                       NaN
# 9                                                       NaN
# 15                                                      NaN
# 32                                                      NaN
# ...                                                     ...
# 5006                                                    NaN
# 5019                                                    NaN
# 5031                                                    NaN
# 5041                                                    NaN
# 5064                                                    NaN
#
#      current_team_out_of_possession_previous_phase_type  \
# 7                                                   NaN
# 8                                                   NaN
# 9                                                   NaN
# 15                                                  NaN
# 32                                                  NaN
# ...                                                 ...
# 5006                                                NaN
# 5019                                                NaN
# 5031                                                NaN
# 5041                                                NaN
# 5064                                                NaN
#
#       game_interruption_before_id game_interruption_before  \
# 7                             NaN                      NaN
# 8                             NaN                      NaN
# 9                             NaN                      NaN
# 15                            NaN                      NaN
# 32                            NaN                      NaN
# ...                           ...                      ...
# 5006                          NaN                      NaN
# 5019                          NaN                      NaN
# 5031                          NaN                      NaN
# 5041                          NaN                      NaN
# 5064                          NaN                      NaN
#
#       game_interruption_after_id game_interruption_after  lead_to_shot  \
# 7                            NaN                     NaN         False
# 8                            NaN                     NaN         False
# 9                            NaN                     NaN         False
# 15                           NaN                     NaN         False
# 32                           NaN                     NaN         False
# ...                          ...                     ...           ...
# 5006                         NaN                     NaN         False
# 5019                         NaN                     NaN         False
# 5031                         NaN                     NaN         False
# 5041                         NaN                     NaN         False
# 5064                         NaN                     NaN         False
#
#       lead_to_goal  distance_covered  trajectory_angle  \
# 7            False              6.57            118.48
# 8            False              6.67             53.55
# 9            False              7.69             93.29
# 15           False              9.78             59.02
# 32           False             22.86              3.36
# ...            ...               ...               ...
# 5006         False              2.90             19.29
# 5019         False              1.55             -9.71
# 5031         False              8.64             -0.71
# 5041         False              4.73           -120.11
# 5064         False              3.46            -28.74
#
#       trajectory_direction_id trajectory_direction in_to_out out_to_in  \
# 7                         3.0         sideway_left     False     False
# 8                         3.0         sideway_left      True     False
# 9                         3.0         sideway_left      True     False
# 15                        3.0         sideway_left     False     False
# 32                        1.0              forward     False     False
# ...                       ...                  ...       ...       ...
# 5006                      1.0              forward     False     False
# 5019                      1.0              forward     False     False
# 5031                      1.0              forward     False     False
# 5041                      4.0        sideway_right     False     False
# 5064                      1.0              forward     False     False
#
#       speed_avg  speed_avg_band_id speed_avg_band  separation_start  \
# 7         15.15                2.0        running              5.74
# 8         15.21                2.0        running              4.40
# 9         17.16                2.0        running              5.52
# 15        13.20                1.0        jogging             11.40
# 32        22.37                3.0            hsr              2.65
# ...         ...                ...            ...               ...
# 5006      17.36                2.0        running              4.64
# 5019       7.04                1.0        jogging              3.69
# 5031      13.99                1.0        jogging              4.20
# 5041      14.18                1.0        jogging              8.91
# 5064      20.62                3.0            hsr              4.72
#
#       separation_end  separation_gain  last_defensive_line_x_start  \
# 7               6.90             1.16                        19.02
# 8               3.30            -1.10                        19.02
# 9               5.86             0.34                        19.05
# 15              5.78            -5.62                         9.03
# 32              3.42             0.78                        38.48
# ...              ...              ...                          ...
# 5006            3.85            -0.79                        21.29
# 5019            3.32            -0.37                        20.81
# 5031            5.79             1.58                        29.83
# 5041            6.95            -1.96                        36.32
# 5064            4.61            -0.12                        32.59
#
#       last_defensive_line_x_end  delta_to_last_defensive_line_start  \
# 7                         19.11                                4.09
# 8                         19.11                                6.29
# 9                         19.11                               11.74
# 15                         9.36                               24.96
# 32                        42.12                               23.25
# ...                         ...                                 ...
# 5006                      23.09                                4.56
# 5019                      20.84                                7.47
# 5031                      36.40                               11.74
# 5041                      35.25                                3.15
# 5064                      33.93                                4.37
#
#       delta_to_last_defensive_line_end  delta_to_last_defensive_line_gain  \
# 7                                 7.44                               3.35
# 8                                 2.20                              -4.09
# 9                                12.24                               0.50
# 15                               20.18                              -4.78
# 32                                4.23                             -19.02
# ...                                ...                                ...
# 5006                              3.16                              -1.40
# 5019                              5.98                              -1.49
# 5031                              9.38                              -2.36
# 5041                              4.44                               1.29
# 5064                              2.19                              -2.18
#
#       last_defensive_line_height_start  last_defensive_line_height_end  \
# 7                                32.98                           32.89
# 8                                32.98                           32.89
# 9                                32.95                           32.89
# 15                               42.97                           42.64
# 32                               13.52                            9.88
# ...                                ...                             ...
# 5006                             30.71                           28.91
# 5019                             31.19                           31.16
# 5031                             22.17                           15.60
# 5041                             15.68                           16.75
# 5064                             19.41                           18.07
#
#       last_defensive_line_height_gain inside_defensive_shape_start  \
# 7                               -0.09                         True
# 8                               -0.09                         True
# 9                               -0.06                        False
# 15                              -0.33                        False
# 32                              -3.64                         True
# ...                               ...                          ...
# 5006                            -1.80                         True
# 5019                            -0.03                        False
# 5031                            -6.57                        False
# 5041                             1.07                        False
# 5064                            -1.34                         True
#
#      inside_defensive_shape_end  start_type_id start_type  end_type_id  \
# 7                          True            NaN        NaN          NaN
# 8                          True            NaN        NaN          NaN
# 9                         False            NaN        NaN          NaN
# 15                        False            NaN        NaN          NaN
# 32                        False            NaN        NaN          NaN
# ...                         ...            ...        ...          ...
# 5006                       True            NaN        NaN          NaN
# 5019                      False            NaN        NaN          NaN
# 5031                      False            NaN        NaN          NaN
# 5041                      False            NaN        NaN          NaN
# 5064                      False            NaN        NaN          NaN
#
#      end_type consecutive_on_ball_engagements one_touch quick_pass carry  \
# 7         NaN                             NaN       NaN        NaN   NaN
# 8         NaN                             NaN       NaN        NaN   NaN
# 9         NaN                             NaN       NaN        NaN   NaN
# 15        NaN                             NaN       NaN        NaN   NaN
# 32        NaN                             NaN       NaN        NaN   NaN
# ...       ...                             ...       ...        ...   ...
# 5006      NaN                             NaN       NaN        NaN   NaN
# 5019      NaN                             NaN       NaN        NaN   NaN
# 5031      NaN                             NaN       NaN        NaN   NaN
# 5041      NaN                             NaN       NaN        NaN   NaN
# 5064      NaN                             NaN       NaN        NaN   NaN
#
#      forward_momentum is_header hand_pass initiate_give_and_go  \
# 7                 NaN       NaN       NaN                  NaN
# 8                 NaN       NaN       NaN                  NaN
# 9                 NaN       NaN       NaN                  NaN
# 15                NaN       NaN       NaN                  NaN
# 32                NaN       NaN       NaN                  NaN
# ...               ...       ...       ...                  ...
# 5006              NaN       NaN       NaN                  NaN
# 5019              NaN       NaN       NaN                  NaN
# 5031              NaN       NaN       NaN                  NaN
# 5041              NaN       NaN       NaN                  NaN
# 5064              NaN       NaN       NaN                  NaN
#
#       pass_angle_received  pass_direction_received_id pass_direction_received  \
# 7                     NaN                         NaN                     NaN
# 8                     NaN                         NaN                     NaN
# 9                     NaN                         NaN                     NaN
# 15                    NaN                         NaN                     NaN
# 32                    NaN                         NaN                     NaN
# ...                   ...                         ...                     ...
# 5006                  NaN                         NaN                     NaN
# 5019                  NaN                         NaN                     NaN
# 5031                  NaN                         NaN                     NaN
# 5041                  NaN                         NaN                     NaN
# 5064                  NaN                         NaN                     NaN
#
#       pass_distance_received  pass_range_received_id pass_range_received  \
# 7                        NaN                     NaN                 NaN
# 8                        NaN                     NaN                 NaN
# 9                        NaN                     NaN                 NaN
# 15                       NaN                     NaN                 NaN
# 32                       NaN                     NaN                 NaN
# ...                      ...                     ...                 ...
# 5006                     NaN                     NaN                 NaN
# 5019                     NaN                     NaN                 NaN
# 5031                     NaN                     NaN                 NaN
# 5041                     NaN                     NaN                 NaN
# 5064                     NaN                     NaN                 NaN
#
#       pass_outcome_id pass_outcome targeted_passing_option_event_id high_pass  \
# 7                 NaN          NaN                              NaN       NaN
# 8                 NaN          NaN                              NaN       NaN
# 9                 NaN          NaN                              NaN       NaN
# 15                NaN          NaN                              NaN     False
# 32                NaN          NaN                              NaN     False
# ...               ...          ...                              ...       ...
# 5006              NaN          NaN                              NaN       NaN
# 5019              NaN          NaN                              NaN     False
# 5031              NaN          NaN                              NaN       NaN
# 5041              NaN          NaN                              NaN       NaN
# 5064              NaN          NaN                              NaN       NaN
#
#       player_targeted_id player_targeted_name  player_targeted_position_id  \
# 7                    NaN                  NaN                          NaN
# 8                    NaN                  NaN                          NaN
# 9                    NaN                  NaN                          NaN
# 15                   NaN                  NaN                          NaN
# 32                   NaN                  NaN                          NaN
# ...                  ...                  ...                          ...
# 5006                 NaN                  NaN                          NaN
# 5019                 NaN                  NaN                          NaN
# 5031                 NaN                  NaN                          NaN
# 5041                 NaN                  NaN                          NaN
# 5064                 NaN                  NaN                          NaN
#
#      player_targeted_position  player_targeted_x_pass  player_targeted_y_pass  \
# 7                         NaN                     NaN                     NaN
# 8                         NaN                     NaN                     NaN
# 9                         NaN                     NaN                     NaN
# 15                        NaN                     NaN                     NaN
# 32                        NaN                     NaN                     NaN
# ...                       ...                     ...                     ...
# 5006                      NaN                     NaN                     NaN
# 5019                      NaN                     NaN                     NaN
# 5031                      NaN                     NaN                     NaN
# 5041                      NaN                     NaN                     NaN
# 5064                      NaN                     NaN                     NaN
#
#       player_targeted_channel_pass_id player_targeted_channel_pass  \
# 7                                 NaN                          NaN
# 8                                 NaN                          NaN
# 9                                 NaN                          NaN
# 15                                NaN                          NaN
# 32                                NaN                          NaN
# ...                               ...                          ...
# 5006                              NaN                          NaN
# 5019                              NaN                          NaN
# 5031                              NaN                          NaN
# 5041                              NaN                          NaN
# 5064                              NaN                          NaN
#
#       player_targeted_third_pass_id player_targeted_third_pass  \
# 7                               NaN                        NaN
# 8                               NaN                        NaN
# 9                               NaN                        NaN
# 15                              NaN                        NaN
# 32                              NaN                        NaN
# ...                             ...                        ...
# 5006                            NaN                        NaN
# 5019                            NaN                        NaN
# 5031                            NaN                        NaN
# 5041                            NaN                        NaN
# 5064                            NaN                        NaN
#
#      player_targeted_penalty_area_pass  player_targeted_x_reception  \
# 7                                  NaN                          NaN
# 8                                  NaN                          NaN
# 9                                  NaN                          NaN
# 15                                 NaN                          NaN
# 32                                 NaN                          NaN
# ...                                ...                          ...
# 5006                               NaN                          NaN
# 5019                               NaN                          NaN
# 5031                               NaN                          NaN
# 5041                               NaN                          NaN
# 5064                               NaN                          NaN
#
#       player_targeted_y_reception  player_targeted_channel_reception_id  \
# 7                             NaN                                   NaN
# 8                             NaN                                   NaN
# 9                             NaN                                   NaN
# 15                            NaN                                   NaN
# 32                            NaN                                   NaN
# ...                           ...                                   ...
# 5006                          NaN                                   NaN
# 5019                          NaN                                   NaN
# 5031                          NaN                                   NaN
# 5041                          NaN                                   NaN
# 5064                          NaN                                   NaN
#
#      player_targeted_channel_reception  player_targeted_third_reception_id  \
# 7                                  NaN                                 NaN
# 8                                  NaN                                 NaN
# 9                                  NaN                                 NaN
# 15                                 NaN                                 NaN
# 32                                 NaN                                 NaN
# ...                                ...                                 ...
# 5006                               NaN                                 NaN
# 5019                               NaN                                 NaN
# 5031                               NaN                                 NaN
# 5041                               NaN                                 NaN
# 5064                               NaN                                 NaN
#
#      player_targeted_third_reception player_targeted_penalty_area_reception  \
# 7                                NaN                                    NaN
# 8                                NaN                                    NaN
# 9                                NaN                                    NaN
# 15                               NaN                                    NaN
# 32                               NaN                                    NaN
# ...                              ...                                    ...
# 5006                             NaN                                    NaN
# 5019                             NaN                                    NaN
# 5031                             NaN                                    NaN
# 5041                             NaN                                    NaN
# 5064                             NaN                                    NaN
#
#       player_targeted_distance_to_goal_start  \
# 7                                        NaN
# 8                                        NaN
# 9                                        NaN
# 15                                       NaN
# 32                                       NaN
# ...                                      ...
# 5006                                     NaN
# 5019                                     NaN
# 5031                                     NaN
# 5041                                     NaN
# 5064                                     NaN
#
#       player_targeted_distance_to_goal_end  \
# 7                                      NaN
# 8                                      NaN
# 9                                      NaN
# 15                                     NaN
# 32                                     NaN
# ...                                    ...
# 5006                                   NaN
# 5019                                   NaN
# 5031                                   NaN
# 5041                                   NaN
# 5064                                   NaN
#
#       player_targeted_angle_to_goal_start  player_targeted_angle_to_goal_end  \
# 7                                     NaN                                NaN
# 8                                     NaN                                NaN
# 9                                     NaN                                NaN
# 15                                    NaN                                NaN
# 32                                    NaN                                NaN
# ...                                   ...                                ...
# 5006                                  NaN                                NaN
# 5019                                  NaN                                NaN
# 5031                                  NaN                                NaN
# 5041                                  NaN                                NaN
# 5064                                  NaN                                NaN
#
#       player_targeted_average_speed  player_targeted_speed_avg_band_id  \
# 7                               NaN                                NaN
# 8                               NaN                                NaN
# 9                               NaN                                NaN
# 15                              NaN                                NaN
# 32                              NaN                                NaN
# ...                             ...                                ...
# ...
# 15                    NaN                     NaN
# 32                    NaN                     NaN
# ...                   ...                     ...
# 5006                  NaN                     NaN
# 5019                  NaN                     NaN
# 5031                  NaN                     NaN
# 5041                  NaN                     NaN
# 5064                  NaN                     NaN
#
#       n_simultaneous_passing_options passing_option_at_pass_moment  \
# 7                                3.0                          True
# 8                                3.0                          True
# 9                                3.0                          True
# 15                               1.0                          True
# 32                               2.0                          True
# ...                              ...                           ...
# 5006                             1.0                          True
# 5019                             3.0                          True
# 5031                             3.0                          True
# 5041                             2.0                          True
# 5064                             1.0                          True
#
#       n_opponents_ahead_end  n_opponents_ahead_start  n_opponents_overtaken  \
# 7                       NaN                      NaN                    NaN
# 8                       NaN                      NaN                    NaN
# 9                       NaN                      NaN                    NaN
# 15                      NaN                      NaN                    NaN
# 32                      NaN                      NaN                    NaN
# ...                     ...                      ...                    ...
# 5006                    NaN                      NaN                    NaN
# 5019                    NaN                      NaN                    NaN
# 5031                    NaN                      NaN                    NaN
# 5041                    NaN                      NaN                    NaN
# 5064                    NaN                      NaN                    NaN
#
#      pressing_chain  pressing_chain_length  pressing_chain_end_type_id  \
# 7               NaN                    NaN                         NaN
# 8               NaN                    NaN                         NaN
# 9               NaN                    NaN                         NaN
# 15              NaN                    NaN                         NaN
# 32              NaN                    NaN                         NaN
# ...             ...                    ...                         ...
# 5006            NaN                    NaN                         NaN
# 5019            NaN                    NaN                         NaN
# 5031            NaN                    NaN                         NaN
# 5041            NaN                    NaN                         NaN
# 5064            NaN                    NaN                         NaN
#
#      pressing_chain_end_type  pressing_chain_index  index_in_pressing_chain  \
# 7                        NaN                   NaN                      NaN
# 8                        NaN                   NaN                      NaN
# 9                        NaN                   NaN                      NaN
# 15                       NaN                   NaN                      NaN
# 32                       NaN                   NaN                      NaN
# ...                      ...                   ...                      ...
# 5006                     NaN                   NaN                      NaN
# 5019                     NaN                   NaN                      NaN
# 5031                     NaN                   NaN                      NaN
# 5041                     NaN                   NaN                      NaN
# 5064                     NaN                   NaN                      NaN
#
#      simultaneous_defensive_engagement_same_target  \
# 7                                              NaN
# 8                                              NaN
# 9                                              NaN
# 15                                             NaN
# 32                                             NaN
# ...                                            ...
# 5006                                           NaN
# 5019                                           NaN
# 5031                                           NaN
# 5041                                           NaN
# 5064                                           NaN
#
#       simultaneous_defensive_engagement_same_target_rank  \
# 7                                                    NaN
# 8                                                    NaN
# 9                                                    NaN
# 15                                                   NaN
# 32                                                   NaN
# ...                                                  ...
# 5006                                                 NaN
# 5019                                                 NaN
# 5031                                                 NaN
# 5041                                                 NaN
# 5064                                                 NaN
#
#      affected_line_breaking_passing_option_id  affected_line_break_id  \
# 7                                         NaN                     NaN
# 8                                         NaN                     NaN
# 9                                         NaN                     NaN
# 15                                        NaN                     NaN
# 32                                        NaN                     NaN
# ...                                       ...                     ...
# 5006                                      NaN                     NaN
# 5019                                      NaN                     NaN
# 5031                                      NaN                     NaN
# 5041                                      NaN                     NaN
# 5064                                      NaN                     NaN
#
#      affected_line_break affected_line_breaking_passing_option_attempted  \
# 7                    NaN                                             NaN
# 8                    NaN                                             NaN
# 9                    NaN                                             NaN
# 15                   NaN                                             NaN
# 32                   NaN                                             NaN
# ...                  ...                                             ...
# 5006                 NaN                                             NaN
# 5019                 NaN                                             NaN
# 5031                 NaN                                             NaN
# 5041                 NaN                                             NaN
# 5064                 NaN                                             NaN
#
#       affected_line_breaking_passing_option_xthreat  \
# 7                                               NaN
# 8                                               NaN
# 9                                               NaN
# 15                                              NaN
# 32                                              NaN
# ...                                             ...
# 5006                                            NaN
# 5019                                            NaN
# 5031                                            NaN
# 5041                                            NaN
# 5064                                            NaN
#
#      affected_line_breaking_passing_option_dangerous  \
# 7                                                NaN
# 8                                                NaN
# 9                                                NaN
# 15                                               NaN
# 32                                               NaN
# ...                                              ...
# 5006                                             NaN
# 5019                                             NaN
# 5031                                             NaN
# 5041                                             NaN
# 5064                                             NaN
#
#       affected_line_breaking_passing_option_run_subtype_id  \
# 7                                                      NaN
# 8                                                      NaN
# 9                                                      NaN
# 15                                                     NaN
# 32                                                     NaN
# ...                                                    ...
# 5006                                                   NaN
# 5019                                                   NaN
# 5031                                                   NaN
# 5041                                                   NaN
# 5064                                                   NaN
#
#      affected_line_breaking_passing_option_run_subtype possession_danger  \
# 7                                                  NaN               NaN
# 8                                                  NaN               NaN
# 9                                                  NaN               NaN
# 15                                                 NaN               NaN
# 32                                                 NaN               NaN
# ...                                                ...               ...
# 5006                                               NaN               NaN
# 5019                                               NaN               NaN
# 5031                                               NaN               NaN
# 5041                                               NaN               NaN
# 5064                                               NaN               NaN
#
#      beaten_by_possession beaten_by_movement stop_possession_danger  \
# 7                     NaN                NaN                    NaN
# 8                     NaN                NaN                    NaN
# 9                     NaN                NaN                    NaN
# 15                    NaN                NaN                    NaN
# 32                    NaN                NaN                    NaN
# ...                   ...                ...                    ...
# 5006                  NaN                NaN                    NaN
# 5019                  NaN                NaN                    NaN
# 5031                  NaN                NaN                    NaN
# 5041                  NaN                NaN                    NaN
# 5064                  NaN                NaN                    NaN
#
#      reduce_possession_danger force_backward  xloss_player_possession_start  \
# 7                         NaN            NaN                            NaN
# 8                         NaN            NaN                            NaN
# 9                         NaN            NaN                            NaN
# 15                        NaN            NaN                            NaN
# 32                        NaN            NaN                            NaN
# ...                       ...            ...                            ...
# 5006                      NaN            NaN                            NaN
# 5019                      NaN            NaN                            NaN
# 5031                      NaN            NaN                            NaN
# 5041                      NaN            NaN                            NaN
# 5064                      NaN            NaN                            NaN
#
#       xloss_player_possession_end  xloss_player_possession_max  \
# 7                             NaN                          NaN
# 8                             NaN                          NaN
# 9                             NaN                          NaN
# 15                            NaN                          NaN
# 32                            NaN                          NaN
# ...                           ...                          ...
# 5006                          NaN                          NaN
# 5019                          NaN                          NaN
# 5031                          NaN                          NaN
# 5041                          NaN                          NaN
# 5064                          NaN                          NaN
#
#       xshot_player_possession_start  xshot_player_possession_end  \
# 7                               NaN                          NaN
# 8                               NaN                          NaN
# 9                               NaN                          NaN
# 15                              NaN                          NaN
# 32                              NaN                          NaN
# ...                             ...                          ...
# 5006                            NaN                          NaN
# 5019                            NaN                          NaN
# 5031                            NaN                          NaN
# 5041                            NaN                          NaN
# 5064                            NaN                          NaN
#
#       xshot_player_possession_max  is_player_possession_start_matched  \
# 7                             NaN                                True
# 8                             NaN                                True
# 9                             NaN                                True
# 15                            NaN                                True
# 32                            NaN                                True
# ...                           ...                                 ...
# 5006                          NaN                                True
# 5019                          NaN                                True
# 5031                          NaN                                True
# 5041                          NaN                                True
# 5064                          NaN                                True
#
#       is_player_possession_end_matched is_previous_pass_matched  \
# 7                                 True                      NaN
# 8                                 True                      NaN
# 9                                 True                      NaN
# 15                                True                      NaN
# 32                                True                      NaN
# ...                                ...                      ...
# 5006                              True                      NaN
# 5019                              True                      NaN
# 5031                              True                      NaN
# 5041                              True                      NaN
# 5064                              True                      NaN
#
#      is_pass_reception_matched fully_extrapolated
# 7                          NaN              False
# 8                          NaN              False
# 9                          NaN              False
# 15                        True              False
# 32                        True              False
# ...                        ...                ...
# 5006                       NaN              False
# 5019                      True              False
# 5031                       NaN              False
# 5041                       NaN              False
# 5064                       NaN              False
#
# [595 rows x 294 columns]

# %%
de_match['lead_to_goal'].value_counts()
de_match[de_match['lead_to_goal']==True]['event_type'].value_counts()
# Out:
# event_type
# passing_option        14
# player_possession      6
# on_ball_engagement     6
# off_ball_run           4
# Name: count, dtype: int64

# %%
for event_type in de_match['event_type'].unique():
    dummy_df = de_match[de_match['event_type']==event_type]
    print(event_type)
    print(dummy_df['event_subtype'].unique())
# Out:
# player_possession
# [nan]
# passing_option
# [nan]
# on_ball_engagement
# ['pressing' 'recovery_press' 'pressure' 'counter_press' 'other']
# off_ball_run
# ['pulling_wide' 'coming_short' 'behind' 'support' 'overlap'
#  'cross_receiver' 'dropping_off' 'run_ahead_of_the_ball'
#  'pulling_half_space' 'underlap']

# %%
de_match
# Out:
#      event_id  index  match_id  frame_start  frame_end  frame_physical_start  \
# 0         8_0      0   1886347           28         28                   NaN
# 1         8_1      1   1886347           48         58                   NaN
# 2         7_0      2   1886347           48         53                   NaN
# 3         7_1      3   1886347           48         58                   NaN
# 4         9_0      4   1886347           56         58                  34.0
# ...       ...    ...       ...          ...        ...                   ...
# 5074   7_2541   5074   1886347        58757      58761                   NaN
# 5075    9_936   5075   1886347        58760      58761               58760.0
# 5076    8_998   5076   1886347        58907      58932                   NaN
# 5077   7_2542   5077   1886347        58907      58932                   NaN
# 5078   7_2543   5078   1886347        58907      58932                   NaN
#
#      time_start time_end  minute_start  second_start  duration  period  \
# 0       00:01.8  00:01.8             0             1       0.0       1
# 1       00:03.8  00:04.8             0             3       1.0       1
# 2       00:03.8  00:04.3             0             3       0.5       1
# 3       00:03.8  00:04.8             0             3       1.0       1
# 4       00:02.4  00:04.8             0             2       2.4       1
# ...         ...      ...           ...           ...       ...     ...
# 5074    96:35.7  96:36.1            96            35       0.4       2
# 5075    96:36.0  96:36.1            96            36       0.1       2
# 5076    96:50.7  96:53.2            96            50       2.5       2
# 5077    96:50.7  96:53.2            96            50       2.5       2
# 5078    96:50.7  96:53.2            96            50       2.5       2
#
#       attacking_side_id attacking_side  event_type_id          event_type  \
# 0                     1  left_to_right              8   player_possession
# 1                     1  left_to_right              8   player_possession
# 2                     1  left_to_right              7      passing_option
# 3                     1  left_to_right              7      passing_option
# 4                     2  right_to_left              9  on_ball_engagement
# ...                 ...            ...            ...                 ...
# 5074                  2  right_to_left              7      passing_option
# 5075                  1  left_to_right              9  on_ball_engagement
# 5076                  1  left_to_right              8   player_possession
# 5077                  1  left_to_right              7      passing_option
# 5078                  1  left_to_right              7      passing_option
#
#       event_subtype_id event_subtype  player_id player_name  \
# 0                  NaN           NaN     966120   B. Gibson
# 1                  NaN           NaN      51649  A. Šušnjar
# 2                  NaN           NaN     735574   K. Grozos
# 3                  NaN           NaN     735578    M. Natta
# 4                 11.0      pressing      50951  J. Brimmer
# ...                ...           ...        ...         ...
# 5074               NaN           NaN     795506   C. Taylor
# 5075              15.0         other      43829   N. Moreno
# 5076               NaN           NaN     285188  A. Paulsen
# 5077               NaN           NaN      43829   N. Moreno
# 5078               NaN           NaN     163972     M. Mata
#
#       player_position_id player_position  player_in_possession_id  \
# 0                     19              CF                      NaN
# 1                      4             LCB                      NaN
# 2                     11             RDM                  51649.0
# 3                      2              LB                  51649.0
# 4                     19              CF                  51649.0
# ...                  ...             ...                      ...
# 5074                  19              CF                  51649.0
# 5075                  17              RW                  51649.0
# 5076                   1              GK                      NaN
# 5077                  17              RW                 285188.0
# 5078                  19              CF                 285188.0
#
#      player_in_possession_name  player_in_possession_position_id  \
# 0                          NaN                               NaN
# 1                          NaN                               NaN
# 2                   A. Šušnjar                               4.0
# 3                   A. Šušnjar                               4.0
# 4                   A. Šušnjar                               4.0
# ...                        ...                               ...
# 5074                A. Šušnjar                               4.0
# 5075                A. Šušnjar                               4.0
# 5076                       NaN                               NaN
# 5077                A. Paulsen                               1.0
# 5078                A. Paulsen                               1.0
#
#      player_in_possession_position  team_id team_shortname  x_start  y_start  \
# 0                              NaN     1805      Newcastle     0.73     0.49
# 1                              NaN     1805      Newcastle   -22.31     1.22
# 2                              LCB     1805      Newcastle   -10.47    -2.78
# 3                              LCB     1805      Newcastle   -20.69    16.66
# 4                              LCB     4177    Auckland FC    13.03     0.06
# ...                            ...      ...            ...      ...      ...
# 5074                           LCB     1805      Newcastle    31.25     8.32
# 5075                           LCB     4177    Auckland FC   -21.73    -3.68
# 5076                           NaN     4177    Auckland FC   -40.36   -12.23
# 5077                            GK     4177    Auckland FC    -1.58   -26.68
# 5078                            GK     4177    Auckland FC     6.12   -18.07
#
#       channel_id_start     channel_start  third_id_start      third_start  \
# 0                    3            center               2     middle_third
# 1                    3            center               1  defensive_third
# 2                    3            center               2     middle_third
# 3                    2   half_space_left               1  defensive_third
# 4                    3            center               2     middle_third
# ...                ...               ...             ...              ...
# 5074                 3            center               3  attacking_third
# 5075                 3            center               1  defensive_third
# 5076                 4  half_space_right               1  defensive_third
# 5077                 5        wide_right               2     middle_third
# 5078                 4  half_space_right               2     middle_third
#
#       penalty_area_start  x_end  y_end  channel_id_end       channel_end  \
# 0                  False   0.73   0.49               3            center
# 1                  False -22.21   2.70               3            center
# 2                  False -11.36  -1.38               3            center
# 3                  False -20.36  17.69               2   half_space_left
# 4                  False  13.98  -0.68               3            center
# ...                  ...    ...    ...             ...               ...
# 5074               False  31.39   9.17               2   half_space_left
# 5075               False -21.77  -3.74               3            center
# 5076               False -37.73 -18.48               4  half_space_right
# 5077               False  -0.49 -29.93               5        wide_right
# 5078               False   9.24 -23.32               5        wide_right
#
#       third_id_end        third_end  penalty_area_end  \
# 0                2     middle_third             False
# 1                1  defensive_third             False
# 2                2     middle_third             False
# 3                1  defensive_third             False
# 4                2     middle_third             False
# ...            ...              ...               ...
# 5074             3  attacking_third             False
# 5075             1  defensive_third             False
# 5076             1  defensive_third             False
# 5077             2     middle_third             False
# 5078             2     middle_third             False
#
#      associated_player_possession_event_id  \
# 0                                      NaN
# 1                                      NaN
# 2                                      8_1
# 3                                      8_1
# 4                                      8_1
# ...                                    ...
# 5074                                 8_997
# 5075                                 8_997
# 5076                                   NaN
# 5077                                 8_998
# 5078                                 8_998
#
#       associated_player_possession_frame_start  \
# 0                                          NaN
# 1                                          NaN
# 2                                         48.0
# 3                                         48.0
# 4                                         48.0
# ...                                        ...
# 5074                                   58733.0
# 5075                                   58733.0
# 5076                                       NaN
# 5077                                   58907.0
# 5078                                   58907.0
#
#       associated_player_possession_frame_end  \
# 0                                        NaN
# 1                                        NaN
# 2                                        NaN
# 3                                        NaN
# 4                                       58.0
# ...                                      ...
# 5074                                     NaN
# 5075                                 58761.0
# 5076                                     NaN
# 5077                                     NaN
# 5078                                     NaN
#
#       associated_player_possession_end_type_id  \
# 0                                          NaN
# 1                                          NaN
# 2                                          NaN
# 3                                          NaN
# 4                                          1.0
# ...                                        ...
# 5074                                       NaN
# 5075                                       2.0
# 5076                                       NaN
# 5077                                       NaN
# 5078                                       NaN
#
#      associated_player_possession_end_type associated_off_ball_run_event_id  \
# 0                                      NaN                              NaN
# 1                                      NaN                              NaN
# 2                                      NaN                              NaN
# 3                                      NaN                              NaN
# 4                                     pass                              NaN
# ...                                    ...                              ...
# 5074                                   NaN                              NaN
# 5075                                  shot                              NaN
# 5076                                   NaN                              NaN
# 5077                                   NaN                              NaN
# 5078                                   NaN                              NaN
#
#       associated_off_ball_run_subtype_id associated_off_ball_run_subtype  \
# 0                                    NaN                             NaN
# 1                                    NaN                             NaN
# 2                                    NaN                             NaN
# 3                                    NaN                             NaN
# 4                                    NaN                             NaN
# ...                                  ...                             ...
# 5074                                 NaN                             NaN
# 5075                                 NaN                             NaN
# 5076                                 NaN                             NaN
# 5077                                 NaN                             NaN
# 5078                                 NaN                             NaN
#
#       game_state_id game_state  team_score  opponent_team_score  phase_index  \
# 0                 3    drawing           0                    0            0
# 1                 3    drawing           0                    0            0
# 2                 3    drawing           0                    0            0
# 3                 3    drawing           0                    0            0
# 4                 3    drawing           0                    0            0
# ...             ...        ...         ...                  ...          ...
# 5074              2     losing           0                    2          452
# 5075              1    winning           2                    0          452
# 5076              1    winning           2                    0          453
# 5077              1    winning           2                    0          453
# 5078              1    winning           2                    0          453
#
#       player_possession_phase_index  \
# 0                               1.0
# 1                               2.0
# 2                               NaN
# 3                               NaN
# 4                               NaN
# ...                             ...
# 5074                            NaN
# 5075                            NaN
# 5076                            1.0
# 5077                            NaN
# 5078                            NaN
#
#      first_player_possession_in_team_possession  \
# 0                                          True
# 1                                         False
# 2                                           NaN
# 3                                           NaN
# 4                                           NaN
# ...                                         ...
# 5074                                        NaN
# 5075                                        NaN
# 5076                                       True
# 5077                                        NaN
# 5078                                        NaN
#
#      last_player_possession_in_team_possession lead_to_different_phase  \
# 0                                        False                   False
# 1                                        False                    True
# 2                                          NaN                     NaN
# 3                                          NaN                     NaN
# 4                                          NaN                     NaN
# ...                                        ...                     ...
# 5074                                       NaN                     NaN
# 5075                                       NaN                     NaN
# 5076                                      True                    True
# 5077                                       NaN                     NaN
# 5078                                       NaN                     NaN
#
#      issued_from_different_phase  n_player_possessions_in_phase  \
# 0                           True                            3.0
# 1                          False                            3.0
# 2                            NaN                            NaN
# 3                            NaN                            NaN
# 4                            NaN                            NaN
# ...                          ...                            ...
# 5074                         NaN                            NaN
# 5075                         NaN                            NaN
# 5076                        True                            1.0
# 5077                         NaN                            NaN
# 5078                         NaN                            NaN
#
#      team_possession_loss_in_phase  team_in_possession_phase_type_id  \
# 0                            False                                 1
# 1                            False                                 1
# 2                              NaN                                 1
# 3                              NaN                                 1
# 4                            False                                 1
# ...                            ...                               ...
# 5074                           NaN                                 2
# 5075                          True                                 2
# 5076                         False                                 5
# 5077                           NaN                                 5
# 5078                           NaN                                 5
#
#      team_in_possession_phase_type  team_out_of_possession_phase_type_id  \
# 0                           create                                     9
# 1                           create                                     9
# 2                           create                                     9
# 3                           create                                     9
# 4                           create                                     9
# ...                            ...                                   ...
# 5074                        finish                                     8
# 5075                        finish                                     8
# 5076                       chaotic                                     5
# 5077                       chaotic                                     5
# 5078                       chaotic                                     5
#
#      team_out_of_possession_phase_type  \
# 0                         medium_block
# 1                         medium_block
# 2                         medium_block
# 3                         medium_block
# 4                         medium_block
# ...                                ...
# 5074                         low_block
# 5075                         low_block
# 5076                           chaotic
# 5077                           chaotic
# 5078                           chaotic
#
#       current_team_in_possession_next_phase_type_id  \
# 0                                               6.0
# 1                                               6.0
# 2                                               NaN
# 3                                               NaN
# 4                                               NaN
# ...                                             ...
# 5074                                            NaN
# 5075                                            NaN
# 5076                                            NaN
# 5077                                            NaN
# 5078                                            NaN
#
#      current_team_in_possession_next_phase_type  \
# 0                                        direct
# 1                                        direct
# 2                                           NaN
# 3                                           NaN
# 4                                           NaN
# ...                                         ...
# 5074                                        NaN
# 5075                                        NaN
# 5076                                        NaN
# 5077                                        NaN
# 5078                                        NaN
#
#       current_team_out_of_possession_next_phase_type_id  \
# 0                                                  15.0
# 1                                                  15.0
# 2                                                   NaN
# 3                                                   NaN
# 4                                                   NaN
# ...                                                 ...
# 5074                                                NaN
# 5075                                                NaN
# 5076                                                NaN
# 5077                                                NaN
# 5078                                                NaN
#
#      current_team_out_of_possession_next_phase_type  \
# 0                                  defending_direct
# 1                                  defending_direct
# 2                                               NaN
# 3                                               NaN
# 4                                               NaN
# ...                                             ...
# 5074                                            NaN
# 5075                                            NaN
# 5076                                            NaN
# 5077                                            NaN
# 5078                                            NaN
#
#       current_team_in_possession_previous_phase_type_id  \
# 0                                                   NaN
# 1                                                   NaN
# 2                                                   NaN
# 3                                                   NaN
# 4                                                   NaN
# ...                                                 ...
# 5074                                                NaN
# 5075                                                NaN
# 5076                                                8.0
# 5077                                                NaN
# 5078                                                NaN
#
#      current_team_in_possession_previous_phase_type  \
# 0                                               NaN
# 1                                               NaN
# 2                                               NaN
# 3                                               NaN
# 4                                               NaN
# ...                                             ...
# 5074                                            NaN
# 5075                                            NaN
# 5076                                      low_block
# 5077                                            NaN
# 5078                                            NaN
#
#       current_team_out_of_possession_previous_phase_type_id  \
# 0                                                       NaN
# 1                                                       NaN
# 2                                                       NaN
# 3                                                       NaN
# 4                                                       NaN
# ...                                                     ...
# 5074                                                    NaN
# 5075                                                    NaN
# 5076                                                    2.0
# 5077                                                    NaN
# 5078                                                    NaN
#
#      current_team_out_of_possession_previous_phase_type  \
# 0                                                   NaN
# 1                                                   NaN
# 2                                                   NaN
# 3                                                   NaN
# 4                                                   NaN
# ...                                                 ...
# 5074                                                NaN
# 5075                                                NaN
# 5076                                             finish
# 5077                                                NaN
# 5078                                                NaN
#
#       game_interruption_before_id game_interruption_before  \
# 0                             NaN                      NaN
# 1                             NaN                      NaN
# 2                             NaN                      NaN
# 3                             NaN                      NaN
# 4                             NaN                      NaN
# ...                           ...                      ...
# 5074                          NaN                      NaN
# 5075                          NaN                      NaN
# 5076                          NaN                      NaN
# 5077                          NaN                      NaN
# 5078                          NaN                      NaN
#
#       game_interruption_after_id game_interruption_after  lead_to_shot  \
# 0                            NaN                     NaN         False
# 1                            NaN                     NaN         False
# 2                            NaN                     NaN         False
# 3                            NaN                     NaN         False
# 4                            NaN                     NaN         False
# ...                          ...                     ...           ...
# 5074                         NaN                     NaN          True
# 5075                         NaN                     NaN          True
# 5076                         NaN                     NaN         False
# 5077                         NaN                     NaN         False
# 5078                         NaN                     NaN         False
#
#       lead_to_goal  distance_covered  trajectory_angle  \
# 0            False              0.00            150.26
# 1            False              1.49             86.13
# 2            False              1.31            122.44
# 3            False              1.09             72.24
# 4            False             14.45            -36.69
# ...            ...               ...               ...
# 5074         False              0.86             81.42
# 5075         False              0.18           -120.58
# 5076         False              7.13            -67.18
# 5077         False              3.33            -71.46
# 5078         False              5.88            -59.28
#
#       trajectory_direction_id trajectory_direction in_to_out out_to_in  \
# 0                         2.0             backward       NaN       NaN
# 1                         3.0         sideway_left       NaN       NaN
# 2                         3.0         sideway_left     False     False
# 3                         3.0         sideway_left     False     False
# 4                         1.0              forward       NaN       NaN
# ...                       ...                  ...       ...       ...
# 5074                      3.0         sideway_left      True     False
# 5075                      4.0        sideway_right       NaN       NaN
# 5076                      4.0        sideway_right     False     False
# 5077                      4.0        sideway_right     False     False
# 5078                      4.0        sideway_right      True     False
#
#       speed_avg  speed_avg_band_id speed_avg_band  separation_start  \
# 0          2.24                1.0        jogging              8.66
# 1          5.34                1.0        jogging             14.22
# 2         11.89                1.0        jogging              1.74
# 3          3.96                1.0        jogging             17.17
# 4         21.52                3.0            hsr               NaN
# ...         ...                ...            ...               ...
# 5074       7.66                1.0        jogging              3.47
# 5075       1.92                1.0        jogging               NaN
# 5076      10.54                1.0        jogging             22.57
# 5077        NaN                NaN            NaN              8.48
# 5078        NaN                NaN            NaN              3.54
#
#       separation_end  separation_gain  last_defensive_line_x_start  \
# 0               8.66             0.00                        17.93
# 1               8.47            -5.74                        18.17
# 2               0.22            -1.52                        18.17
# 3               7.73            -9.44                        18.17
# 4                NaN              NaN                       -18.94
# ...              ...              ...                          ...
# 5074            3.42            -0.04                        32.02
# 5075             NaN              NaN                       -32.34
# 5076           12.93            -9.64                         6.74
# 5077            9.71             1.23                         6.74
# 5078            2.39            -1.15                         6.74
#
#       last_defensive_line_x_end  delta_to_last_defensive_line_start  \
# 0                         17.93                               17.20
# 1                         19.11                               40.48
# 2                         18.61                               28.64
# 3                         19.11                               38.86
# 4                        -19.11                               31.97
# ...                         ...                                 ...
# 5074                      32.47                                0.77
# 5075                     -32.47                               10.61
# 5076                       9.84                               47.10
# 5077                       9.84                                8.32
# 5078                       9.84                                0.62
#
#       delta_to_last_defensive_line_end  delta_to_last_defensive_line_gain  \
# 0                                17.20                               0.00
# 1                                41.32                               0.84
# 2                                29.97                               1.33
# 3                                39.47                               0.61
# 4                                33.09                               1.12
# ...                                ...                                ...
# 5074                              1.08                               0.31
# 5075                             10.70                               0.09
# 5076                             47.57                               0.47
# 5077                             10.33                               2.01
# 5078                              0.60                              -0.02
#
#       last_defensive_line_height_start  last_defensive_line_height_end  \
# 0                                34.07                           34.07
# 1                                33.83                           32.89
# 2                                33.83                           33.39
# 3                                33.83                           32.89
# 4                                33.06                           32.89
# ...                                ...                             ...
# 5074                             19.98                           19.53
# 5075                             19.66                           19.53
# 5076                             45.26                           42.16
# 5077                             45.26                           42.16
# 5078                             45.26                           42.16
#
#       last_defensive_line_height_gain inside_defensive_shape_start  \
# 0                                0.00                         True
# 1                               -0.94                        False
# 2                               -0.44                        False
# 3                               -0.94                        False
# 4                               -0.17                          NaN
# ...                               ...                          ...
# 5074                            -0.45                         True
# 5075                            -0.13                          NaN
# 5076                            -3.10                        False
# 5077                            -3.10                        False
# 5078                            -3.10                        False
#
#      inside_defensive_shape_end  start_type_id      start_type  end_type_id  \
# 0                          True           13.0         unknown          1.0
# 1                         False            1.0  pass_reception          1.0
# 2                         False            NaN             NaN          NaN
# 3                         False            NaN             NaN          NaN
# 4                           NaN            NaN             NaN          NaN
# ...                         ...            ...             ...          ...
# 5074                       True            NaN             NaN          NaN
# 5075                        NaN            NaN             NaN          8.0
# 5076                      False           13.0         unknown          1.0
# 5077                      False            NaN             NaN          NaN
# 5078                      False            NaN             NaN          NaN
#
#              end_type consecutive_on_ball_engagements one_touch quick_pass  \
# 0                pass                             NaN      True      False
# 1                pass                             NaN     False       True
# 2                 NaN                             NaN       NaN        NaN
# 3                 NaN                             NaN       NaN        NaN
# 4                 NaN                           False       NaN        NaN
# ...               ...                             ...       ...        ...
# 5074              NaN                             NaN       NaN        NaN
# 5075  indirect_regain                           False       NaN        NaN
# 5076             pass                             NaN     False      False
# 5077              NaN                             NaN       NaN        NaN
# 5078              NaN                             NaN       NaN        NaN
#
#       carry forward_momentum is_header hand_pass initiate_give_and_go  \
# 0     False            False     False     False                False
# 1     False            False     False     False                False
# 2       NaN              NaN       NaN       NaN                  NaN
# 3       NaN              NaN       NaN       NaN                  NaN
# 4       NaN              NaN       NaN       NaN                  NaN
# ...     ...              ...       ...       ...                  ...
# 5074    NaN              NaN       NaN       NaN                  NaN
# 5075    NaN              NaN       NaN       NaN                  NaN
# 5076   True            False     False     False                False
# 5077    NaN              NaN       NaN       NaN                  NaN
# 5078    NaN              NaN       NaN       NaN                  NaN
#
#       pass_angle_received  pass_direction_received_id pass_direction_received  \
# 0                     NaN                         NaN                     NaN
# 1                 -179.78                         2.0                backward
# 2                     NaN                         NaN                     NaN
# 3                     NaN                         NaN                     NaN
# 4                     NaN                         NaN                     NaN
# ...                   ...                         ...                     ...
# 5074                  NaN                         NaN                     NaN
# 5075                  NaN                         NaN                     NaN
# 5076                  NaN                         NaN                     NaN
# 5077                  NaN                         NaN                     NaN
# 5078                  NaN                         NaN                     NaN
#
#       pass_distance_received  pass_range_received_id pass_range_received  \
# 0                        NaN                     NaN                 NaN
# 1                      26.02                     2.0              medium
# 2                        NaN                     NaN                 NaN
# 3                        NaN                     NaN                 NaN
# 4                        NaN                     NaN                 NaN
# ...                      ...                     ...                 ...
# 5074                     NaN                     NaN                 NaN
# 5075                     NaN                     NaN                 NaN
# 5076                     NaN                     NaN                 NaN
# 5077                     NaN                     NaN                 NaN
# 5078                     NaN                     NaN                 NaN
#
#       pass_outcome_id  pass_outcome targeted_passing_option_event_id  \
# 0                 1.0    successful                              NaN
# 1                 1.0    successful                              7_1
# 2                 NaN           NaN                              NaN
# 3                 NaN           NaN                              NaN
# 4                 NaN           NaN                              NaN
# ...               ...           ...                              ...
# 5074              NaN           NaN                              NaN
# 5075              NaN           NaN                              NaN
# 5076              2.0  unsuccessful                           7_2542
# 5077              NaN           NaN                              NaN
# 5078              NaN           NaN                              NaN
#
#      high_pass  player_targeted_id player_targeted_name  \
# 0          NaN             51649.0           A. Šušnjar
# 1        False            735578.0             M. Natta
# 2          NaN                 NaN                  NaN
# 3        False                 NaN                  NaN
# 4          NaN             51649.0           A. Šušnjar
# ...        ...                 ...                  ...
# 5074       NaN                 NaN                  NaN
# 5075       NaN             51649.0           A. Šušnjar
# 5076       NaN             43829.0            N. Moreno
# 5077       NaN                 NaN                  NaN
# 5078       NaN                 NaN                  NaN
#
#       player_targeted_position_id player_targeted_position  \
# 0                             4.0                      LCB
# 1                             2.0                       LB
# 2                             NaN                      NaN
# 3                             NaN                      NaN
# 4                             4.0                      LCB
# ...                           ...                      ...
# 5074                          NaN                      NaN
# 5075                          4.0                      LCB
# 5076                         17.0                       RW
# 5077                          NaN                      NaN
# 5078                          NaN                      NaN
#
#       player_targeted_x_pass  player_targeted_y_pass  \
# 0                     -21.72                    0.22
# 1                     -20.36                   17.69
# 2                        NaN                     NaN
# 3                        NaN                     NaN
# 4                        NaN                     NaN
# ...                      ...                     ...
# 5074                     NaN                     NaN
# 5075                     NaN                     NaN
# 5076                   -0.49                  -29.93
# 5077                     NaN                     NaN
# 5078                     NaN                     NaN
#
#       player_targeted_channel_pass_id player_targeted_channel_pass  \
# 0                                 3.0                       center
# 1                                 2.0              half_space_left
# 2                                 NaN                          NaN
# 3                                 NaN                          NaN
# 4                                 NaN                          NaN
# ...                               ...                          ...
# 5074                              NaN                          NaN
# 5075                              NaN                          NaN
# 5076                              5.0                   wide_right
# 5077                              NaN                          NaN
# 5078                              NaN                          NaN
#
#       player_targeted_third_pass_id player_targeted_third_pass  \
# 0                               1.0            defensive_third
# 1                               1.0            defensive_third
# 2                               NaN                        NaN
# 3                               NaN                        NaN
# 4                               NaN                        NaN
# ...                             ...                        ...
# 5074                            NaN                        NaN
# 5075                            NaN                        NaN
# 5076                            2.0               middle_third
# 5077                            NaN                        NaN
# 5078                            NaN                        NaN
#
#      player_targeted_penalty_area_pass  player_targeted_x_reception  \
# 0                                False                       -22.31
# 1                                False                       -17.60
# 2                                  NaN                          NaN
# 3                                  NaN                          NaN
# 4                                  NaN                          NaN
# ...                                ...                          ...
# 5074                               NaN                          NaN
# 5075                               NaN                          NaN
# 5076                             False                          NaN
# 5077                               NaN                          NaN
# 5078                               NaN                          NaN
#
#       player_targeted_y_reception  player_targeted_channel_reception_id  \
# 0                            1.22                                   3.0
# 1                           20.17                                   1.0
# 2                             NaN                                   NaN
# 3                             NaN                                   NaN
# 4                             NaN                                   NaN
# ...                           ...                                   ...
# 5074                          NaN                                   NaN
# 5075                          NaN                                   NaN
# 5076                          NaN                                   NaN
# 5077                          NaN                                   NaN
# 5078                          NaN                                   NaN
#
#      player_targeted_channel_reception  player_targeted_third_reception_id  \
# 0                               center                                 1.0
# 1                            wide_left                                 1.0
# 2                                  NaN                                 NaN
# 3                                  NaN                                 NaN
# 4                                  NaN                                 NaN
# ...                                ...                                 ...
# 5074                               NaN                                 NaN
# 5075                               NaN                                 NaN
# 5076                               NaN                                 NaN
# 5077                               NaN                                 NaN
# 5078                               NaN                                 NaN
#
#      player_targeted_third_reception player_targeted_penalty_area_reception  \
# 0                    defensive_third                                  False
# 1                    defensive_third                                  False
# 2                                NaN                                    NaN
# 3                                NaN                                    NaN
# 4                                NaN                                    NaN
# ...                              ...                                    ...
# 5074                             NaN                                    NaN
# 5075                             NaN                                    NaN
# 5076                             NaN                                    NaN
# 5077                             NaN                                    NaN
# 5078                             NaN                                    NaN
#
#       player_targeted_distance_to_goal_start  \
# 0                                        NaN
# 1                                        NaN
# 2                                        NaN
# 3                                        NaN
# 4                                      74.24
# ...                                      ...
# 5074                                     NaN
# 5075                                   35.51
# 5076                                     NaN
# 5077                                     NaN
# 5078                                     NaN
#
#       player_targeted_distance_to_goal_end  \
# 0                                      NaN
# 1                                      NaN
# 2                                      NaN
# 3                                      NaN
# 4                                    74.26
# ...                                    ...
# 5074                                   NaN
# 5075                                 35.05
# 5076                                   NaN
# 5077                                   NaN
# 5078                                   NaN
#
#       player_targeted_angle_to_goal_start  player_targeted_angle_to_goal_end  \
# 0                                     NaN                                NaN
# 1                                     NaN                                NaN
# 2                                     NaN                                NaN
# 3                                     NaN                                NaN
# 4                                  178.20                             177.92
# ...                                   ...                                ...
# 5074                                  NaN                                NaN
# 5075                               178.08                             177.58
# 5076                                  NaN                                NaN
# 5077                                  NaN                                NaN
# 5078                                  NaN                                NaN
#
#       player_targeted_average_speed  player_targeted_speed_avg_band_id  \
# 0                               NaN                                NaN
# ...
# 3                     NaN                     NaN
# 4                     NaN                     NaN
# ...                   ...                     ...
# 5074                  NaN                     NaN
# 5075                  NaN                     NaN
# 5076                  NaN                     NaN
# 5077                  NaN                     NaN
# 5078                  NaN                     NaN
#
#       n_simultaneous_passing_options passing_option_at_pass_moment  \
# 0                                NaN                           NaN
# 1                                NaN                           NaN
# 2                                1.0                          True
# 3                                1.0                          True
# 4                                NaN                           NaN
# ...                              ...                           ...
# 5074                             2.0                         False
# 5075                             NaN                           NaN
# 5076                             NaN                           NaN
# 5077                             1.0                          True
# 5078                             1.0                          True
#
#       n_opponents_ahead_end  n_opponents_ahead_start  n_opponents_overtaken  \
# 0                       9.0                      9.0                    0.0
# 1                      10.0                     10.0                    0.0
# 2                       NaN                      NaN                    NaN
# 3                       NaN                      NaN                    NaN
# 4                       NaN                      NaN                    NaN
# ...                     ...                      ...                    ...
# 5074                    NaN                      NaN                    NaN
# 5075                    NaN                      NaN                    NaN
# 5076                   10.0                     10.0                    0.0
# 5077                    NaN                      NaN                    NaN
# 5078                    NaN                      NaN                    NaN
#
#      pressing_chain  pressing_chain_length  pressing_chain_end_type_id  \
# 0               NaN                    NaN                         NaN
# 1               NaN                    NaN                         NaN
# 2               NaN                    NaN                         NaN
# 3               NaN                    NaN                         NaN
# 4              True                    2.0                         2.0
# ...             ...                    ...                         ...
# 5074            NaN                    NaN                         NaN
# 5075          False                    NaN                         NaN
# 5076            NaN                    NaN                         NaN
# 5077            NaN                    NaN                         NaN
# 5078            NaN                    NaN                         NaN
#
#      pressing_chain_end_type  pressing_chain_index  index_in_pressing_chain  \
# 0                        NaN                   NaN                      NaN
# 1                        NaN                   NaN                      NaN
# 2                        NaN                   NaN                      NaN
# 3                        NaN                   NaN                      NaN
# 4                 disruption                   0.0                      1.0
# ...                      ...                   ...                      ...
# 5074                     NaN                   NaN                      NaN
# 5075                     NaN                   NaN                      NaN
# 5076                     NaN                   NaN                      NaN
# 5077                     NaN                   NaN                      NaN
# 5078                     NaN                   NaN                      NaN
#
#      simultaneous_defensive_engagement_same_target  \
# 0                                              NaN
# 1                                              NaN
# 2                                              NaN
# 3                                              NaN
# 4                                            False
# ...                                            ...
# 5074                                           NaN
# 5075                                          True
# 5076                                           NaN
# 5077                                           NaN
# 5078                                           NaN
#
#       simultaneous_defensive_engagement_same_target_rank  \
# 0                                                    NaN
# 1                                                    NaN
# 2                                                    NaN
# 3                                                    NaN
# 4                                                    NaN
# ...                                                  ...
# 5074                                                 NaN
# 5075                                                 2.0
# 5076                                                 NaN
# 5077                                                 NaN
# 5078                                                 NaN
#
#      affected_line_breaking_passing_option_id  affected_line_break_id  \
# 0                                         NaN                     NaN
# 1                                         NaN                     NaN
# 2                                         NaN                     NaN
# 3                                         NaN                     NaN
# 4                                         NaN                     NaN
# ...                                       ...                     ...
# 5074                                      NaN                     NaN
# 5075                                      NaN                     NaN
# 5076                                      NaN                     NaN
# 5077                                      NaN                     NaN
# 5078                                      NaN                     NaN
#
#      affected_line_break affected_line_breaking_passing_option_attempted  \
# 0                    NaN                                             NaN
# 1                    NaN                                             NaN
# 2                    NaN                                             NaN
# 3                    NaN                                             NaN
# 4                    NaN                                             NaN
# ...                  ...                                             ...
# 5074                 NaN                                             NaN
# 5075                 NaN                                             NaN
# 5076                 NaN                                             NaN
# 5077                 NaN                                             NaN
# 5078                 NaN                                             NaN
#
#       affected_line_breaking_passing_option_xthreat  \
# 0                                               NaN
# 1                                               NaN
# 2                                               NaN
# 3                                               NaN
# 4                                               NaN
# ...                                             ...
# 5074                                            NaN
# 5075                                            NaN
# 5076                                            NaN
# 5077                                            NaN
# 5078                                            NaN
#
#      affected_line_breaking_passing_option_dangerous  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
# ...                                              ...
# 5074                                             NaN
# 5075                                             NaN
# 5076                                             NaN
# 5077                                             NaN
# 5078                                             NaN
#
#       affected_line_breaking_passing_option_run_subtype_id  \
# 0                                                      NaN
# 1                                                      NaN
# 2                                                      NaN
# 3                                                      NaN
# 4                                                      NaN
# ...                                                    ...
# 5074                                                   NaN
# 5075                                                   NaN
# 5076                                                   NaN
# 5077                                                   NaN
# 5078                                                   NaN
#
#      affected_line_breaking_passing_option_run_subtype possession_danger  \
# 0                                                  NaN               NaN
# 1                                                  NaN               NaN
# 2                                                  NaN               NaN
# 3                                                  NaN               NaN
# 4                                                  NaN             False
# ...                                                ...               ...
# 5074                                               NaN               NaN
# 5075                                               NaN              True
# 5076                                               NaN               NaN
# 5077                                               NaN               NaN
# 5078                                               NaN               NaN
#
#      beaten_by_possession beaten_by_movement stop_possession_danger  \
# 0                     NaN                NaN                    NaN
# 1                     NaN                NaN                    NaN
# 2                     NaN                NaN                    NaN
# 3                     NaN                NaN                    NaN
# 4                   False              False                  False
# ...                   ...                ...                    ...
# 5074                  NaN                NaN                    NaN
# 5075                False              False                  False
# 5076                  NaN                NaN                    NaN
# 5077                  NaN                NaN                    NaN
# 5078                  NaN                NaN                    NaN
#
#      reduce_possession_danger force_backward  xloss_player_possession_start  \
# 0                         NaN            NaN                            NaN
# 1                         NaN            NaN                            NaN
# 2                         NaN            NaN                            NaN
# 3                         NaN            NaN                            NaN
# 4                       False          False                            NaN
# ...                       ...            ...                            ...
# 5074                      NaN            NaN                            NaN
# 5075                    False          False                          0.071
# 5076                      NaN            NaN                            NaN
# 5077                      NaN            NaN                            NaN
# 5078                      NaN            NaN                            NaN
#
#       xloss_player_possession_end  xloss_player_possession_max  \
# 0                             NaN                          NaN
# 1                             NaN                          NaN
# 2                             NaN                          NaN
# 3                             NaN                          NaN
# 4                             NaN                          NaN
# ...                           ...                          ...
# 5074                          NaN                          NaN
# 5075                        0.402                        0.402
# 5076                          NaN                          NaN
# 5077                          NaN                          NaN
# 5078                          NaN                          NaN
#
#       xshot_player_possession_start  xshot_player_possession_end  \
# 0                               NaN                          NaN
# 1                               NaN                          NaN
# 2                               NaN                          NaN
# 3                               NaN                          NaN
# 4                               NaN                          NaN
# ...                             ...                          ...
# 5074                            NaN                          NaN
# 5075                          0.004                        0.231
# 5076                            NaN                          NaN
# 5077                            NaN                          NaN
# 5078                            NaN                          NaN
#
#       xshot_player_possession_max  is_player_possession_start_matched  \
# 0                             NaN                                True
# 1                             NaN                                True
# 2                             NaN                                True
# 3                             NaN                                True
# 4                             NaN                                True
# ...                           ...                                 ...
# 5074                          NaN                                True
# 5075                        0.402                                True
# 5076                          NaN                                True
# 5077                          NaN                                True
# 5078                          NaN                                True
#
#       is_player_possession_end_matched is_previous_pass_matched  \
# 0                                 True                      NaN
# 1                                 True                     True
# 2                                 True                      NaN
# 3                                 True                      NaN
# 4                                 True                     True
# ...                                ...                      ...
# 5074                              True                      NaN
# 5075                              True                     True
# 5076                              True                      NaN
# 5077                              True                      NaN
# 5078                              True                      NaN
#
#      is_pass_reception_matched fully_extrapolated
# 0                         True              False
# 1                         True              False
# 2                          NaN              False
# 3                         True              False
# 4                         True                NaN
# ...                        ...                ...
# 5074                       NaN              False
# 5075                       NaN                NaN
# 5076                       NaN              False
# 5077                       NaN               True
# 5078                       NaN               True
#
# [5079 rows x 294 columns]

# %%
specific_event = de_match[de_match.event_id == "8_3"][
    [
        "player_id",
        "frame_start",
        "frame_end",
        "event_type",
        "team_id",
        "player_in_possession_id",
        "x_start",
        "y_start",
        "x_end",
        "y_end",
    ]
]

synced = specific_event.merge(
    enriched_tracking_data,
    left_on=["frame_end"],
    right_on="frame",
    suffixes=("_event", "_tracking"),
)

synced["runner"] = synced.player_id_event == synced.player_id_tracking
synced["ball_carrier"] = synced.player_in_possession_id == synced.player_id_tracking
synced["tip"] = synced.team_id_event == synced.team_id_tracking

synced
# Out:
#     player_id_event  frame_start frame_end         event_type  team_id_event  \
# 0             33697          202       229  player_possession           4177
# 1             33697          202       229  player_possession           4177
# 2             33697          202       229  player_possession           4177
# 3             33697          202       229  player_possession           4177
# 4             33697          202       229  player_possession           4177
# 5             33697          202       229  player_possession           4177
# 6             33697          202       229  player_possession           4177
# 7             33697          202       229  player_possession           4177
# 8             33697          202       229  player_possession           4177
# 9             33697          202       229  player_possession           4177
# 10            33697          202       229  player_possession           4177
# 11            33697          202       229  player_possession           4177
# 12            33697          202       229  player_possession           4177
# 13            33697          202       229  player_possession           4177
# 14            33697          202       229  player_possession           4177
# 15            33697          202       229  player_possession           4177
# 16            33697          202       229  player_possession           4177
# 17            33697          202       229  player_possession           4177
# 18            33697          202       229  player_possession           4177
# 19            33697          202       229  player_possession           4177
# 20            33697          202       229  player_possession           4177
# 21            33697          202       229  player_possession           4177
#
#     player_in_possession_id  x_start  y_start  x_end  y_end      x      y  \
# 0                       NaN   -27.84      6.4 -23.05  13.87 -36.61  -2.57
# 1                       NaN   -27.84      6.4 -23.05  13.87  -9.34  -9.73
# 2                       NaN   -27.84      6.4 -23.05  13.87  -9.36  -0.22
# 3                       NaN   -27.84      6.4 -23.05  13.87  -6.76 -18.47
# 4                       NaN   -27.84      6.4 -23.05  13.87  -9.20  10.26
# 5                       NaN   -27.84      6.4 -23.05  13.87  -1.26  -1.32
# 6                       NaN   -27.84      6.4 -23.05  13.87   1.98 -11.19
# 7                       NaN   -27.84      6.4 -23.05  13.87  12.83   0.76
# 8                       NaN   -27.84      6.4 -23.05  13.87   8.15 -20.23
# 9                       NaN   -27.84      6.4 -23.05  13.87   7.63  15.78
# 10                      NaN   -27.84      6.4 -23.05  13.87  14.35 -11.71
# 11                      NaN   -27.84      6.4 -23.05  13.87  41.38  -2.87
# 12                      NaN   -27.84      6.4 -23.05  13.87  25.03   6.86
# 13                      NaN   -27.84      6.4 -23.05  13.87  23.05 -13.87
# 14                      NaN   -27.84      6.4 -23.05  13.87  12.52  20.24
# 15                      NaN   -27.84      6.4 -23.05  13.87  10.82 -30.43
# 16                      NaN   -27.84      6.4 -23.05  13.87   9.56   5.37
# 17                      NaN   -27.84      6.4 -23.05  13.87   9.09 -10.82
# 18                      NaN   -27.84      6.4 -23.05  13.87  -3.14  20.15
# 19                      NaN   -27.84      6.4 -23.05  13.87  -2.21 -19.90
# 20                      NaN   -27.84      6.4 -23.05  13.87  -1.27  -2.91
# 21                      NaN   -27.84      6.4 -23.05  13.87  -8.92   4.45
#
#     player_id_tracking  is_detected frame               timestamp period  \
# 0                51009        False   229 2025-10-27 00:00:21.900    1.0
# 1               176224        False   229 2025-10-27 00:00:21.900    1.0
# 2                51649        False   229 2025-10-27 00:00:21.900    1.0
# 3                50983        False   229 2025-10-27 00:00:21.900    1.0
# 4               735578        False   229 2025-10-27 00:00:21.900    1.0
# 5                50978         True   229 2025-10-27 00:00:21.900    1.0
# 6               735574         True   229 2025-10-27 00:00:21.900    1.0
# 7               795507         True   229 2025-10-27 00:00:21.900    1.0
# 8               795505         True   229 2025-10-27 00:00:21.900    1.0
# 9               735573         True   229 2025-10-27 00:00:21.900    1.0
# 10              966120         True   229 2025-10-27 00:00:21.900    1.0
# 11              285188        False   229 2025-10-27 00:00:21.900    1.0
# 12               51667         True   229 2025-10-27 00:00:21.900    1.0
# 13               33697         True   229 2025-10-27 00:00:21.900    1.0
# 14               51713         True   229 2025-10-27 00:00:21.900    1.0
# 15              133498         True   229 2025-10-27 00:00:21.900    1.0
# 16               14736         True   229 2025-10-27 00:00:21.900    1.0
# 17               23418         True   229 2025-10-27 00:00:21.900    1.0
# 18              133501        False   229 2025-10-27 00:00:21.900    1.0
# 19              965685        False   229 2025-10-27 00:00:21.900    1.0
# 20               50951        False   229 2025-10-27 00:00:21.900    1.0
# 21               38673        False   229 2025-10-27 00:00:21.900    1.0
#
#     possession_player_id possession_group  ball_x  ball_y  ball_z  \
# 0                    NaN        home team   22.43   -14.9    0.11
# 1                    NaN        home team   22.43   -14.9    0.11
# 2                    NaN        home team   22.43   -14.9    0.11
# 3                    NaN        home team   22.43   -14.9    0.11
# 4                    NaN        home team   22.43   -14.9    0.11
# 5                    NaN        home team   22.43   -14.9    0.11
# 6                    NaN        home team   22.43   -14.9    0.11
# 7                    NaN        home team   22.43   -14.9    0.11
# 8                    NaN        home team   22.43   -14.9    0.11
# 9                    NaN        home team   22.43   -14.9    0.11
# 10                   NaN        home team   22.43   -14.9    0.11
# 11                   NaN        home team   22.43   -14.9    0.11
# 12                   NaN        home team   22.43   -14.9    0.11
# 13                   NaN        home team   22.43   -14.9    0.11
# 14                   NaN        home team   22.43   -14.9    0.11
# 15                   NaN        home team   22.43   -14.9    0.11
# 16                   NaN        home team   22.43   -14.9    0.11
# 17                   NaN        home team   22.43   -14.9    0.11
# 18                   NaN        home team   22.43   -14.9    0.11
# 19                   NaN        home team   22.43   -14.9    0.11
# 20                   NaN        home team   22.43   -14.9    0.11
# 21                   NaN        home team   22.43   -14.9    0.11
#
#     is_detected_ball  match_id start_time  end_time  \
# 0               True   1886347   00:00:00      None
# 1               True   1886347   00:00:00      None
# 2               True   1886347   00:00:00      None
# 3               True   1886347   00:00:00      None
# 4               True   1886347   00:00:00      None
# 5               True   1886347   00:00:00  01:24:58
# 6               True   1886347   00:00:00      None
# 7               True   1886347   00:00:00  01:00:15
# 8               True   1886347   00:00:00  01:24:58
# 9               True   1886347   00:00:00      None
# 10              True   1886347   00:00:00  01:07:43
# 11              True   1886347   00:00:00      None
# 12              True   1886347   00:00:00      None
# 13              True   1886347   00:00:00      None
# 14              True   1886347   00:00:00      None
# 15              True   1886347   00:00:00      None
# 16              True   1886347   00:00:00      None
# 17              True   1886347   00:00:00      None
# 18              True   1886347   00:00:00  01:09:53
# 19              True   1886347   00:00:00      None
# 20              True   1886347   00:00:00  01:16:37
# 21              True   1886347   00:00:00  01:25:21
#
#                                  match_name             date_time  \
# 0   Auckland FC vs Newcastle United Jets FC  2024-11-30T04:00:00Z
# 1   Auckland FC vs Newcastle United Jets FC  2024-11-30T04:00:00Z
# 2   Auckland FC vs Newcastle United Jets FC  2024-11-30T04:00:00Z
# 3   Auckland FC vs Newcastle United Jets FC  2024-11-30T04:00:00Z
# 4   Auckland FC vs Newcastle United Jets FC  2024-11-30T04:00:00Z
# 5   Auckland FC vs Newcastle United Jets FC  2024-11-30T04:00:00Z
# 6   Auckland FC vs Newcastle United Jets FC  2024-11-30T04:00:00Z
# 7   Auckland FC vs Newcastle United Jets FC  2024-11-30T04:00:00Z
# 8   Auckland FC vs Newcastle United Jets FC  2024-11-30T04:00:00Z
# 9   Auckland FC vs Newcastle United Jets FC  2024-11-30T04:00:00Z
# 10  Auckland FC vs Newcastle United Jets FC  2024-11-30T04:00:00Z
# 11  Auckland FC vs Newcastle United Jets FC  2024-11-30T04:00:00Z
# 12  Auckland FC vs Newcastle United Jets FC  2024-11-30T04:00:00Z
# 13  Auckland FC vs Newcastle United Jets FC  2024-11-30T04:00:00Z
# 14  Auckland FC vs Newcastle United Jets FC  2024-11-30T04:00:00Z
# 15  Auckland FC vs Newcastle United Jets FC  2024-11-30T04:00:00Z
# 16  Auckland FC vs Newcastle United Jets FC  2024-11-30T04:00:00Z
# 17  Auckland FC vs Newcastle United Jets FC  2024-11-30T04:00:00Z
# 18  Auckland FC vs Newcastle United Jets FC  2024-11-30T04:00:00Z
# 19  Auckland FC vs Newcastle United Jets FC  2024-11-30T04:00:00Z
# 20  Auckland FC vs Newcastle United Jets FC  2024-11-30T04:00:00Z
# 21  Auckland FC vs Newcastle United Jets FC  2024-11-30T04:00:00Z
#
#    home_team.name            away_team.name      id     short_name  number  \
# 0     Auckland FC  Newcastle United Jets FC   51009       R. Scott       1
# 1     Auckland FC  Newcastle United Jets FC  176224      P. Cancar       4
# 2     Auckland FC  Newcastle United Jets FC   51649     A. Šušnjar      15
# 3     Auckland FC  Newcastle United Jets FC   50983      D. Ingham      14
# 4     Auckland FC  Newcastle United Jets FC  735578       M. Natta      33
# 5     Auckland FC  Newcastle United Jets FC   50978     C. Timmins      19
# 6     Auckland FC  Newcastle United Jets FC  735574      K. Grozos      17
# 7     Auckland FC  Newcastle United Jets FC  795507     L. Bayliss      37
# 8     Auckland FC  Newcastle United Jets FC  795505       E. Adams       7
# 9     Auckland FC  Newcastle United Jets FC  735573    T. Aquilina      39
# 10    Auckland FC  Newcastle United Jets FC  966120      B. Gibson      22
# 11    Auckland FC  Newcastle United Jets FC  285188     A. Paulsen      12
# 12    Auckland FC  Newcastle United Jets FC   51667        D. Hall      23
# 13    Auckland FC  Newcastle United Jets FC   33697    N. Pijnaker       4
# 14    Auckland FC  Newcastle United Jets FC   51713     C. Elliott      17
# 15    Auckland FC  Newcastle United Jets FC  133498    F. De Vries      15
# 16    Auckland FC  Newcastle United Jets FC   14736  L. Verstraete       6
# 17    Auckland FC  Newcastle United Jets FC   23418    F. Gallegos      28
# 18    Auckland FC  Newcastle United Jets FC  133501    L. Rogerson      27
# 19    Auckland FC  Newcastle United Jets FC  965685     L. Gillion      14
# 20    Auckland FC  Newcastle United Jets FC   50951     J. Brimmer      22
# 21    Auckland FC  Newcastle United Jets FC   38673         G. May      10
#
#     team_id_tracking                 team_name player_role.position_group  \
# 0               1805  Newcastle United Jets FC                      Other
# 1               1805  Newcastle United Jets FC           Central Defender
# 2               1805  Newcastle United Jets FC           Central Defender
# 3               1805  Newcastle United Jets FC                  Full Back
# 4               1805  Newcastle United Jets FC                  Full Back
# 5               1805  Newcastle United Jets FC                   Midfield
# 6               1805  Newcastle United Jets FC                   Midfield
# 7               1805  Newcastle United Jets FC                   Midfield
# 8               1805  Newcastle United Jets FC              Wide Attacker
# 9               1805  Newcastle United Jets FC              Wide Attacker
# 10              1805  Newcastle United Jets FC             Center Forward
# 11              4177               Auckland FC                      Other
# 12              4177               Auckland FC           Central Defender
# 13              4177               Auckland FC           Central Defender
# 14              4177               Auckland FC                  Full Back
# 15              4177               Auckland FC                  Full Back
# 16              4177               Auckland FC                   Midfield
# 17              4177               Auckland FC                   Midfield
# 18              4177               Auckland FC              Wide Attacker
# 19              4177               Auckland FC              Wide Attacker
# 20              4177               Auckland FC             Center Forward
# 21              4177               Auckland FC             Center Forward
#
#     total_time          player_role.name player_role.acronym  is_gk  \
# 0         5400                Goalkeeper                  GK   True
# 1         5400         Right Center Back                 RCB  False
# 2         5400          Left Center Back                 LCB  False
# 3         5400                Right Back                  RB  False
# 4         5400                 Left Back                  LB  False
# 5         5098   Left Defensive Midfield                 LDM  False
# 6         5400  Right Defensive Midfield                 RDM  False
# 7         3615        Attacking Midfield                  AM  False
# 8         5098              Right Winger                  RW  False
# 9         5400               Left Winger                  LW  False
# 10        4063            Center Forward                  CF  False
# 11        5400                Goalkeeper                  GK   True
# 12        5400         Right Center Back                 RCB  False
# 13        5400          Left Center Back                 LCB  False
# 14        5400                Right Back                  RB  False
# 15        5400                 Left Back                  LB  False
# 16        5400        Defensive Midfield                  DM  False
# 17        5400        Attacking Midfield                  AM  False
# 18        4193              Right Winger                  RW  False
# 19        5400               Left Winger                  LW  False
# 20        4597            Center Forward                  CF  False
# 21        5121            Center Forward                  CF  False
#
#    direction_player_1st_half direction_player_2nd_half  runner  ball_carrier  \
# 0              left_to_right             right_to_left   False         False
# 1              left_to_right             right_to_left   False         False
# 2              left_to_right             right_to_left   False         False
# 3              left_to_right             right_to_left   False         False
# 4              left_to_right             right_to_left   False         False
# 5              left_to_right             right_to_left   False         False
# 6              left_to_right             right_to_left   False         False
# 7              left_to_right             right_to_left   False         False
# 8              left_to_right             right_to_left   False         False
# 9              left_to_right             right_to_left   False         False
# 10             left_to_right             right_to_left   False         False
# 11             right_to_left             left_to_right   False         False
# 12             right_to_left             left_to_right   False         False
# 13             right_to_left             left_to_right    True         False
# 14             right_to_left             left_to_right   False         False
# 15             right_to_left             left_to_right   False         False
# 16             right_to_left             left_to_right   False         False
# 17             right_to_left             left_to_right   False         False
# 18             right_to_left             left_to_right   False         False
# 19             right_to_left             left_to_right   False         False
# 20             right_to_left             left_to_right   False         False
# 21             right_to_left             left_to_right   False         False
#
#       tip
# 0   False
# 1   False
# 2   False
# 3   False
# 4   False
# 5   False
# 6   False
# 7   False
# 8   False
# 9   False
# 10  False
# 11   True
# 12   True
# 13   True
# 14   True
# 15   True
# 16   True
# 17   True
# 18   True
# 19   True
# 20   True
# 21   True

# %% [markdown]
# ### Plot

# %%
import matplotlib.pyplot as plt
from IPython.display import clear_output
import time

def plot_tracking_with_events_frame(enriched_data, events_data, frame_num, delay=0.1, fixed_xlim=None, fixed_ylim=None):
    """
    Plot a single frame of tracking data with event highlighting
    
    Parameters:
    - enriched_data: DataFrame with enriched tracking data
    - events_data: DataFrame with dynamic events data
    - frame_num: Frame number to plot
    - delay: Delay between frames (for animation effect)
    - fixed_xlim: Tuple of (min, max) for x-axis limits
    - fixed_ylim: Tuple of (min, max) for y-axis limits
    """
    # Filter tracking data for specific frame
    frame_data = enriched_data[enriched_data['frame'] == frame_num]
    
    if frame_data.empty:
        print(f"No tracking data found for frame {frame_num}")
        return
    
    # Check for events at this frame
    frame_events = events_data[
        (events_data['frame_start'] <= frame_num) & 
        (events_data['frame_end'] >= frame_num)
    ]
    
    # Create pitch
    pitch = Pitch(
        pitch_type="skillcorner",
        line_alpha=0.75,
        pitch_length=105,
        pitch_width=68,
        pitch_color="#001400",
        line_color="white",
        linewidth=1.5,
    )
    
    fig, ax = pitch.draw(figsize=(14, 10))
    
    size = 300
    
    # Default team colors
    teams = frame_data['team_name'].unique()
    team_colors = {'possession': '#084D42', 'out_of_possession': '#E51717'}
    
    # Plot regular players first
    for i, team in enumerate(teams):
        team_data = frame_data[frame_data['team_name'] == team]
        
        # Regular players
        regular_players = team_data[team_data['is_gk'] == False]
        ax.scatter(
            regular_players['x'],
            regular_players['y'],
            c='#084D42' if i == 0 else '#E51717',
            alpha=0.95,
            s=size,
            edgecolors='white',
            linewidths=1.5,
            zorder=10
        )
        
        # Goalkeepers
        goalkeepers = team_data[team_data['is_gk'] == True]
        if not goalkeepers.empty:
            ax.scatter(
                goalkeepers['x'],
                goalkeepers['y'],
                c='#084D42' if i == 0 else '#E51717',
                alpha=0.95,
                s=size * 1.2,
                edgecolors='yellow',
                linewidths=3,
                marker='s',
                zorder=10
            )
    
    # Plot ball
    if 'ball_x' in frame_data.columns and not frame_data['ball_x'].isna().all():
        ball_data = frame_data[['ball_x', 'ball_y']].dropna()
        if not ball_data.empty:
            ax.scatter(
                ball_data['ball_x'].iloc[0],
                ball_data['ball_y'].iloc[0],
                c='white',
                s=100,
                edgecolors='black',
                linewidths=2,
                zorder=15
            )
    
    # Highlight events if they exist at this frame
    event_info = []
    if not frame_events.empty:
        for _, event in frame_events.iterrows():
            # Merge event with tracking data for this frame
            event_tracking = frame_data.merge(
                pd.DataFrame([event]),
                left_on=['player_id'],
                right_on=['player_id'],
                how='inner'
            )
            
            if not event_tracking.empty:
                # Highlight the player involved in the event (runner/event player)
                runner_data = event_tracking[event_tracking['player_id'] == event['player_id']]
                if not runner_data.empty:
                    ax.scatter(
                        runner_data['x'],
                        runner_data['y'],
                        c='#E5BA21',  # Yellow for event player
                        alpha=0.95,
                        s=size * 1.3,
                        edgecolors='#E5BA21',
                        linewidths=3,
                        zorder=20
                    )
                    
                    # Draw trajectory line if we have start/end positions
                    if pd.notna(event['x_start']) and pd.notna(event['x_end']):
                        ax.plot(
                            [event['x_start'], event['x_end']],
                            [event['y_start'], event['y_end']],
                            color='#E5BA21',
                            linewidth=3,
                            ls='--',
                            alpha=0.8,
                            zorder=15
                        )
                        
                        # Mark start position
                        ax.scatter(
                            event['x_start'],
                            event['y_start'],
                            c='#E5BA21',
                            alpha=0.6,
                            s=size/2,
                            edgecolors='#E5BA21',
                            linewidths=2,
                            zorder=15
                        )
            
            # Highlight ball carrier if different from event player
            if pd.notna(event['player_in_possession_id']) and event['player_in_possession_id'] != event['player_id']:
                ball_carrier_data = frame_data[frame_data['player_id'] == event['player_in_possession_id']]
                if not ball_carrier_data.empty:
                    ax.scatter(
                        ball_carrier_data['x'],
                        ball_carrier_data['y'],
                        c='#32FE6B',  # Green for ball carrier
                        alpha=0.95,
                        s=size * 1.2,
                        edgecolors='#32FE6B',
                        linewidths=3,
                        zorder=20
                    )
            
            # Collect event info for display
            event_info.append(f"{event['event_type']} (ID: {event['event_id']})")
    
    # Add frame and event info
    timestamp = frame_data['timestamp'].iloc[0] if 'timestamp' in frame_data.columns else 'N/A'
    period = frame_data['period'].iloc[0] if 'period' in frame_data.columns else 'N/A'
    
    title = f'Frame: {frame_num} | Time: {timestamp} | Period: {period}'
    if event_info:
        title += f'\nEvents: {", ".join(event_info)}'
    
    ax.set_title(title, fontsize=12, fontweight='bold', color='white', pad=20)
    
    # Add legend
    legend_elements = [
        plt.scatter([], [], c='#084D42', s=100, label='Team 1'),
        plt.scatter([], [], c='#E51717', s=100, label='Team 2'),
        plt.scatter([], [], c='white', s=50, edgecolors='black', label='Ball'),
    ]
    
    if event_info:
        legend_elements.extend([
            plt.scatter([], [], c='#E5BA21', s=120, label='Event Player'),
            plt.scatter([], [], c='#32FE6B', s=120, label='Ball Carrier'),
        ])
    
    ax.legend(handles=legend_elements, loc='upper left', bbox_to_anchor=(0, 1))
    
    plt.tight_layout()
    
    # Set fixed axis limits AFTER tight_layout to prevent zooming
    if fixed_xlim is not None:
        ax.set_xlim(fixed_xlim)
    if fixed_ylim is not None:
        ax.set_ylim(fixed_ylim)
    
    plt.show()
    
    if delay > 0:
        time.sleep(delay)

def animate_tracking_with_events(enriched_data, events_data, start_frame=10, end_frame=100, delay=0.3):
    """
    Animate tracking data with event highlighting through multiple frames
    
    Parameters:
    - enriched_data: DataFrame with enriched tracking data
    - events_data: DataFrame with dynamic events data
    - start_frame: Starting frame number
    - end_frame: Ending frame number
    - delay: Delay between frames in seconds
    """
    available_frames = sorted(enriched_data['frame'].unique())
    frames_to_plot = [f for f in available_frames if start_frame <= f <= end_frame]
    
    # Calculate axis limits based on ALL frames to keep consistent view and capture full movement range
    frames_data = enriched_data[enriched_data['frame'].isin(frames_to_plot)]
    x_min, x_max = frames_data['x'].min() - 5, frames_data['x'].max() + 5
    y_min, y_max = frames_data['y'].min() - 5, frames_data['y'].max() + 5
    
    print(f"Fixed axis limits: X=({x_min:.1f}, {x_max:.1f}), Y=({y_min:.1f}, {y_max:.1f})")
    
    # Check which frames have events
    event_frames = set()
    for _, event in events_data.iterrows():
        event_frames.update(range(int(event['frame_start']), int(event['frame_end']) + 1))
    
    frames_with_events = [f for f in frames_to_plot if f in event_frames]
    
    print(f"Animating {len(frames_to_plot)} frames from {start_frame} to {end_frame}")
    print(f"Frames with events: {len(frames_with_events)} out of {len(frames_to_plot)}")
    
    if frames_with_events:
        print("Event frames:", sorted(frames_with_events)[:10], "..." if len(frames_with_events) > 10 else "")
    
    for frame_num in frames_to_plot:
        clear_output(wait=True)
        plot_tracking_with_events_frame(enriched_data, events_data, frame_num, delay=0, 
                                      fixed_xlim=(x_min, x_max), fixed_ylim=(y_min, y_max))
        if delay > 0:
            time.sleep(delay)

# Example usage:
# animate_tracking_with_events(enriched_tracking_data, de_match, start_frame=10, end_frame=100, delay=0.3)

# %%
def animate_tracking_stable_pitch(enriched_data, events_data, start_frame=10, end_frame=100, delay=0.3):
    """
    Animate tracking data with stable pitch - creates pitch once and updates scatter plots
    
    Parameters:
    - enriched_data: DataFrame with enriched tracking data
    - events_data: DataFrame with dynamic events data
    - start_frame: Starting frame number
    - end_frame: Ending frame number
    - delay: Delay between frames in seconds
    """
    available_frames = sorted(enriched_data['frame'].unique())
    frames_to_plot = [f for f in available_frames if start_frame <= f <= end_frame]
    
    # Calculate axis limits based on ALL frames
    frames_data = enriched_data[enriched_data['frame'].isin(frames_to_plot)]
    x_min, x_max = frames_data['x'].min() - 5, frames_data['x'].max() + 5
    y_min, y_max = frames_data['y'].min() - 5, frames_data['y'].max() + 5
    
    print(f"Fixed axis limits: X=({x_min:.1f}, {x_max:.1f}), Y=({y_min:.1f}, {y_max:.1f})")
    
    # Check which frames have events
    event_frames = set()
    for _, event in events_data.iterrows():
        event_frames.update(range(int(event['frame_start']), int(event['frame_end']) + 1))
    
    frames_with_events = [f for f in frames_to_plot if f in event_frames]
    
    print(f"Animating {len(frames_to_plot)} frames from {start_frame} to {end_frame}")
    print(f"Frames with events: {len(frames_with_events)} out of {len(frames_to_plot)}")
    
    # CREATE PITCH ONCE
    pitch = Pitch(
        pitch_type="skillcorner",
        line_alpha=0.75,
        pitch_length=105,
        pitch_width=68,
        pitch_color="#001400",
        line_color="white",
        linewidth=1.5,
    )
    
    fig, ax = pitch.draw(figsize=(14, 10))
    
    # Set fixed axis limits once
    ax.set_xlim(x_min, x_max)
    ax.set_ylim(y_min, y_max)
    
    size = 300
    
    # Animation loop - only update scatter plots
    for frame_num in frames_to_plot:
        # Clear previous scatter plots but keep pitch lines
        ax.clear()
        
        # Redraw pitch on cleared axes
        pitch.draw(ax=ax)
        ax.set_xlim(x_min, x_max)
        ax.set_ylim(y_min, y_max)
        
        # Filter tracking data for specific frame
        frame_data = enriched_data[enriched_data['frame'] == frame_num]
        
        if frame_data.empty:
            continue
            
        # Check for events at this frame
        frame_events = events_data[
            (events_data['frame_start'] <= frame_num) & 
            (events_data['frame_end'] >= frame_num)
        ]
        
        # Get team info
        teams = frame_data['team_name'].unique()
        
        # Plot regular players
        for i, team in enumerate(teams):
            team_data = frame_data[frame_data['team_name'] == team]
            
            # Regular players
            regular_players = team_data[team_data['is_gk'] == False]
            if not regular_players.empty:
                ax.scatter(
                    regular_players['x'],
                    regular_players['y'],
                    c='#084D42' if i == 0 else '#E51717',
                    alpha=0.95,
                    s=size,
                    edgecolors='white',
                    linewidths=1.5,
                    zorder=10
                )
            
            # Goalkeepers
            goalkeepers = team_data[team_data['is_gk'] == True]
            if not goalkeepers.empty:
                ax.scatter(
                    goalkeepers['x'],
                    goalkeepers['y'],
                    c='#084D42' if i == 0 else '#E51717',
                    alpha=0.95,
                    s=size * 1.2,
                    edgecolors='yellow',
                    linewidths=3,
                    marker='s',
                    zorder=10
                )
        
        # Plot ball
        if 'ball_x' in frame_data.columns and not frame_data['ball_x'].isna().all():
            ball_data = frame_data[['ball_x', 'ball_y']].dropna()
            if not ball_data.empty:
                ax.scatter(
                    ball_data['ball_x'].iloc[0],
                    ball_data['ball_y'].iloc[0],
                    c='white',
                    s=100,
                    edgecolors='black',
                    linewidths=2,
                    zorder=15
                )
        
        # Highlight events
        event_info = []
        if not frame_events.empty:
            for _, event in frame_events.iterrows():
                # Highlight event player
                event_player_data = frame_data[frame_data['player_id'] == event['player_id']]
                if not event_player_data.empty:
                    ax.scatter(
                        event_player_data['x'],
                        event_player_data['y'],
                        c='#E5BA21',  # Yellow for event player
                        alpha=0.95,
                        s=size * 1.3,
                        edgecolors='#E5BA21',
                        linewidths=3,
                        zorder=20
                    )
                    
                    # Draw trajectory line
                    if pd.notna(event['x_start']) and pd.notna(event['x_end']):
                        ax.plot(
                            [event['x_start'], event['x_end']],
                            [event['y_start'], event['y_end']],
                            color='#E5BA21',
                            linewidth=3,
                            ls='--',
                            alpha=0.8,
                            zorder=15
                        )
                        
                        # Mark start position
                        ax.scatter(
                            event['x_start'],
                            event['y_start'],
                            c='#E5BA21',
                            alpha=0.6,
                            s=size/2,
                            edgecolors='#E5BA21',
                            linewidths=2,
                            zorder=15
                        )
                
                # Highlight ball carrier if different
                if pd.notna(event['player_in_possession_id']) and event['player_in_possession_id'] != event['player_id']:
                    ball_carrier_data = frame_data[frame_data['player_id'] == event['player_in_possession_id']]
                    if not ball_carrier_data.empty:
                        ax.scatter(
                            ball_carrier_data['x'],
                            ball_carrier_data['y'],
                            c='#32FE6B',  # Green for ball carrier
                            alpha=0.95,
                            s=size * 1.2,
                            edgecolors='#32FE6B',
                            linewidths=3,
                            zorder=20
                        )
                
                event_info.append(f"{event['event_type']} (ID: {event['event_id']})")
        
        # Update title
        timestamp = frame_data['timestamp'].iloc[0] if 'timestamp' in frame_data.columns else 'N/A'
        period = frame_data['period'].iloc[0] if 'period' in frame_data.columns else 'N/A'
        
        title = f'Frame: {frame_num} | Time: {timestamp} | Period: {period}'
        if event_info:
            title += f'\nEvents: {", ".join(event_info)}'
        
        ax.set_title(title, fontsize=12, fontweight='bold', color='white', pad=20)
        
        # Add legend
        legend_elements = [
            plt.scatter([], [], c='#084D42', s=100, label='Team 1'),
            plt.scatter([], [], c='#E51717', s=100, label='Team 2'),
            plt.scatter([], [], c='white', s=50, edgecolors='black', label='Ball'),
        ]
        
        if event_info:
            legend_elements.extend([
                plt.scatter([], [], c='#E5BA21', s=120, label='Event Player'),
                plt.scatter([], [], c='#32FE6B', s=120, label='Ball Carrier'),
            ])
        
        ax.legend(handles=legend_elements, loc='upper left', bbox_to_anchor=(0, 1))
        
        # Display frame
        clear_output(wait=True)
        plt.show()
        
        if delay > 0:
            time.sleep(delay)
    
    plt.close(fig)  # Clean up when done

# %%
# Test the new stable pitch animation
animate_tracking_stable_pitch(enriched_tracking_data, de_match, start_frame=1, end_frame=90, delay=0.1)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[86], line 2
#       1 # Test the new stable pitch animation
# ----> 2 animate_tracking_stable_pitch(enriched_tracking_data, de_match, start_frame=1, end_frame=90, delay=0.1)
#
# Cell In[85], line 208, in animate_tracking_stable_pitch(enriched_data, events_data, start_frame, end_frame, delay)
#     205 ax.legend(handles=legend_elements, loc='upper left', bbox_to_anchor=(0, 1))
#     207 # Display frame
# --> 208 clear_output(wait=True)
#     209 plt.show()
#     211 if delay > 0:
#
# File ~/anaconda3/envs/e4_hackathon/lib/python3.13/site-packages/IPython/core/display_functions.py:366, in clear_output(wait)
#     364 from IPython.core.interactiveshell import InteractiveShell
#     365 if InteractiveShell.initialized():
# --> 366     InteractiveShell.instance().display_pub.clear_output(wait)
#     367 else:
#     368     print('\033[2K\r', end='')
#
# File ~/anaconda3/envs/e4_hackathon/lib/python3.13/site-packages/ipykernel/zmqshell.py:148, in ZMQDisplayPublisher.clear_output(self, wait)
#     137 """Clear output associated with the current execution (cell).
#     138
#     139 Parameters
#    (...)    145
#     146 """
#     147 content = dict(wait=wait)
# --> 148 self._flush_streams()
#     149 assert self.session is not None
#     150 msg = self.session.msg("clear_output", json_clean(content), parent=self.parent_header)
#
# File ~/anaconda3/envs/e4_hackathon/lib/python3.13/site-packages/ipykernel/zmqshell.py:66, in ZMQDisplayPublisher._flush_streams(self)
#      64 def _flush_streams(self):
#      65     """flush IO Streams prior to display"""
# ---> 66     sys.stdout.flush()
#      67     sys.stderr.flush()
#
# File ~/anaconda3/envs/e4_hackathon/lib/python3.13/site-packages/ipykernel/iostream.py:609, in OutStream.flush(self)
#     607     self.pub_thread.schedule(evt.set)
#     608     # and give a timeout to avoid
# --> 609     if not evt.wait(self.flush_timeout):
#     610         # write directly to __stderr__ instead of warning because
#     611         # if this is happening sys.stderr may be the problem.
#     612         print("IOStream.flush timed out", file=sys.__stderr__)
#     613 else:
#
# File ~/anaconda3/envs/e4_hackathon/lib/python3.13/threading.py:659, in Event.wait(self, timeout)
#     657 signaled = self._flag
#     658 if not signaled:
# --> 659     signaled = self._cond.wait(timeout)
#     660 return signaled
#
# File ~/anaconda3/envs/e4_hackathon/lib/python3.13/threading.py:363, in Condition.wait(self, timeout)
#     361 else:
#     362     if timeout > 0:
# --> 363         gotit = waiter.acquire(True, timeout)
#     364     else:
#     365         gotit = waiter.acquire(False)
#
# KeyboardInterrupt:

# %%
# Run the animation with events
animate_tracking_with_events(enriched_tracking_data, de_match, start_frame=1, end_frame=90, delay=0.1)
