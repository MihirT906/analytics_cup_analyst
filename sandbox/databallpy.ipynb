# %%
# %pip install databallpy
# Out:
# Collecting databallpy
#   Using cached databallpy-0.6.2-py3-none-any.whl.metadata (16 kB)
# Collecting beautifulsoup4<5.0.0,>=4.11.1 (from databallpy)
#   Downloading beautifulsoup4-4.14.2-py3-none-any.whl.metadata (3.8 kB)
# Collecting chardet<6.0.0,>=5.2.0 (from databallpy)
#   Downloading chardet-5.2.0-py3-none-any.whl.metadata (3.4 kB)
# Collecting lxml<=6.0,>=4.9 (from databallpy)
#   Downloading lxml-6.0.0-cp313-cp313-macosx_10_13_universal2.whl.metadata (6.6 kB)
# Collecting matplotlib<4.0.0,>=3.6.3 (from databallpy)
#   Downloading matplotlib-3.10.7-cp313-cp313-macosx_11_0_arm64.whl.metadata (11 kB)
# Collecting numpy<3.0,>=2.1 (from databallpy)
#   Using cached numpy-2.3.4-cp313-cp313-macosx_14_0_arm64.whl.metadata (62 kB)
# Collecting pandas<3.0,>=2.1 (from databallpy)
#   Using cached pandas-2.3.3-cp313-cp313-macosx_11_0_arm64.whl.metadata (91 kB)
# Collecting pandera<0.23.0,>=0.22.1 (from databallpy)
#   Using cached pandera-0.22.1-py3-none-any.whl.metadata (15 kB)
# Collecting pyarrow<20.0.0,>=19.0.0 (from databallpy)
#   Downloading pyarrow-19.0.1-cp313-cp313-macosx_12_0_arm64.whl.metadata (3.3 kB)
# Collecting requests<3.0,>=2.31 (from databallpy)
#   Downloading requests-2.32.5-py3-none-any.whl.metadata (4.9 kB)
# Collecting scipy<2.0,>=1.11 (from databallpy)
#   Downloading scipy-1.16.2-cp313-cp313-macosx_14_0_arm64.whl.metadata (62 kB)
# Collecting tqdm<5.0.0,>=4.64.1 (from databallpy)
#   Using cached tqdm-4.67.1-py3-none-any.whl.metadata (57 kB)
# Collecting soupsieve>1.2 (from beautifulsoup4<5.0.0,>=4.11.1->databallpy)
#   Downloading soupsieve-2.8-py3-none-any.whl.metadata (4.6 kB)
# Collecting typing-extensions>=4.0.0 (from beautifulsoup4<5.0.0,>=4.11.1->databallpy)
#   Using cached typing_extensions-4.15.0-py3-none-any.whl.metadata (3.3 kB)
# Collecting contourpy>=1.0.1 (from matplotlib<4.0.0,>=3.6.3->databallpy)
#   Downloading contourpy-1.3.3-cp313-cp313-macosx_11_0_arm64.whl.metadata (5.5 kB)
# Collecting cycler>=0.10 (from matplotlib<4.0.0,>=3.6.3->databallpy)
#   Using cached cycler-0.12.1-py3-none-any.whl.metadata (3.8 kB)
# Collecting fonttools>=4.22.0 (from matplotlib<4.0.0,>=3.6.3->databallpy)
#   Downloading fonttools-4.60.1-cp313-cp313-macosx_10_13_universal2.whl.metadata (112 kB)
# Collecting kiwisolver>=1.3.1 (from matplotlib<4.0.0,>=3.6.3->databallpy)
#   Downloading kiwisolver-1.4.9-cp313-cp313-macosx_11_0_arm64.whl.metadata (6.3 kB)
# Requirement already satisfied: packaging>=20.0 in /Users/mihirthalanki/anaconda3/envs/e4_databallpy/lib/python3.13/site-packages (from matplotlib<4.0.0,>=3.6.3->databallpy) (25.0)
# Collecting pillow>=8 (from matplotlib<4.0.0,>=3.6.3->databallpy)
#   Downloading pillow-12.0.0-cp313-cp313-macosx_11_0_arm64.whl.metadata (8.8 kB)
# Collecting pyparsing>=3 (from matplotlib<4.0.0,>=3.6.3->databallpy)
#   Downloading pyparsing-3.2.5-py3-none-any.whl.metadata (5.0 kB)
# Requirement already satisfied: python-dateutil>=2.7 in /Users/mihirthalanki/anaconda3/envs/e4_databallpy/lib/python3.13/site-packages (from matplotlib<4.0.0,>=3.6.3->databallpy) (2.9.0.post0)
# Collecting pytz>=2020.1 (from pandas<3.0,>=2.1->databallpy)
#   Using cached pytz-2025.2-py2.py3-none-any.whl.metadata (22 kB)
# Collecting tzdata>=2022.7 (from pandas<3.0,>=2.1->databallpy)
#   Using cached tzdata-2025.2-py2.py3-none-any.whl.metadata (1.4 kB)
# Collecting pydantic (from pandera<0.23.0,>=0.22.1->databallpy)
#   Downloading pydantic-2.12.3-py3-none-any.whl.metadata (87 kB)
# Collecting typeguard (from pandera<0.23.0,>=0.22.1->databallpy)
#   Using cached typeguard-4.4.4-py3-none-any.whl.metadata (3.3 kB)
# Collecting typing_inspect>=0.6.0 (from pandera<0.23.0,>=0.22.1->databallpy)
#   Downloading typing_inspect-0.9.0-py3-none-any.whl.metadata (1.5 kB)
# Collecting charset_normalizer<4,>=2 (from requests<3.0,>=2.31->databallpy)
#   Downloading charset_normalizer-3.4.4-cp313-cp313-macosx_10_13_universal2.whl.metadata (37 kB)
# Collecting idna<4,>=2.5 (from requests<3.0,>=2.31->databallpy)
#   Using cached idna-3.11-py3-none-any.whl.metadata (8.4 kB)
# Collecting urllib3<3,>=1.21.1 (from requests<3.0,>=2.31->databallpy)
#   Downloading urllib3-2.5.0-py3-none-any.whl.metadata (6.5 kB)
# Collecting certifi>=2017.4.17 (from requests<3.0,>=2.31->databallpy)
#   Downloading certifi-2025.10.5-py3-none-any.whl.metadata (2.5 kB)
# Requirement already satisfied: six>=1.5 in /Users/mihirthalanki/anaconda3/envs/e4_databallpy/lib/python3.13/site-packages (from python-dateutil>=2.7->matplotlib<4.0.0,>=3.6.3->databallpy) (1.17.0)
# Collecting mypy-extensions>=0.3.0 (from typing_inspect>=0.6.0->pandera<0.23.0,>=0.22.1->databallpy)
#   Downloading mypy_extensions-1.1.0-py3-none-any.whl.metadata (1.1 kB)
# Collecting annotated-types>=0.6.0 (from pydantic->pandera<0.23.0,>=0.22.1->databallpy)
#   Using cached annotated_types-0.7.0-py3-none-any.whl.metadata (15 kB)
# Collecting pydantic-core==2.41.4 (from pydantic->pandera<0.23.0,>=0.22.1->databallpy)
#   Downloading pydantic_core-2.41.4-cp313-cp313-macosx_11_0_arm64.whl.metadata (7.3 kB)
# Collecting typing-inspection>=0.4.2 (from pydantic->pandera<0.23.0,>=0.22.1->databallpy)
#   Downloading typing_inspection-0.4.2-py3-none-any.whl.metadata (2.6 kB)
# Using cached databallpy-0.6.2-py3-none-any.whl (902 kB)
# Downloading beautifulsoup4-4.14.2-py3-none-any.whl (106 kB)
# Downloading chardet-5.2.0-py3-none-any.whl (199 kB)
# Downloading lxml-6.0.0-cp313-cp313-macosx_10_13_universal2.whl (8.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.4/8.4 MB 15.6 MB/s  0:00:00 eta 0:00:01
# Downloading matplotlib-3.10.7-cp313-cp313-macosx_11_0_arm64.whl (8.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.1/8.1 MB 25.0 MB/s  0:00:00 eta 0:00:01
# Using cached numpy-2.3.4-cp313-cp313-macosx_14_0_arm64.whl (5.1 MB)
# Using cached pandas-2.3.3-cp313-cp313-macosx_11_0_arm64.whl (10.7 MB)
# Using cached pandera-0.22.1-py3-none-any.whl (261 kB)
# Downloading pyarrow-19.0.1-cp313-cp313-macosx_12_0_arm64.whl (30.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 30.7/30.7 MB 46.9 MB/s  0:00:00m0:00:0100:01
# Downloading requests-2.32.5-py3-none-any.whl (64 kB)
# Downloading charset_normalizer-3.4.4-cp313-cp313-macosx_10_13_universal2.whl (208 kB)
# Using cached idna-3.11-py3-none-any.whl (71 kB)
# Downloading scipy-1.16.2-cp313-cp313-macosx_14_0_arm64.whl (20.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 20.9/20.9 MB 88.2 MB/s  0:00:00 eta 0:00:01
# Using cached tqdm-4.67.1-py3-none-any.whl (78 kB)
# Downloading urllib3-2.5.0-py3-none-any.whl (129 kB)
# Downloading certifi-2025.10.5-py3-none-any.whl (163 kB)
# Downloading contourpy-1.3.3-cp313-cp313-macosx_11_0_arm64.whl (274 kB)
# Using cached cycler-0.12.1-py3-none-any.whl (8.3 kB)
# Downloading fonttools-4.60.1-cp313-cp313-macosx_10_13_universal2.whl (2.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.8/2.8 MB 74.9 MB/s  0:00:00
# Downloading kiwisolver-1.4.9-cp313-cp313-macosx_11_0_arm64.whl (64 kB)
# Downloading pillow-12.0.0-cp313-cp313-macosx_11_0_arm64.whl (4.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.7/4.7 MB 81.4 MB/s  0:00:00
# Downloading pyparsing-3.2.5-py3-none-any.whl (113 kB)
# Using cached pytz-2025.2-py2.py3-none-any.whl (509 kB)
# Downloading soupsieve-2.8-py3-none-any.whl (36 kB)
# Using cached typing_extensions-4.15.0-py3-none-any.whl (44 kB)
# Downloading typing_inspect-0.9.0-py3-none-any.whl (8.8 kB)
# Downloading mypy_extensions-1.1.0-py3-none-any.whl (5.0 kB)
# Using cached tzdata-2025.2-py2.py3-none-any.whl (347 kB)
# Downloading pydantic-2.12.3-py3-none-any.whl (462 kB)
# Downloading pydantic_core-2.41.4-cp313-cp313-macosx_11_0_arm64.whl (1.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.9/1.9 MB 57.0 MB/s  0:00:00
# Using cached annotated_types-0.7.0-py3-none-any.whl (13 kB)
# Downloading typing_inspection-0.4.2-py3-none-any.whl (14 kB)
# Using cached typeguard-4.4.4-py3-none-any.whl (34 kB)
# Installing collected packages: pytz, urllib3, tzdata, typing-extensions, tqdm, soupsieve, pyparsing, pyarrow, pillow, numpy, mypy-extensions, lxml, kiwisolver, idna, fonttools, cycler, charset_normalizer, chardet, certifi, annotated-types, typing-inspection, typing_inspect, typeguard, scipy, requests, pydantic-core, pandas, contourpy, beautifulsoup4, pydantic, matplotlib, pandera, databallpy
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 33/33 [databallpy]3 [databallpy]
# Successfully installed annotated-types-0.7.0 beautifulsoup4-4.14.2 certifi-2025.10.5 chardet-5.2.0 charset_normalizer-3.4.4 contourpy-1.3.3 cycler-0.12.1 databallpy-0.6.2 fonttools-4.60.1 idna-3.11 kiwisolver-1.4.9 lxml-6.0.0 matplotlib-3.10.7 mypy-extensions-1.1.0 numpy-2.3.4 pandas-2.3.3 pandera-0.22.1 pillow-12.0.0 pyarrow-19.0.1 pydantic-2.12.3 pydantic-core-2.41.4 pyparsing-3.2.5 pytz-2025.2 requests-2.32.5 scipy-1.16.2 soupsieve-2.8 tqdm-4.67.1 typeguard-4.4.4 typing-extensions-4.15.0 typing-inspection-0.4.2 typing_inspect-0.9.0 tzdata-2025.2 urllib3-2.5.0
# Note: you may need to restart the kernel to use updated packages.

# %%
from databallpy import get_game, get_open_game

game = get_game(
  tracking_data_loc="../data/tracking_data.dat",
  tracking_metadata_loc="../data/tracking_metadata.xml",
  tracking_data_provider="tracab",
  event_data_loc="../data/event_data_f24.xml",
  event_metadata_loc="../data/event_metadata_f7.xml",
  event_data_provider="opta",
)

# or get the open game provided by Metrica
game = get_open_game(provider="metrica")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[5], line 3
#       1 from databallpy import get_game, get_open_game
# ----> 3 game = get_game(
#       4   tracking_data_loc="../data/tracking_data.dat",
#       5   tracking_metadata_loc="../data/tracking_metadata.xml",
#       6   tracking_data_provider="tracab",
#       7   event_data_loc="../data/event_data_f24.xml",
#       8   event_metadata_loc="../data/event_metadata_f7.xml",
#       9   event_data_provider="opta",
#      10 )
#      12 # or get the open game provided by Metrica
#      13 game = get_open_game(provider="metrica")
#
# File ~/anaconda3/envs/e4_databallpy/lib/python3.13/site-packages/databallpy/utils/get_game.py:162, in get_game(tracking_data_loc, tracking_metadata_loc, event_data_loc, event_metadata_loc, event_match_loc, event_lineup_loc, tracking_data_provider, event_data_provider, check_quality, _check_game_class_, verbose)
#     160 # Check if event data should be loaded
#     161 if event_data_loc and event_data_provider:
# --> 162     event_data, event_metadata, databallpy_events = load_event_data(
#     163         event_data_loc=event_data_loc,
#     164         event_metadata_loc=event_metadata_loc,
#     165         event_data_provider=event_data_provider,
#     166         event_match_loc=event_match_loc,
#     167         event_lineup_loc=event_lineup_loc,
#     168     )
#     169     EventDataSchema.validate(event_data)
#     170     uses_event_data = True
#
# File ~/anaconda3/envs/e4_databallpy/lib/python3.13/site-packages/databallpy/utils/logging.py:26, in logging_wrapper.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#      22 except Exception as e:
#      23     logger.error(
#      24         f"Error in the function `{func.__name__}`: {e}\n{traceback.format_exc()}"
#      25     )
# ---> 26     raise e
#
# File ~/anaconda3/envs/e4_databallpy/lib/python3.13/site-packages/databallpy/utils/logging.py:19, in logging_wrapper.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#      17 try:
#      18     logger.info(f"Trying to run the function `{func.__name__}`")
# ---> 19     result = func(*args, **kwargs)
#      20     logger.info(f"Successfully ran the function `{func.__name__}`")
#      21     return result
#
# File ~/anaconda3/envs/e4_databallpy/lib/python3.13/site-packages/databallpy/utils/get_game.py:484, in load_event_data(event_data_loc, event_metadata_loc, event_data_provider, event_match_loc, event_lineup_loc)
#     482 databallpy_events = {}
#     483 if event_data_provider == "opta":
# --> 484     event_data, event_metadata, databallpy_events = load_opta_event_data(
#     485         f7_loc=event_metadata_loc, f24_loc=event_data_loc
#     486     )
#     487 elif event_data_provider == "metrica":
#     488     event_data, event_metadata, databallpy_events = load_metrica_event_data(
#     489         event_data_loc=event_data_loc, metadata_loc=event_metadata_loc
#     490     )
#
# File ~/anaconda3/envs/e4_databallpy/lib/python3.13/site-packages/databallpy/utils/logging.py:26, in logging_wrapper.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#      22 except Exception as e:
#      23     logger.error(
#      24         f"Error in the function `{func.__name__}`: {e}\n{traceback.format_exc()}"
#      25     )
# ---> 26     raise e
#
# File ~/anaconda3/envs/e4_databallpy/lib/python3.13/site-packages/databallpy/utils/logging.py:19, in logging_wrapper.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#      17 try:
#      18     logger.info(f"Trying to run the function `{func.__name__}`")
# ---> 19     result = func(*args, **kwargs)
#      20     logger.info(f"Successfully ran the function `{func.__name__}`")
#      21     return result
#
# File ~/anaconda3/envs/e4_databallpy/lib/python3.13/site-packages/databallpy/data_parsers/event_data_parsers/opta_parser.py:216, in load_opta_event_data(f7_loc, f24_loc, pitch_dimensions)
#     211 if not f24_loc == "pass" and not f24_loc[-4:] == ".xml":
#     212     raise ValueError(
#     213         f"f24 opta file should be of .xml format, not {f24_loc.split('.')[-1]}"
#     214     )
# --> 216 metadata = _load_metadata(f7_loc, pitch_dimensions=pitch_dimensions)
#     217 all_players = pd.concat(
#     218     [metadata.home_players, metadata.away_players], ignore_index=True
#     219 )
#     220 if f24_loc != "pass":
#
# File ~/anaconda3/envs/e4_databallpy/lib/python3.13/site-packages/databallpy/data_parsers/event_data_parsers/opta_parser.py:291, in _load_metadata(f7_loc, pitch_dimensions)
#     281 def _load_metadata(f7_loc: str, pitch_dimensions: list) -> Metadata:
#     282     """Function to load metadata from the f7.xml opta file
#     283
#     284     Args:
#    (...)    289         MetaData: all metadata information of the current game
#     290     """
# --> 291     with open(f7_loc, "rb") as f:
#     292         encoding = chardet.detect(f.read())["encoding"]
#     293     with open(f7_loc, "r", encoding=encoding) as file:
#
# FileNotFoundError: [Errno 2] No such file or directory: '../data/event_metadata_f7.xml'
