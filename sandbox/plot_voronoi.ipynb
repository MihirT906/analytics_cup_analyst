# %%
from src.models.DataLoader import DataLoader
from src.models.Pitch import PlotlyPitch
dl = DataLoader()
match_id = 1886347
enriched_data = dl.create_enriched_tracking_data(match_id)

# %%
frame_data = enriched_data[enriched_data['frame'] == 10]

# %%
# # show all columns
# import pandas as pd
# pd.set_option('display.max_columns', None)
# frame_data

# %%
pp = PlotlyPitch()
p = pp.generate_pitch()

# %%
import matplotlib.pyplot as plt
fig, ax = p.draw(figsize=(12,8))

# Plot Voronoi
team1, team2 = p.voronoi(frame_data.x+105/2, frame_data.y+68/2,
                         frame_data['direction_player_1st_half'] == 'left_to_right')
t1 = p.polygon(team1, ax=ax, fc='orange', ec='white', lw=3, alpha=0.4)
t2 = p.polygon(team2, ax=ax, fc='dodgerblue', ec='white', lw=3, alpha=0.4)

# Plot players
sc1 = p.scatter(frame_data.x+105/2, frame_data.y+68/2, c='orange', s=80, ec='k', ax=ax)
# sc2 = p.scatter(opponent_locs.x, opponent_locs.y, c='dodgerblue', s=80, ec='k', ax=ax)

# Plot the visible area
# visible = p.polygon([visible_area], color='None', ec='k', linestyle='--', lw=2, ax=ax)

# # clip each player to the visible area
# for p1 in t1:
#     p1.set_clip_path(visible[0])
# for p2 in t2:
#     p2.set_clip_path(visible[0])

plt.show()  # If you are using a Jupyter notebook you do not need this line

# %%
team1
# Out:
# array([array([[9.99150833e+00, 7.91098596e-16],
#               [2.19943607e+01, 2.69338731e+01],
#               [2.14619318e+01, 4.41652065e+01],
#               [5.95422761e-16, 7.23331436e+01],
#               [2.93900213e-15, 0.00000000e+00]]),
#        array([[9.99150833e+00, 7.91098596e-16],
#               [2.19943607e+01, 2.69338731e+01],
#               [3.64413608e+01, 3.08562710e+01],
#               [4.19159020e+01, 1.81217267e+01],
#               [3.55542507e+01, 7.93534675e+00],
#               [2.53152355e+01, 5.25621682e-16]]),
#        array([[36.26155302, 41.30420502],
#               [21.46193182, 44.1652065 ],
#               [21.99436066, 26.93387305],
#               [36.44136081, 30.85627102],
#               [38.72050079, 35.98017696]]),
#        array([[7.17537680e+01, 0.00000000e+00],
#               [2.53152355e+01, 5.25621682e-16],
#               [3.55542507e+01, 7.93534675e+00],
#               [6.03293685e+01, 7.13614940e+00],
#               [6.98091685e+01, 1.92811111e+00]]),
#        array([[4.24441514e+01, 4.95500658e+01],
#               [3.69549383e+01, 8.00000000e+01],
#               [3.99871458e-15, 8.00000000e+01],
#               [5.95422761e-16, 7.23331436e+01],
#               [2.14619318e+01, 4.41652065e+01],
#               [3.62615530e+01, 4.13042050e+01]]),
#        array([[47.37388155, 47.20136834],
#               [47.70443093, 35.60852967],
#               [46.94734069, 34.55708275],
#               [38.72050079, 35.98017696],
#               [36.26155302, 41.30420502],
#               [42.44415137, 49.55006584]]),
#        array([[46.94734069, 34.55708275],
#               [49.05102042, 30.70688452],
#               [45.56952018, 20.15591589],
#               [41.91590203, 18.1217267 ],
#               [36.44136081, 30.85627102],
#               [38.72050079, 35.98017696]]),
#        array([[50.29633169, 47.03661617],
#               [47.37388155, 47.20136834],
#               [47.70443093, 35.60852967],
#               [54.21465136, 39.44945785]]),
#        array([[60.3293685 ,  7.1361494 ],
#               [53.99036548, 19.35522311],
#               [45.56952018, 20.15591589],
#               [41.91590203, 18.1217267 ],
#               [35.55425074,  7.93534675]]),
#        array([[50.29633169, 47.03661617],
#               [47.37388155, 47.20136834],
#               [42.44415137, 49.55006584],
#               [36.95493834, 80.        ],
#               [50.45782609, 80.        ],
#               [52.30921706, 48.06350577]]),
#        array([[58.4278097 , 38.79841793],
#               [54.21465136, 39.44945785],
#               [47.70443093, 35.60852967],
#               [46.94734069, 34.55708275],
#               [49.05102042, 30.70688452],
#               [57.05635627, 29.94655241],
#               [59.43656453, 36.9999029 ]])], dtype=object)

# %%
for poly in team1:
    fig.add_trace(go.Scatter(
        x=poly[:,0], 
        y=poly[:,1], 
        fill="toself",
        showlegend=False
    ))
fig.show()

# %%
import plotly.graph_objects as go

fig = go.Figure(go.Scatter(x=[0,1,2,0], y=[0,2,0,0], fill="toself"))
fig.show()

# %%
import matplotlib.pyplot as plt
fig, ax = p.draw(figsize=(12,8))

# Plot Voronoi
team1, team2 = p.voronoi(frame_data.x, frame_data.y,
                         frame_data['direction_player_1st_half'] == 'left_to_right')
t1 = p.polygon(team1, ax=ax, fc='orange', ec='white', lw=3, alpha=0.4)
t2 = p.polygon(team2, ax=ax, fc='dodgerblue', ec='white', lw=3, alpha=0.4)

# Plot players
sc1 = p.scatter(frame_data.x, frame_data.y, c='orange', s=80, ec='k', ax=ax)
# sc2 = p.scatter(opponent_locs.x, opponent_locs.y, c='dodgerblue', s=80, ec='k', ax=ax)

# Plot the visible area
# visible = p.polygon([visible_area], color='None', ec='k', linestyle='--', lw=2, ax=ax)

# # clip each player to the visible area
# for p1 in t1:
#     p1.set_clip_path(visible[0])
# for p2 in t2:
#     p2.set_clip_path(visible[0])

plt.show()  # If you are using a Jupyter notebook you do not need this line

# %%
enriched_data
# Out:
#             x      y  player_id  is_detected  frame               timestamp  \
# 0      -39.63  -0.08      51009        False     10 2025-12-11 00:00:00.000
# 1      -19.21  -9.18     176224         True     10 2025-12-11 00:00:00.000
# 2      -21.83   0.47      51649         True     10 2025-12-11 00:00:00.000
# 3       -1.16 -32.47      50983         True     10 2025-12-11 00:00:00.000
# 4      -18.88  15.73     735578         True     10 2025-12-11 00:00:00.000
# ...       ...    ...        ...          ...    ...                     ...
# 956071   9.43 -11.55     735574         True  59038 2025-12-11 01:37:03.800
# 956072  10.88 -24.28     797297         True  59038 2025-12-11 01:37:03.800
# 956073  -0.95   3.53     735573        False  59038 2025-12-11 01:37:03.800
# 956074   9.43 -31.76     560992         True  59038 2025-12-11 01:37:03.800
# 956075 -10.47 -16.15     795506        False  59038 2025-12-11 01:37:03.800
#
#        period  possession_player_id possession_group  ball_x  ...  number  \
# 0         1.0                   NaN             None    0.32  ...       1
# 1         1.0                   NaN             None    0.32  ...       4
# 2         1.0                   NaN             None    0.32  ...      15
# 3         1.0                   NaN             None    0.32  ...      14
# 4         1.0                   NaN             None    0.32  ...      33
# ...       ...                   ...              ...     ...  ...     ...
# 956071    2.0                   NaN             None   29.50  ...      17
# 956072    2.0                   NaN             None   29.50  ...       6
# 956073    2.0                   NaN             None   29.50  ...      39
# 956074    2.0                   NaN             None   29.50  ...      23
# 956075    2.0                   NaN             None   29.50  ...      13
#
#         team_id                 team_name  player_role.position_group  \
# 0          1805  Newcastle United Jets FC                       Other
# 1          1805  Newcastle United Jets FC            Central Defender
# 2          1805  Newcastle United Jets FC            Central Defender
# 3          1805  Newcastle United Jets FC                   Full Back
# 4          1805  Newcastle United Jets FC                   Full Back
# ...         ...                       ...                         ...
# 956071     1805  Newcastle United Jets FC                    Midfield
# 956072     1805  Newcastle United Jets FC                    Midfield
# 956073     1805  Newcastle United Jets FC               Wide Attacker
# 956074     1805  Newcastle United Jets FC                    Midfield
# 956075     1805  Newcastle United Jets FC              Center Forward
#
#        total_time          player_role.name player_role.acronym  is_gk  \
# 0            5400                Goalkeeper                  GK   True
# 1            5400         Right Center Back                 RCB  False
# 2            5400          Left Center Back                 LCB  False
# 3            5400                Right Back                  RB  False
# 4            5400                 Left Back                  LB  False
# ...           ...                       ...                 ...    ...
# 956071       5400  Right Defensive Midfield                 RDM  False
# 956072        302        Attacking Midfield                  AM  False
# 956073       5400               Left Winger                  LW  False
# 956074       1785        Attacking Midfield                  AM  False
# 956075       1337            Center Forward                  CF  False
#
#        direction_player_1st_half direction_player_2nd_half
# 0                  left_to_right             right_to_left
# 1                  left_to_right             right_to_left
# 2                  left_to_right             right_to_left
# 3                  left_to_right             right_to_left
# 4                  left_to_right             right_to_left
# ...                          ...                       ...
# 956071             left_to_right             right_to_left
# 956072             left_to_right             right_to_left
# 956073             left_to_right             right_to_left
# 956074             left_to_right             right_to_left
# 956075             left_to_right             right_to_left
#
# [956076 rows x 32 columns]

# %% [markdown]
# # Plots a Voronoi diagram
#
# This example shows how to plot a Voronoi diagram for a freeze frame.

# %%
import matplotlib.pyplot as plt
from mplsoccer import Pitch, Sbopen
import numpy as np

# get freeze frame data for game 3788741
parser = Sbopen()
frames, visible = parser.frame(3788741)

# %% [markdown]
# Subset a shot

# %%
frame_idx = 50
frame_id = visible.iloc[50].id

visible_area = np.array(visible.iloc[frame_idx].visible_area).reshape(-1, 2)
player_position_data = frames[frames.id == frame_id]

teammate_locs = player_position_data[player_position_data.teammate]
opponent_locs = player_position_data[~player_position_data.teammate]

# %% [markdown]
# Plotting

# %%
player_position_data
# Out:
#      teammate  actor  keeper  match_id                                    id  \
# 710      True  False   False   3788741  32e784fb-a623-4dd0-b7c0-030dd35f5972
# 711      True  False   False   3788741  32e784fb-a623-4dd0-b7c0-030dd35f5972
# 712      True  False   False   3788741  32e784fb-a623-4dd0-b7c0-030dd35f5972
# 713     False  False   False   3788741  32e784fb-a623-4dd0-b7c0-030dd35f5972
# 714      True  False   False   3788741  32e784fb-a623-4dd0-b7c0-030dd35f5972
# 715     False  False   False   3788741  32e784fb-a623-4dd0-b7c0-030dd35f5972
# 716     False  False   False   3788741  32e784fb-a623-4dd0-b7c0-030dd35f5972
# 717      True  False   False   3788741  32e784fb-a623-4dd0-b7c0-030dd35f5972
# 718     False  False   False   3788741  32e784fb-a623-4dd0-b7c0-030dd35f5972
# 719      True  False   False   3788741  32e784fb-a623-4dd0-b7c0-030dd35f5972
# 720     False  False   False   3788741  32e784fb-a623-4dd0-b7c0-030dd35f5972
# 721      True   True   False   3788741  32e784fb-a623-4dd0-b7c0-030dd35f5972
# 722     False  False   False   3788741  32e784fb-a623-4dd0-b7c0-030dd35f5972
# 723     False  False   False   3788741  32e784fb-a623-4dd0-b7c0-030dd35f5972
# 724      True  False   False   3788741  32e784fb-a623-4dd0-b7c0-030dd35f5972
# 725      True  False   False   3788741  32e784fb-a623-4dd0-b7c0-030dd35f5972
#
#              x          y
# 710  23.519619  41.807806
# 711  27.188612  68.547258
# 712  27.907616  26.814768
# 713  28.335245  62.641055
# 714  28.885842  57.834857
# 715  28.890490  54.578963
# 716  32.534914  22.631028
# 717  33.332629  65.920658
# 718  36.168083  68.948036
# 719  36.312408  55.726740
# 720  37.438779  66.895325
# 721  38.500000  74.099998
# 722  41.233530  47.493613
# 723  45.356801  61.664575
# 724  45.958177  64.372225
# 725  46.749888  45.868858

# %%
# draw plot
p = Pitch(pitch_type='statsbomb')
fig, ax = p.draw(figsize=(12,8))

# Plot Voronoi
team1, team2 = p.voronoi(player_position_data.x, player_position_data.y,
                         player_position_data.teammate)
t1 = p.polygon(team1, ax=ax, fc='orange', ec='white', lw=3, alpha=0.4)
t2 = p.polygon(team2, ax=ax, fc='dodgerblue', ec='white', lw=3, alpha=0.4)

# Plot players
sc1 = p.scatter(teammate_locs.x, teammate_locs.y, c='orange', s=80, ec='k', ax=ax)
sc2 = p.scatter(opponent_locs.x, opponent_locs.y, c='dodgerblue', s=80, ec='k', ax=ax)

# Plot the visible area
visible = p.polygon([visible_area], color='None', ec='k', linestyle='--', lw=2, ax=ax)

# clip each player to the visible area
for p1 in t1:
    p1.set_clip_path(visible[0])
for p2 in t2:
    p2.set_clip_path(visible[0])

plt.show()  # If you are using a Jupyter notebook you do not need this line
