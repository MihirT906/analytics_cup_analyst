# %% [markdown]
# Setup

# %%
import sys
import os

# # Get the project root (go up from tests to project root)
project_root = os.path.dirname(os.path.abspath('.'))
if project_root not in sys.path:
    sys.path.insert(0, project_root)

# %% [markdown]
# Import

# %%
from src.models.GameRenderer import GameRenderer
game_renderer = GameRenderer()
match_id = 1886347

# %% [markdown]
# Plotting

# %%
# To plot tracking data
game_renderer.plot_episode(match_id, start_frame=10, end_frame=200, delay=0.0001, plot_events=False)
# Out:
# (<Figure size 1400x1000 with 1 Axes>,
#  <Axes: title={'center': 'Frame: 200 | Time: 2025-10-31 00:00:19 | Period: 1.0'}>)

# %%
# # To plot tracking data with player possessions highlighted
# game_renderer.plot_episode(match_id, start_frame=10, end_frame=200, delay=0.0001, plot_events=True)
