# %%
from src.models.GameRenderer import GameRenderer

# %%
game_renderer = GameRenderer(config_file='src/config/custom_game_renderer_config.json')

# %%
match_id = 1886347
game_renderer.plot_episode(match_id, start_frame=45000, end_frame=45100, delay=0)
