# %% [markdown]
# Setup

# %%
import sys
import os

# # Get the project root (go up from tests to project root)
project_root = os.path.dirname(os.path.abspath('.'))
if project_root not in sys.path:
    sys.path.insert(0, project_root)

# %% [markdown]
# Plot game data from match id

# %%
from models.GameRenderer import GameRenderer
game_renderer = GameRenderer()
match_id = 1886347

# %%
game_renderer.plot_episode(match_id, start_frame=10, end_frame=200, delay=0)

# %% [markdown]
# Add config file for styling

# %%
game_renderer = GameRenderer(config_file='../config/simple_game_renderer_config.json')
game_renderer.plot_episode(match_id, start_frame=10, end_frame=200, delay=0)

# %% [markdown]
# Plot a saved episode

# %%
game_renderer.plot_saved_episode('../episodes/1886347_all_shots/episode_1.json', delay=0)
